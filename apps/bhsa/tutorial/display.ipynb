# %% [markdown]
# # Rich display
#
# We have a new module, `bhsa.py`, that can display every node in a shebanq-like way.
# It can also display query results obtained by Text-Fabric search.
#
# ## Install
#
# This module is part of the [BHSA](https://github.com/ETCBC/bhsa) repo, which you need to have to run TF on the Hebrew Bible anyway. So update your repo by `git pull origin master` or clone it again.
#
# ## Usage
#
# The new module makes the use of TF a bit easier.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
from IPython.display import display, HTML
from tf.app import use

# %%
A = use('bhsa', hoist=globals())
# Out:
# Using etcbc/bhsa - c r1.5 in ~/text-fabric-data/etcbc/bhsa/tf/c
# Using etcbc/phono - c r1.2 in ~/text-fabric-data/etcbc/phono/tf/c
# Using etcbc/parallels - c r1.2 in ~/text-fabric-data/etcbc/parallels/tf/c
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Writing/Hebrew" title="('Hebrew characters and transcriptions',)">Character table</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/c/0_home.html" title="BHSA feature documentation">Feature docs</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/Bhsa/" title="bhsa API documentation">bhsa API</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/" title="text-fabric-api">Text-Fabric API 6.4.6</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#search-templates" title="Search Templates Introduction and Reference">Search Reference</a>
# <details open><summary><b>Loaded features</b>:</summary>
# <p><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b>: <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/book@am.tf">book@ll</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/code.tf">code</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/det.tf">det</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/dist.tf">dist</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/dist_unit.tf">dist_unit</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/domain.tf">domain</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/freq_lex.tf">freq_lex</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/freq_occ.tf">freq_occ</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/function.tf">function</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/g_word.tf">g_word</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/g_word_utf8.tf">g_word_utf8</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/gloss.tf">gloss</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/instruction.tf">instruction</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/is_root.tf">is_root</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/kind.tf">kind</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/label.tf">label</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/language.tf">language</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/lex.tf">lex</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/lex_utf8.tf">lex_utf8</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/ls.tf">ls</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/nametype.tf">nametype</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/nme.tf">nme</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/nu.tf">nu</a>  <a target="_blank" href="https://github.com/etcbc/bhsa/tree/master/tf" title="/Users/dirk/text-fabric-data/etcbc/bhsa/tf/c/number.tf">number</a>  ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src: url('https://github.com/Dans-labs/text-fabric/blob/master/tf/server/static/fonts/SILEOT.ttf?raw=true');
#   src: url('https://github.com/Dans-labs/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
# </style>
#
# <style type="text/css">
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.L,.catom.L,.patom.L {
#     border-left-style: none
# }
# .satom.R,.catom.R,.patom.R {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 1.8;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#loading" title="doc">TF</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#loading" title="doc">ignored</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#messaging" title="doc">cache</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#messaging" title="doc">error</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#messaging" title="doc">indent</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#messaging" title="doc">info</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#searching" title="doc">S Search</a><br/>
# <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
A.nodeFromDefaultSection('Genesis 1:1')
# Out:
# ('', 1414354)

# %%
phrase = 651574
A.pretty(phrase)
# Out:
# <div class="atoms " style="background-color: None;">
#
#
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BJNn" title="show this lexeme in SHEBANQ">בֵּ֥ין </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">prep</a></span> <span class="gloss">interval</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AWRn" title="show this lexeme in SHEBANQ">אֹ֖ור </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">subs</a></span> <span class="gloss">light</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BJNn" title="show this lexeme in SHEBANQ">בֵ֥ין </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">prep</a></span> <span class="gloss">interval</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1XCKn" title="show this lexeme in SHEBANQ">חֹֽשֶׁךְ׃ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:4" sec="Genesis 1:4">subs</a></span> <span class="gloss">darkness</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Where is this phrase on SHEBANQ?
# You can click on the word `phrase` in the label of the box.
#
# You can generate this link in code as follows:

# %%
A.webLink(phrase)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:4">Genesis 1:4</a>

# %% [markdown]
# A link to another passage:

# %%
z = T.nodeFromSection(('Ezra', 3, 4))

# %%
A.webLink(z)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Esra&chapter=3&verse=4&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Ezra 3:4">Ezra 3:4</a>

# %% [markdown]
# # Verses
# Now a couple of verses:

# %%
verse1 = T.nodeFromSection(('Genesis', 1, 7))
verse2 = T.nodeFromSection(('Genesis', 1, 17))

# %%
A.pretty(verse1)
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:7">Genesis 1:7</a></div>
#
#     </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">sentence</a>   <span class="number">18</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1OFHv" title="show this lexeme in SHEBANQ">יַּ֣עַשׂ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">verb</a></span> <span class="gloss">make</span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִים֮ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">subs</a></span> <span class="gloss">god(s)</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1RQJOn" title="show this lexeme in SHEBANQ">רָקִיעַ֒ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">subs</a></span> <span class="gloss">firmament</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">sentence</a>   <span class="number">19</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l" style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7" sec="Genesis 1:7">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BDLv" title="show this lexeme in SHEBANQ">יַּבְדֵּ֗ל </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-da

# %% [markdown]
# The next verse with node numbers.

# %%
A.pretty(verse2, withNodes=True)
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:17">Genesis 1:17</a></div>
#         <a href="#" class="nd">1414370</a>
#     </div>
#
# <div class="satom  L" style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">sentence</a> <a href="#" class="nd">1172335</a>  <span class="number">46</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">clause</a> <a href="#" class="nd">427611</a>  <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a> <a href="#" class="nd">651720</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">314</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a> <a href="#" class="nd">651721</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">315</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1NTNv" title="show this lexeme in SHEBANQ">יִּתֵּ֥ן </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">verb</a></span> <span class="gloss">give</span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a> <a href="#" class="nd">651722</a>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">316</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֹתָ֛ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a> <a href="#" class="nd">651723</a>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">317</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִ֖ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss">god(s)</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a> <a href="#" class="nd">651724</a>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">318</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span> <span class="gloss">in</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">319</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1RQJOn" title="show this lexeme in SHEBANQ">רְקִ֣יעַ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss">firmament</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">320</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">321</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1CMJMn" title="show this lexeme in SHEBANQ">שָּׁמָ֑יִם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss">heavens</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">clause</a> <a href="#" class="nd">427612</a>  <span

# %% [markdown]
# Now we selectively remove a few features from the display:

# %%
A.pretty(verse2, suppress={'gloss', 'typ'})
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:17">Genesis 1:17</a></div>
#
#     </div>
#
# <div class="satom  L" style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">sentence</a>   <span class="number">46</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">clause</a>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Conj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">conj</a></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1NTNv" title="show this lexeme in SHEBANQ">יִּתֵּ֥ן </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">verb</a></span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Objc</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֹתָ֛ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Subj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִ֖ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1RQJOn" title="show this lexeme in SHEBANQ">רְקִ֣יעַ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">art</a></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1CMJMn" title="show this lexeme in SHEBANQ">שָּׁמָ֑יִם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">clause</a>   <span class="rela">Adju</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1L" title="show this lexeme in SHEBANQ">לְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-

# %% [markdown]
# Now we add features to the display: `lex` and `g_word` :

# %%
A.prettySetup(features=['lex', 'g_word'])

# %%
A.pretty(verse2)
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:17">Genesis 1:17</a></div>
#
#     </div>
#
# <div class="satom  L" style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">sentence</a>   <span class="number">46</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">conj</a></span> <span class="gloss">and</span> <span class="g_word xft"><span class="f">g_word=</span>WA-</span> <span class="lex xft"><span class="f">lex=</span>W</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1NTNv" title="show this lexeme in SHEBANQ">יִּתֵּ֥ן </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">verb</a></span> <span class="gloss">give</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="g_word xft"><span class="f">g_word=</span>J.IT.;71N</span> <span class="lex xft"><span class="f">lex=</span>NTN[</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֹתָ֛ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span> <span class="gloss">&lt;object marker></span> <span class="g_word xft"><span class="f">g_word=</span>>OT@91M</span> <span class="lex xft"><span class="f">lex=</span>>T</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִ֖ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss">god(s)</span> <span class="g_word xft"><span class="f">g_word=</span>>:ELOHI73JM</span> <span class="lex xft"><span class="f">lex=</span>>LHJM/</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">prep</a></span> <span class="gloss">in</span> <span class="g_word xft"><span class="f">g_word=</span>B.I-</span> <span class="lex xft"><span class="f">lex=</span>B</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1RQJOn" title="show this lexeme in SHEBANQ">רְקִ֣יעַ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss">firmament</span> <span class="g_word xft"><span class="f">g_word=</span>R:QI74J&lt;A</span> <span class="lex xft"><span class="f">lex=</span>RQJ&lt;/</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">art</a></span> <span class="gloss">the</span> <span class="g_word xft"><span class="f">g_word=</span>HA-</span> <span class="lex xft"><span class="f">lex=</span>H</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1CMJMn" title="show this lexeme in SHEBANQ">שָּׁמָ֑יִם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17" sec="Genesis 1:17">subs</a></span> <span class="gloss"

# %% [markdown]
# and we reset the pretty features to the default values:

# %%
A.prettySetup()

# %% [markdown]
# # Query results
# We run a TF query and show some of its results with a lot of pomp and circumstance.
# The query is written by Stephen Ku, and he is the one who prompted me to write
# rich display function for query results.

# %%
ellipQuery = '''
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
'''

# %% [markdown]
# Instead of running `S.search()`, we do `A.search()`.

# %%
results = A.search(ellipQuery)
len(results)
# Out:
#   1.80s 1472 results
# 1472

# %% [markdown]
# Here it comes: the `A.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
A.show(results, start=10, end=14, withNodes=True)
# Out:
# **verse** *10*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Exodus 23:16">Exodus 23:16</a></div>
#         <a href="#" class="nd">1416514</a>
#     </div>
#
# <div class="satom  r hl">
#
#     <div class="sentence hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=15&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:15" sec="Exodus 23:15">sentence</a> <a href="#" class="nd">1178876</a>  <span class="number">36</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">clause</a> <a href="#" class="nd">436059</a>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">phrase</a> <a href="#" class="nd">677199</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41279</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">phrase</a> <a href="#" class="nd">677200</a>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41280</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1XGn" title="show this lexeme in SHEBANQ">חַ֤ג </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">subs</a></span> <span class="gloss">festival</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41281</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41282</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1QYJRn" title="show this lexeme in SHEBANQ">קָּצִיר֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">subs</a></span> <span class="gloss">harvest</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">phrase</a> <a href="#" class="nd">677201</a>  <span class="function">Adju</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41283</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BKWRJMn" title="show this lexeme in SHEBANQ">בִּכּוּרֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">subs</a></span> <span class="gloss">first fruits</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41284</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1MOFHn" title="show this lexeme in SHEBANQ">מַעֲשֶׂ֔יךָ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">subs</a></span> <span class="gloss">deed</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">clause</a> <a href="#" class="nd">436060</a>  <span class="rela">Attr</span> <span class="typ">xYq0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">phrase</a> <a href="#" class="nd">677202</a>  <span class="function">Rela</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41285</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ACR" title="show this lexeme in SHEBANQ">אֲשֶׁ֥ר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">conj</a></span> <span class="gloss">&lt;relative></span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">phrase</a> <a href="#" class="nd">677203</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">41286</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ZROv" title="show this lexeme in SHEBANQ">תִּזְרַ֖ע </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16" sec="Exodus 23:16">verb</a></span> <span class="gloss">sow</span> <span class="vs">qal</span> <span class="vt">impf</sp
# **verse** *11*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Exodus 25:12">Exodus 25:12</a></div>
#         <a href="#" class="nd">1416561</a>
#     </div>
#
# <div class="satom  hl">
#
#     <div class="sentence hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">sentence</a> <a href="#" class="nd">1178995</a>  <span class="number">16</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">clause</a> <a href="#" class="nd">436206</a>  <span class="typ">WQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677666</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42122</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677667</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl">
# <a href="#" class="nd">42123</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1JYQv" title="show this lexeme in SHEBANQ">יָצַ֣קְתָּ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">verb</a></span> <span class="gloss">pour</span> <span class="vs">qal</span> <span class="vt">perf</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677668</a>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42124</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1L" title="show this lexeme in SHEBANQ">לֹּ֗ו </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">prep</a></span> <span class="gloss">to</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677669</a>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42125</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ARBOn" title="show this lexeme in SHEBANQ">אַרְבַּע֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">subs</a></span> <span class="gloss">four</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42126</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1VBOTn" title="show this lexeme in SHEBANQ">טַבְּעֹ֣ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">subs</a></span> <span class="gloss">sealing ring</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42127</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ZHBn" title="show this lexeme in SHEBANQ">זָהָ֔ב </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">subs</a></span> <span class="gloss">gold</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">clause</a> <a href="#" class="nd">436207</a>  <span class="rela">Coor</span> <span class="typ">WQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677670</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42128</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12" sec="Exodus 25:12">phrase</a> <a href="#" class="nd">677671</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">42129</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=
# **verse** *12*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Exodus 31:6">Exodus 31:6</a></div>
#         <a href="#" class="nd">1416780</a>
#     </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">sentence</a> <a href="#" class="nd">1179443</a>  <span class="number">7</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">clause</a> <a href="#" class="nd">436833</a>  <span class="typ">CPen</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679661</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46227</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679662</a>  <span class="function">Frnt</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46228</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ANJ" title="show this lexeme in SHEBANQ">אֲנִ֞י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">prps</a></span> <span class="gloss">i</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">clause</a> <a href="#" class="nd">436834</a>  <span class="rela">Resu</span> <span class="typ">xQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679663</a>  <span class="function">Intj</span> <span class="typ">InjP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46229</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1HNH" title="show this lexeme in SHEBANQ">הִנֵּ֧ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">intj</a></span> <span class="gloss">behold</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679664</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46230</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1NTNv" title="show this lexeme in SHEBANQ">נָתַ֣תִּי </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">verb</a></span> <span class="gloss">give</span> <span class="vs">qal</span> <span class="vt">perf</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679665</a>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46231</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1ATii" title="show this lexeme in SHEBANQ">אִתֹּ֗ו </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">prep</a></span> <span class="gloss">together with</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l" style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">phrase</a> <a href="#" class="nd">679666</a>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46232</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֵ֣ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46233</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AHLJABn" title="show this lexeme in SHEBANQ">אָהֳלִיאָ֞ב </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">nmpr</a></span> <span class="gloss">Oholiab</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r
# **verse** *13*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Exodus 31:10">Exodus 31:10</a></div>
#         <a href="#" class="nd">1416784</a>
#     </div>
#
# <div class="satom  R L hl">
#
#     <div class="sentence hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">sentence</a> <a href="#" class="nd">1179445</a>  <span class="number">9</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">clause</a> <a href="#" class="nd">436842</a>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">phrase</a> <a href="#" class="nd">679683</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46313</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l" style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">phrase</a> <a href="#" class="nd">679684</a>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46314</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֵ֖ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46315</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BGDn" title="show this lexeme in SHEBANQ">בִּגְדֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">subs</a></span> <span class="gloss">garment</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46316</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46317</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1FRDin" title="show this lexeme in SHEBANQ">שְּׂרָ֑ד </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">subs</a></span> <span class="gloss">cord</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46318</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46319</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46320</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1BGDn" title="show this lexeme in SHEBANQ">בִּגְדֵ֤י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">subs</a></span> <span class="gloss">garment</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46321</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46322</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1QDCn" title="show this lexeme in SHEBANQ">קֹּ֨דֶשׁ֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">subs</a></span> <span class="gloss">holiness</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l" style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10" sec="Exodus 31:10">phrase</a> <a href="#" class="nd">679684</a>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46323</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1L" title="show this lexeme in SHEBANQ">לְ</a></div>
# <div clas
# **verse** *14*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ" sec="Exodus 31:11">Exodus 31:11</a></div>
#         <a href="#" class="nd">1416785</a>
#     </div>
#
# <div class="satom  R hl">
#
#     <div class="sentence hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6" sec="Exodus 31:6">sentence</a> <a href="#" class="nd">1179445</a>  <span class="number">9</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">clause</a> <a href="#" class="nd">436844</a>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">phrase</a> <a href="#" class="nd">679686</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46333</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">phrase</a> <a href="#" class="nd">679687</a>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46334</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֵ֨ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word  hl">
# <a href="#" class="nd">46335</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1CMNn" title="show this lexeme in SHEBANQ">שֶׁ֧מֶן </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">subs</a></span> <span class="gloss">oil</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46336</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word  hl">
# <a href="#" class="nd">46337</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1MCXHn" title="show this lexeme in SHEBANQ">מִּשְׁחָ֛ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">subs</a></span> <span class="gloss">anointment</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46338</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">conj</a></span> <span class="gloss">and</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46339</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
#
# </div>
#
# <div class="word  hl">
# <a href="#" class="nd">46340</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1QVRTn" title="show this lexeme in SHEBANQ">קְטֹ֥רֶת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">subs</a></span> <span class="gloss">smoke of sacrifice</span></div>
#
#
# </div>
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46341</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">art</a></span> <span class="gloss">the</span></div>
#
#
# </div>
#
# <div class="word  hl">
# <a href="#" class="nd">46342</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1SMn" title="show this lexeme in SHEBANQ">סַּמִּ֖ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">subs</a></span> <span class="gloss">perfume</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11" sec="Exodus 31:11">phrase</a> <a href="#" class="nd">679688</a>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <a href="#" class="nd">46343</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&id=1L" title="show this lexeme in SHEBANQ">לַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=c&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=
