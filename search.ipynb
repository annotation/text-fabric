# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Finding-a-tablet" data-toc-modified-id="Finding-a-tablet-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Finding a tablet</a></span></li><li><span><a href="#More-info-in-the-results" data-toc-modified-id="More-info-in-the-results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>More info in the results</a></span></li><li><span><a href="#Search-templates" data-toc-modified-id="Search-templates-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Search templates</a></span></li><li><span><a href="#Search-for-spatial-patterns" data-toc-modified-id="Search-for-spatial-patterns-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Search for spatial patterns</a></span></li><li><span><a href="#Comparisons-in-templates:-cases" data-toc-modified-id="Comparisons-in-templates:-cases-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Comparisons in templates: cases</a></span></li><li><span><a href="#Relational-patterns:-quads" data-toc-modified-id="Relational-patterns:-quads-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Relational patterns: quads</a></span></li><li><span><a href="#Regular-expressions-in-templates" data-toc-modified-id="Regular-expressions-in-templates-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Regular expressions in templates</a></span><ul class="toc-item"><li><span><a href="#Digits-in-graphemes" data-toc-modified-id="Digits-in-graphemes-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Digits in graphemes</a></span></li><li><span><a href="#Pit-numbers" data-toc-modified-id="Pit-numbers-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Pit numbers</a></span></li></ul></li><li><span><a href="#Search-and-hand-coding" data-toc-modified-id="Search-and-hand-coding-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Search and hand-coding</a></span><ul class="toc-item"><li><span><a href="#A-tablet-calculator" data-toc-modified-id="A-tablet-calculator-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>A tablet calculator</a></span><ul class="toc-item"><li><span><a href="#Rationale" data-toc-modified-id="Rationale-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Rationale</a></span></li><li><span><a href="#Data-collection" data-toc-modified-id="Data-collection-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Data collection</a></span></li><li><span><a href="#The-calculator" data-toc-modified-id="The-calculator-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>The calculator</a></span></li><li><span><a href="#Calculate-once" data-toc-modified-id="Calculate-once-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>Calculate once</a></span></li><li><span><a href="#Calculate-ad-lib" data-toc-modified-id="Calculate-ad-lib-8.1.5"><span class="toc-item-num">8.1.5&nbsp;&nbsp;</span>Calculate ad lib</a></span></li></ul></li></ul></li><li><span><a href="#More-..." data-toc-modified-id="More-...-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>More ...</a></span></li></ul></div>

# %% [markdown]
# <img align="right" src="images/ninologo.png" width="200"/>
# <img align="right" src="images/dans.png" width="100"/>
# <img align="right" src="images/tf.png" width="100"/>
#
# # Search
#
# Search is essential to get around in the corpus, and it is convenient as well.
# Whereas the whole point of Text-Fabric is to move around in the corpus programmatically,
# we show that
# [template based search](https://dans-labs.github.io/text-fabric/Api/General/#search-templates)
# makes everything a lot more convenient ...
#
# Along with showing how search works, we also point to pretty ways to display your search results.
# The good news is that `search` and `pretty` work well together.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import collections
from IPython.display import display, Markdown
from tf.extra.cunei import Cunei

# %%
LOC = ('~/github', 'Nino-cunei/uruk', 'search')
CN = Cunei(*LOC)
CN.api.makeAvailableIn(globals())
# Out:
# Found 2095 ideograph linearts
# Found 2724 tablet linearts
# Found 5495 tablet photos
# **Documentation:** <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs/about.md" title="provenance of this corpus">Uruk IV-III (v1.0)</a> <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs/transcription.md" title="feature documentation">Feature docs</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/Cunei/" title="cunei api documentation">Cunei API</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/" title="text-fabric-api">Text-Fabric API 4.3.5</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#search-templates" title="Search Templates Introduction and Reference">Search Reference</a>
# This notebook online:
# <a target="_blank" href="http://nbviewer.jupyter.org/github/Dans-labs/text-fabric/blob/master/search.ipynb">NBViewer</a>
# <a target="_blank" href="https://github.com/Dans-labs/text-fabric/blob/master/search.ipynb">GitHub</a>
# <style>
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.tablet,.children.face {
#     flex-flow: row nowrap;
# }
# .children.column {
#     align-items: stretch;
#     flex-flow: column nowrap;
# }
# .children.line,.children.case {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.caseh,.children.trminalh {
#     flex-flow: row nowrap;
# }
# .children.casev,.children.trminalv {
#     flex-flow: column nowrap;
# }
# .children.trminal {
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.quad {
#     flex-flow: row wrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.tablet,.contnr.face,.contnr.column,
# .contnr.line,.contnr.case,.contnr.trminal,
# .contnr.comment,
# .contnr.cluster,
# .contnr.quad,.contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.tablet,.contnr.face,.contnr.column {
#     border-color: #bb8800;
# }
# .contnr.line,.contnr.case,.contnr.trminal {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.sign,.contnr.quad {
#     border-color: #bbbbbb;
# }
# .contnr.comment {
#     background-color: #ffddaa;
#     border: 0.2em solid #eecc99;
#     border-radius: 0.3em;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.tablet,.lbl.face,.lbl.column,
# .lbl.line,.lbl.case,.lbl.trminal,
# .lbl.comment,
# .lbl.cluster,
# .lbl.quad,.lbl.sign {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     color: #0000cc;
#     display: block;
# }
# .lbl.tablet,.lbl.face,.lbl.column {
#     border-color: #bb8800;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #bb8800;
# }
# .lbl.line,.lbl.case,.lbl.trminal {
#     border-color: #0088bb;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0088bb;
# }
# .lbl.comment {
#     border-color: #eecc99;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #eecc99;
#     background-color: #ffddaa none repeat scroll 0 0;
# }
# .lbl.clusterB,.lbl.clusterE {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     color: #888844;
#     font-size: x-small;
# }
# .lbl.clusterB {
#     border-left: 0.3em solid #cccc99;
#     border-right: 0;
#     border-top: 0;
#     border-bottom: 0;
#     border-radius: 1em;
# }
# .lbl.clusterE {
#     border-left: 0;
#     border-right: 0.3em solid #cccc99;
#     border-top: 0;
#     border-bottom: 0;
#     border-radius: 1em;
# }
# .lbl.quad,.lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     color: #bbbbbb;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .excavation {
#     font-family: monospace;
#     font-size: medium;
#     font-style: italic;
#     color: #779900;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcLn {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srcLnNum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# </style>

# %%
query = '''
tablet
/without/
  case
    sign type=numeral
/-/
/with/
  case
/-/
  sign type=numeral
'''
results = S.search(query, withContext='number kind type grapheme op sub repeat')
results = S.search(query, withContext=True)
# Out:
#   0.28s Cannot load feature "kind": not in dataset
# applying edge op hasValues=True
# applying edge sub hasValues=False

# %%
len(results[0])
# Out:
# 160

# %%
for (f, data) in results[1].items():
    print(f'{f} {len(data)} items')
# Out:
# catalogId 37 items
# crossref 0 items
# damage 33 items
# depth 0 items
# excavation 25 items
# fragment 0 items
# fullNumber 0 items
# grapheme 160 items
# identifier 0 items
# modifier 0 items
# modifierFirst 0 items
# modifierInner 0 items
# name 37 items
# number 0 items
# otype 197 items
# period 37 items
# prime 0 items
# remarkable 0 items
# repeat 160 items
# srcLn 37 items
# srcLnNum 37 items
# terminal 0 items
# text 0 items
# type 160 items
# uncertain 1 items
# variant 4 items
# variantOuter 0 items
# written 0 items
# oslots 197 items

# %%
results[1]
# Out:
# {'catalogId': {146967: 'P002756',
#   147994: 'P005206',
#   143900: 'P006438',
#   148030: 'P005242',
#   147039: 'P004033',
#   145054: 'P004969',
#   144592: 'P003718',
#   146646: 'P006416',
#   146647: 'P387750',
#   147163: 'P003580',
#   147188: 'P003646',
#   146680: 'P387744',
#   146173: 'P325736',
#   144640: 'P003820',
#   146701: 'P464171',
#   146198: 'P325073',
#   146709: 'P464179',
#   148252: 'P005472',
#   144692: 'P004461',
#   144698: 'P004473',
#   144191: 'P002082',
#   148740: 'P001195',
#   146767: 'P469727',
#   144221: 'P002120',
#   147809: 'P006304',
#   146804: 'P002265',
#   148362: 'P002843',
#   147866: 'P005077',
#   144807: 'P004694',
#   147385: 'P004331',
#   144827: 'P004712',
#   148434: 'P004478',
#   144859: 'P004752',
#   147936: 'P005147',
#   147431: 'P004433',
#   146925: 'P002741',
#   147441: 'P004506'},
#  'crossref': {},
#  'damage': {77825: 1,
#   49186: 1,
#   49188: 1,
#   49190: 1,
#   49192: 1,
#   15403: 1,
#   13888: 1,
#   49216: 1,
#   49224: 1,
#   5262: 1,
#   5266: 1,
#   5269: 1,
#   5272: 1,
#   66742: 1,
#   66746: 1,
#   66756: 1,
#   64251: 1,
#   15116: 1,
#   15122: 1,
#   15125: 1,
#   15129: 1,
#   15130: 1,
#   15134: 1,
#   96062: 1,
#   101702: 1,
#   101713: 1,
#   100706: 1,
#   13158: 1,
#   100710: 1,
#   100712: 1,
#   13163: 1,
#   93066: 1,
#   64460: 1},
#  'depth': {},
#  'excavation': {146967: 'W 17729,dz',
#   147994: 'Ashm 1926,720',
#   148030: 'Ashm 1926,600',
#   147039: 'W 20736,7',
#   145054: 'W 24238',
#   144592: 'W 20493,11',
#   147163: 'W 20274,082',
#   147188: 'W 20274,148',
#   144640: 'W 20511,15',
#   144692: 'W 21814',
#   144698: 'W 21880',
#   144191: 'W 14637',
#   148740: 'W 09312,t',
#   144221: 'W 14731,af',
#   146804: 'W 15771,i',
#   148362: 'W 17879,l',
#   144807: 'W 23973,10a',
#   147385: 'W 21241,2',
#   144827: 'W 23990,b',
#   148434: 'W 21913',
#   144859: 'W 24004,05',
#   147936: 'Ashm 1926,666',
#   147431: 'W 21663',
#   146925: 'W 17729,dk',
#   147441: 'W 22100,08'},
#  'fragment': {},
#  'fullNumber': {},
#  'grapheme': {77825: 'N01',
#   15394: 'N01',
#   49186: 'N01',
#   49188: 'N01',
#   15398: 'N01',
#   49190: 'N01',
#   15400: 'N58',
#   49192: 'N01',
#   15403: 'N01',
#   49198: 'N01',
#   49200: 'N01',
#   49202: 'N01',
#   13881: 'N01',
#   13888: 'N01',
#   49216: 'N01',
#   49218: 'N01',
#   49220: 'N01',
#   49224: 'N14',
#   70760: 'N04',
#   63594: 'N45',
#   63595: 'N14',
#   63596: 'N01',
#   63597: 'N57',
#   62062: 'N34',
#   62063: 'N14',
#   63601: 'N45',
#   62066: 'N34',
#   5747: 'N02',
#   63602: 'N14',
#   22646: 'N01',
#   63607: 'N14',
#   63608: 'N01',
#   22650: 'N01',
#   63610: 'N57',
#   22653: 'N01',
#   62077: 'N14',
#   62079: 'N14',
#   63613: 'N34',
#   22657: 'N01',
#   63614: 'N14',
#   63615: 'N01',
#   18052: 'N01',
#   5262: 'N01',
#   5266: 'N01',
#   5269: 'N14',
#   18070: 'N34',
#   18071: 'N14',
#   5272: 'N01',
#   18072: 'N01',
#   5275: 'N34',
#   66728: 'N14',
#   66729: 'N01',
#   66731: 'N14',
#   66732: 'N01',
#   66734: 'N14',
#   66735: 'N01',
#   66738: 'N01',
#   66742: 'N34',
#   66745: 'N14',
#   66746: 'N01',
#   111802: 'N01',
#   79038: 'N34',
#   111806: 'N57',
#   111808: 'N01',
#   17090: 'N34',
#   66754: 'N34',
#   66755: 'N14',
#   66756: 'N01',
#   17094: 'N01',
#   73922: 'N01',
#   73926: 'N01',
#   73929: 'N01',
#   111811: 'N01',
#   111817: 'N14',
#   111818: 'N01',
#   73933: 'N01',
#   111821: 'N01',
#   111824: 'N57',
#   111826: 'N01',
#   73940: 'N01',
#   111828: 'N02',
#   73942: 'N01',
#   73944: 'N01',
#   73946: 'N01',
#   73947: 'N57',
#   111831: 'N01',
#   73954: 'N14',
#   73955: 'N01',
#   115954: 'N01',
#   115958: 'N01',
#   64251: 'N14',
#   15107: 'N01',
#   15108: 'N39',
#   15109: 'N24',
#   15110: 'N26',
#   15111: 'N28',
#   15112: 'N01',
#   15113: 'N39',
#   15114: 'N24',
#   15115: 'N28',
#   15116: 'N01',
#   15117: 'N39',
#   15118: 'N26',
#   15119: 'N57',
#   15122: 'N14',
#   275: 'N01',
#   15125: 'N14',
#   15129: 'N34',
#   15130: 'N45',
#   15131: 'N14',
#   15132: 'N01',
#   15133: 'N39',
#   15134: 'N28',
#   74537: 'N14',
#   74539: 'N01',
#   74541: 'N01',
#   74544: 'N01',
#   74551: 'N01',
#   96061: 'N45',
#   96062: 'N14',
#   67392: 'N08',
#   101698: 'N01',
#   101701: 'N57',
#   101702: 'N01',
#   101705: 'N01',
#   96076: 'N50',
#   101709: 'N01',
#   101710: 'N08',
#   101713: 'N01',
#   101716: 'N01',
#   13150: 'N01',
#   13153: 'N01',
#   97634: 'N57',
#   100706: 'N14',
#   69989: 'N01',
#   13158: 'N14',
#   13159: 'N01',
#   100710: 'N34',
#   100712: 'N14',
#   13162: 'N14',
#   13163: 'N01',
#   93066: 'N01',
#   93068: 'N01',
#   50083: 'N04',
#   78757: 'N01',
#   78761: 'N01',
#   78763: 'N01',
#   78767: 'N01',
#   17332: 'N01',
#   78774: 'N01',
#   78783: 'N01',
#   78785: 'N01',
#   119748: 'N24',
#   64460: 'N14',
#   72154: 'N01',
#   72156: 'N01',
#   72158: 'N01',
#   72161: 'N01',
#   72163: 'N01',
#   110076: 'N01'},
#  'identifier': {},
#  'modifier': {},
#  'modifierFirst': {},
#  'modifierInner': {},
#  'name': {146967: 'IM 046038',
#   147994: 'MSVO 1, 139',
#   143900: 'AOST 109',
#   148030: 'MSVO 1, 175',
#   147039: 'IM 073497',
#   145054: 'BagM 22, 158, W 24238',
#   144592: 'ATU 7, pl. 062, W 20493,11',
#   146646: 'CUSAS 31, 077',
#   146647: 'CUSAS 31, 078',
#   147163: 'IM 134291',
#   147188: 'IM 134317',
#   146680: 'CUSAS 31, 111',
#   146173: 'CUSAS 01, 053',
#   144640: 'ATU 7, pl. 068, W 20511,15',
#   146701: 'CUSAS 31, 132',
#   146198: 'CUSAS 01, 078',
#   146709: 'CUSAS 31, 140',
#   148252: 'MSVO 4, 70',
#   144692: 'ATU 7, pl. 080, W 21814',
#   144698: 'ATU 7, pl. 081, W 21880',
#   144191: 'ATU 6, pl. 047, W 14637',
#   148740: 'ATU 5, pl. 052, W 9312,t',
#   146767: 'CUSAS 31, add198',
#   144221: 'ATU 6, pl. 051, W 14731,af',
#   147809: 'MS 4500',
#   146804: 'IM 023435,09',
#   148362: 'W 17879,l',
#   147866: 'MSVO 1, 010',
#   144807: 'BagM 22, 064, W 23973,10a',
#   147385: 'IM 134849',
#   144827: 'BagM 22, 068, W 23990,b',
#   148434: 'W 21913',
#   144859: 'BagM 22, 079, W 24004,5',
#   147936: 'MSVO 1, 080',
#   147431: 'IM 134949',
#   146925: 'IM 045991',
#   147441: 'IM 134971'},
#  'number': {},
#  'otype': {77825: 'sign',
#   146967: 'tablet',
#   147994: 'tablet',
#   143900: 'tablet',
#   15394: 'sign',
#   49186: 'sign',
#   49188: 'sign',
#   15398: 'sign',
#   49190: 'sign',
#   15400: 'sign',
#   49192: 'sign',
#   15403: 'sign',
#   49198: 'sign',
#   49200: 'sign',
#   49202: 'sign',
#   13881: 'sign',
#   148030: 'tablet',
#   13888: 'sign',
#   49216: 'sign',
#   49218: 'sign',
#   49220: 'sign',
#   49224: 'sign',
#   147039: 'tablet',
#   70760: 'sign',
#   63594: 'sign',
#   63595: 'sign',
#   63596: 'sign',
#   63597: 'sign',
#   62062: 'sign',
#   62063: 'sign',
#   63601: 'sign',
#   62066: 'sign',
#   5747: 'sign',
#   63602: 'sign',
#   22646: 'sign',
#   63607: 'sign',
#   63608: 'sign',
#   22650: 'sign',
#   63610: 'sign',
#   22653: 'sign',
#   62077: 'sign',
#   62079: 'sign',
#   63613: 'sign',
#   22657: 'sign',
#   63614: 'sign',
#   63615: 'sign',
#   18052: 'sign',
#   5262: 'sign',
#   5266: 'sign',
#   5269: 'sign',
#   18070: 'sign',
#   18071: 'sign',
#   5272: 'sign',
#   18072: 'sign',
#   5275: 'sign',
#   145054: 'tablet',
#   66728: 'sign',
#   66729: 'sign',
#   66731: 'sign',
#   66732: 'sign',
#   66734: 'sign',
#   66735: 'sign',
#   66738: 'sign',
#   66742: 'sign',
#   66745: 'sign',
#   66746: 'sign',
#   111802: 'sign',
#   79038: 'sign',
#   111806: 'sign',
#   111808: 'sign',
#   17090: 'sign',
#   66754: 'sign',
#   66755: 'sign',
#   66756: 'sign',
#   17094: 'sign',
#   73922: 'sign',
#   73926: 'sign',
#   73929: 'sign',
#   111811: 'sign',
#   111817: 'sign',
#   111818: 'sign',
#   73933: 'sign',
#   111821: 'sign',
#   144592: 'tablet',
#   111824: 'sign',
#   111826: 'sign',
#   73940: 'sign',
#   111828: 'sign',
#   146646: 'tablet',
#   146647: 'tablet',
#   73942: 'sign',
#   73944: 'sign',
#   73946: 'sign',
#   147163: 'tablet',
#   73947: 'sign',
#   111831: 'sign',
#   73954: 'sign',
#   73955: 'sign',
#   115954: 'sign',
#   147188: 'tablet',
#   115958: 'sign',
#   146680: 'tablet',
#   64251: 'sign',
#   146173: 'tablet',
#   144640: 'tablet',
#   15107: 'sign',
#   15108: 'sign',
#   15109: 'sign',
#   15110: 'sign',
#   15111: 'sign',
#   15112: 'sign',
#   15113: 'sign',
#   15114: 'sign',
#   15115: 'sign',
#   15116: 'sign',
#   15117: 'sign',
#   15118: 'sign',
#   15119: 'sign',
#   146701: 'tablet',
#   15122: 'sign',
#   275: 'sign',
#   15125: 'sign',
#   146198: 'tablet',
#   146709: 'tablet',
#   15129: 'sign',
#   15130: 'sign',
#   15131: 'sign',
#   15132: 'sign',
#   15133: 'sign',
#   15134: 'sign',
#   148252: 'tablet',
#   74537: 'sign',
#   74539: 'sign',
#   74541: 'sign',
#   74544: 'sign',
#   144692: 'tablet',
#   74551: 'sign',
#   144698: 'tablet',
#   96061: 'sign',
#   96062: 'sign',
#   144191: 'tablet',
#   67392: 'sign',
#   148740: 'tablet',
#   101698: 'sign',
#   101701: 'sign',
#   101702: 'sign',
#   101705: 'sign',
#   96076: 'sign',
#   101709: 'sign',
#   101710: 'sign',
#   146767: 'tablet',
#   101713: 'sign',
#   101716: 'sign',
#   144221: 'tablet',
#   13150: 'sign',
#   13153: 'sign',
#   147809: 'tablet',
#   97634: 'sign',
#   100706: 'sign',
#   69989: 'sign',
#   13158: 'sign',
#   13159: 'sign',
#   100710: 'sign',
#   100712: 'sign',
#   13162: 'sign',
#   13163: 'sign',
#   146804: 'tablet',
#   93066: 'sign',
#   148362: 'tablet',
#   93068: 'sign',
#   147866: 'tablet',
#   50083: 'sign',
#   78757: 'sign',
#   144807: 'tablet',
#   78761: 'sign',
#   78763: 'sign',
#   78767: 'sign',
#   17332: 'sign',
#   78774: 'sign',
#   147385: 'tablet',
#   144827: 'tablet',
#   78783: 'sign',
#   78785: 'sign',
#   119748: 'sign',
#   64460: 'sign',
#   148434: 'tablet',
#   72154: 'sign',
#   144859: 'tablet',
#   72156: 'sign',
#   72158: 'sign',
#   147936: 'tablet',
#   72161: 'sign',
#   72163: 'sign',
#   147431: 'tablet',
#   146925: 'tablet',
#   147441: 'tablet',
#   110076: 'sign'},
#  'period': {146967: 'uruk-iii',
#   147994: 'uruk-iii',
#   143900: 'uruk-iii',
#   148030: 'uruk-iii',
#   147039: 'uruk-iii',
#   145054: 'uruk-iii',
#   144592: 'uruk-iii',
#   146646: 'uruk-iii',
#   146647: 'uruk-iii',
#   147163: 'uruk-iii',
#   147188: 'uruk-iii',
#   146680: 'uruk-iii',
#   146173: 'uruk-iii',
#   144640: 'uruk-iii',
#   146701: 'uruk-iii',
#   146198: 'uruk-iii',
#   146709: 'uruk-iii',
#   148252: 'uruk-iii',
#   144692: 'uruk-iii',
#   144698: 'uruk-iii',
#   144191: 'uruk-iii',
#   148740: 'uruk-iv',
#   146767: 'uruk-iii',
#   144221: 'uruk-iii',
#   147809: 'uruk-iii',
#   146804: 'uruk-iii',
#   148362: 'uruk-iii',
#   147866: 'uruk-iii',
#   144807: 'uruk-iii',
#   147385: 'uruk-iii',
#   144827: 'uruk-iii',
#   148434: 'uruk-iii',
#   144859: 'uruk-iii',
#   147936: 'uruk-iii',
#   147431: 'uruk-iii',
#   146925: 'uruk-iii',
#   147441: 'uruk-iii'},
#  'prime': {},
#  'remarkable': {},
#  'repeat': {77825: 2,
#   15394: 1,
#   49186: 2,
#   49188: 2,
#   15398: 1,
#   49190: 2,
#   15400: 1,
#   49192: 5,
#   15403: 1,
#   49198: 1,
#   49200: 3,
#   49202: 5,
#   13881: 1,
#   13888: 1,
#   49216: 2,
#   49218: 2,
#   49220: 3,
#   49224: 2,
#   70760: 4,
#   63594: 2,
#   63595: 1,
#   63596: 3,
#   63597: 2,
#   62062: 6,
#   62063: 5,
#   63601: 2,
#   62066: 4,
#   5747: 1,
#   63602: 4,
#   22646: 1,
#   63607: 2,
#   63608: 2,
#   22650: 1,
#   63610: 3,
#   22653: 1,
#   62077: 1,
#   62079: 1,
#   63613: 1,
#   22657: 1,
#   63614: 7,
#   63615: 5,
#   18052: 2,
#   5262: 1,
#   5266: 2,
#   5269: 1,
#   18070: 5,
#   18071: 2,
#   5272: 1,
#   18072: 5,
#   5275: 1,
#   66728: 4,
#   66729: 5,
#   66731: 3,
#   66732: 3,
#   66734: 1,
#   66735: 7,
#   66738: 5,
#   66742: 1,
#   66745: 3,
#   66746: 8,
#   111802: 1,
#   79038: 1,
#   111806: 1,
#   111808: 1,
#   17090: 1,
#   66754: 1,
#   66755: 3,
#   66756: 8,
#   17094: 5,
#   73922: 6,
#   73926: 3,
#   73929: 3,
#   111811: 2,
#   111817: 2,
#   111818: 4,
#   73933: 3,
#   111821: 2,
#   111824: 1,
#   111826: 1,
#   73940: 1,
#   111828: 1,
#   73942: 1,
#   73944: 1,
#   73946: 1,
#   73947: 1,
#   111831: 2,
#   73954: 2,
#   73955: 7,
#   115954: 1,
#   115958: 1,
#   64251: 8,
#   15107: 2,
#   15108: 3,
#   15109: 1,
#   15110: 1,
#   15111: 1,
#   15112: 1,
#   15113: 1,
#   15114: 1,
#   15115: 1,
#   15116: 4,
#   15117: 2,
#   15118: 1,
#   15119: 3,
#   15122: 2,
#   275: 1,
#   15125: 2,
#   15129: 1,
#   15130: 2,
#   15131: 7,
#   15132: 4,
#   15133: 1,
#   15134: 1,
#   74537: 1,
#   74539: 6,
#   74541: 2,
#   74544: 3,
#   74551: 3,
#   96061: 2,
#   96062: 5,
#   67392: 1,
#   101698: 1,
#   101701: 1,
#   101702: 4,
#   101705: 1,
#   96076: 1,
#   101709: 2,
#   101710: 1,
#   101713: 4,
#   101716: 2,
#   13150: 1,
#   13153: 3,
#   97634: 2,
#   100706: 1,
#   69989: 1,
#   13158: 3,
#   13159: 1,
#   100710: 1,
#   100712: 2,
#   13162: 5,
#   13163: 2,
#   93066: 1,
#   93068: 8,
#   50083: 2,
#   78757: 1,
#   78761: 1,
#   78763: 1,
#   78767: 1,
#   17332: 1,
#   78774: 1,
#   78783: 1,
#   78785: 1,
#   119748: 1,
#   64460: 1,
#   72154: 3,
#   72156: 7,
#   72158: 3,
#   72161: 3,
#   72163: 5,
#   110076: 1},
#  'srcLn': {146967: '&P002756 = IM 046038',
#   147994: '&P005206 = MSVO 1, 139',
#   143900: '&P006438 = AOST 109',
#   148030: '&P005242 = MSVO 1, 175',
#   147039: '&P004033 = IM 073497',
#   145054: '&P004969 = BagM 22, 158, W 24238',
#   144592: '&P003718 = ATU 7, pl. 062, W 20493,11',
#   146646: '&P006416 = CUSAS 31, 077',
#   146647: '&P387750 = CUSAS 31, 078',
#   147163: '&P003580 = IM 134291',
#   147188: '&P003646 = IM 134317',
#   146680: '&P387744 = CUSAS 31, 111',
#   146173: '&P325736 = CUSAS 01, 053',
#   144640: '&P003820 = ATU 7, pl. 068, W 20511,15',
#   146701: '&P464171 = CUSAS 31, 132',
#   146198: '&P325073 = CUSAS 01, 078',
#   146709: '&P464179 = CUSAS 31, 140',
#   148252: '&P005472 = MSVO 4, 70',
#   144692: '&P004461 = ATU 7, pl. 080, W 21814',
#   144698: '&P004473 = ATU 7, pl. 081, W 21880',
#   144191: '&P002082 = ATU 6, pl. 047, W 14637',
#   148740: '&P001195 = ATU 5, pl. 052, W 9312,t',
#   146767: '&P469727 = CUSAS 31, add198',
#   144221: '&P002120 = ATU 6, pl. 051, W 14731,af',
#   147809: '&P006304 = MS 4500',
#   146804: '&P002265 = IM 023435,09',
#   148362: '&P002843 = W 17879,l',
#   147866: '&P005077 = MSVO 1, 010',
#   144807: '&P004694 = BagM 22, 064, W 23973,10a',
#   147385: '&P004331 = IM 134849',
#   144827: '&P004712 = BagM 22, 068, W 23990,b',
#   148434: '&P004478 = W 21913',
#   144859: '&P004752 = BagM 22, 079, W 24004,5',
#   147936: '&P005147 = MSVO 1, 080',
#   147431: '&P004433 = IM 134949',
#   146925: '&P002741 = IM 045991',
#   147441: '&P004506 = IM 134971'},
#  'srcLnNum': {146967: 61676,
#   147994: 81664,
#   143900: 210,
#   148030: 82355,
#   147039: 62751,
#   145054: 17625,
#   144592: 10528,
#   146646: 55856,
#   146647: 55869,
#   147163: 64334,
#   147188: 64784,
#   146680: 56707,
#   146173: 46698,
#   144640: 11169,
#   146701: 57158,
#   146198: 47273,
#   146709: 57310,
#   148252: 87040,
#   144692: 12029,
#   144698: 12177,
#   144191: 4462,
#   148740: 3913,
#   146767: 58677,
#   144221: 4888,
#   147809: 77148,
#   146804: 59193,
#   148362: 88516,
#   147866: 78826,
#   144807: 13696,
#   147385: 67540,
#   144827: 13944,
#   148434: 90510,
#   144859: 14472,
#   147936: 79935,
#   147431: 68264,
#   146925: 61083,
#   147441: 68459},
#  'terminal': {},
#  'text': {},
#  'type': {77825: 'numeral',
#   15394: 'numeral',
#   49186: 'numeral',
#   49188: 'numeral',
#   15398: 'numeral',
#   49190: 'numeral',
#   15400: 'numeral',
#   49192: 'numeral',
#   15403: 'numeral',
#   49198: 'numeral',
#   49200: 'numeral',
#   49202: 'numeral',
#   13881: 'numeral',
#   13888: 'numeral',
#   49216: 'numeral',
#   49218: 'numeral',
#   49220: 'numeral',
#   49224: 'numeral',
#   70760: 'numeral',
#   63594: 'numeral',
#   63595: 'numeral',
#   63596: 'numeral',
#   63597: 'numeral',
#   62062: 'numeral',
#   62063: 'numeral',
#   63601: 'numeral',
#   62066: 'numeral',
#   5747: 'numeral',
#   63602: 'numeral',
#   22646: 'numeral',
#   63607: 'numeral',
#   63608: 'numeral',
#   22650: 'numeral',
#   63610: 'numeral',
#   22653: 'numeral',
#   62077: 'numeral',
#   62079: 'numeral',
#   63613: 'numeral',
#   22657: 'numeral',
#   63614: 'numeral',
#   63615: 'numeral',
#   18052: 'numeral',
#   5262: 'numeral',
#   5266: 'numeral',
#   5269: 'numeral',
#   18070: 'numeral',
#   18071: 'numeral',
#   5272: 'numeral',
#   18072: 'numeral',
#   5275: 'numeral',
#   66728: 'numeral',
#   66729: 'numeral',
#   66731: 'numeral',
#   66732: 'numeral',
#   66734: 'numeral',
#   66735: 'numeral',
#   66738: 'numeral',
#   66742: 'numeral',
#   66745: 'numeral',
#   66746: 'numeral',
#   111802: 'numeral',
#   79038: 'numeral',
#   111806: 'numeral',
#   111808: 'numeral',
#   17090: 'numeral',
#   66754: 'numeral',
#   66755: 'numeral',
#   66756: 'numeral',
#   17094: 'numeral',
#   73922: 'numeral',
#   73926: 'numeral',
#   73929: 'numeral',
#   111811: 'numeral',
#   111817: 'numeral',
#   111818: 'numeral',
#   73933: 'numeral',
#   111821: 'numeral',
#   111824: 'numeral',
#   111826: 'numeral',
#   73940: 'numeral',
#   111828: 'numeral',
#   73942: 'numeral',
#   73944: 'numeral',
#   73946: 'numeral',
#   73947: 'numeral',
#   111831: 'numeral',
#   73954: 'numeral',
#   73955: 'numeral',
#   115954: 'numeral',
#   115958: 'numeral',
#   64251: 'numeral',
#   15107: 'numeral',
#   15108: 'numeral',
#   15109: 'numeral',
#   15110: 'numeral',
#   15111: 'numeral',
#   15112: 'numeral',
#   15113: 'numeral',
#   15114: 'numeral',
#   15115: 'numeral',
#   15116: 'numeral',
#   15117: 'numeral',
#   15118: 'numeral',
#   15119: 'numeral',
#   15122: 'numeral',
#   275: 'numeral',
#   15125: 'numeral',
#   15129: 'numeral',
#   15130: 'numeral',
#   15131: 'numeral',
#   15132: 'numeral',
#   15133: 'numeral',
#   15134: 'numeral',
#   74537: 'numeral',
#   74539: 'numeral',
#   74541: 'numeral',
#   74544: 'numeral',
#   74551: 'numeral',
#   96061: 'numeral',
#   96062: 'numeral',
#   67392: 'numeral',
#   101698: 'numeral',
#   101701: 'numeral',
#   101702: 'numeral',
#   101705: 'numeral',
#   96076: 'numeral',
#   101709: 'numeral',
#   101710: 'numeral',
#   101713: 'numeral',
#   101716: 'numeral',
#   13150: 'numeral',
#   13153: 'numeral',
#   97634: 'numeral',
#   100706: 'numeral',
#   69989: 'numeral',
#   13158: 'numeral',
#   13159: 'numeral',
#   100710: 'numeral',
#   100712: 'numeral',
#   13162: 'numeral',
#   13163: 'numeral',
#   93066: 'numeral',
#   93068: 'numeral',
#   50083: 'numeral',
#   78757: 'numeral',
#   78761: 'numeral',
#   78763: 'numeral',
#   78767: 'numeral',
#   17332: 'numeral',
#   78774: 'numeral',
#   78783: 'numeral',
#   78785: 'numeral',
#   119748: 'numeral',
#   64460: 'numeral',
#   72154: 'numeral',
#   72156: 'numeral',
#   72158: 'numeral',
#   72161: 'numeral',
#   72163: 'numeral',
#   110076: 'numeral'},
#  'uncertain': {70760: 1},
#  'variant': {15108: 'a', 15113: 'a', 15117: 'a', 15133: 'a'},
#  'variantOuter': {},
#  'written': {},
#  'oslots': {77825: (77825,),
#   146967: (70760,),
#   147994: (100706, 100710, 100712),
#   143900: (275,),
#   15394: (15394,),
#   49186: (49186,),
#   49188: (49188,),
#   15398: (15398,),
#   49190: (49190,),
#   15400: (15400,),
#   49192: (49192,),
#   15403: (15403,),
#   49198: (49198,),
#   49200: (49200,),
#   49202: (49202,),
#   13881: (13881,),
#   148030: (101698, 101701, 101702, 101705, 101709, 101710, 101713, 101716),
#   13888: (13888,),
#   49216: (49216,),
#   49218: (49218,),
#   49220: (49220,),
#   49224: (49224,),
#   147039: (72154, 72156, 72158, 72161, 72163),
#   70760: (70760,),
#   63594: (63594,),
#   63595: (63595,),
#   63596: (63596,),
#   63597: (63597,),
#   62062: (62062,),
#   62063: (62063,),
#   63601: (63601,),
#   62066: (62066,),
#   5747: (5747,),
#   63602: (63602,),
#   22646: (22646,),
#   63607: (63607,),
#   63608: (63608,),
#   22650: (22650,),
#   63610: (63610,),
#   22653: (22653,),
#   62077: (62077,),
#   62079: (62079,),
#   63613: (63613,),
#   22657: (22657,),
#   63614: (63614,),
#   63615: (63615,),
#   18052: (18052,),
#   5262: (5262,),
#   5266: (5266,),
#   5269: (5269,),
#   18070: (18070,),
#   18071: (18071,),
#   5272: (5272,),
#   18072: (18072,),
#   5275: (5275,),
#   145054: (22646, 22650, 22653, 22657),
#   66728: (66728,),
#   66729: (66729,),
#   66731: (66731,),
#   66732: (66732,),
#   66734: (66734,),
#   66735: (66735,),
#   66738: (66738,),
#   66742: (66742,),
#   66745: (66745,),
#   66746: (66746,),
#   111802: (111802,),
#   79038: (79038,),
#   111806: (111806,),
#   111808: (111808,),
#   17090: (17090,),
#   66754: (66754,),
#   66755: (66755,),
#   66756: (66756,),
#   17094: (17094,),
#   73922: (73922,),
#   73926: (73926,),
#   73929: (73929,),
#   111811: (111811,),
#   111817: (111817,),
#   111818: (111818,),
#   73933: (73933,),
#   111821: (111821,),
#   144592: (13150, 13153, 13158, 13159, 13162, 13163),
#   111824: (111824,),
#   111826: (111826,),
#   73940: (73940,),
#   111828: (111828,),
#   146646: (62062, 62063, 62066),
#   146647: (62077, 62079),
#   73942: (73942,),
#   73944: (73944,),
#   73946: (73946,),
#   147163: (73922,
#    73926,
#    73929,
#    73933,
#    73940,
#    73942,
#    73944,
#    73946,
#    73947,
#    73954,
#    73955),
#   73947: (73947,),
#   111831: (111831,),
#   73954: (73954,),
#   73955: (73955,),
#   115954: (115954,),
#   147188: (74537, 74539, 74541, 74544, 74551),
#   115958: (115958,),
#   146680: (63594,
#    63595,
#    63596,
#    63597,
#    63601,
#    63602,
#    63607,
#    63608,
#    63610,
#    63613,
#    63614,
#    63615),
#   64251: (64251,),
#   146173: (49186,
#    49188,
#    49190,
#    49192,
#    49198,
#    49200,
#    49202,
#    49216,
#    49218,
#    49220,
#    49224),
#   144640: (13881, 13888),
#   15107: (15107,),
#   15108: (15108,),
#   15109: (15109,),
#   15110: (15110,),
#   15111: (15111,),
#   15112: (15112,),
#   15113: (15113,),
#   15114: (15114,),
#   15115: (15115,),
#   15116: (15116,),
#   15117: (15117,),
#   15118: (15118,),
#   15119: (15119,),
#   146701: (64251,),
#   15122: (15122,),
#   275: (275,),
#   15125: (15125,),
#   146198: (50083,),
#   146709: (64460,),
#   15129: (15129,),
#   15130: (15130,),
#   15131: (15131,),
#   15132: (15132,),
#   15133: (15133,),
#   15134: (15134,),
#   148252: (110076,),
#   74537: (74537,),
#   74539: (74539,),
#   74541: (74541,),
#   74544: (74544,),
#   144692: (15107,
#    15108,
#    15109,
#    15110,
#    15111,
#    15112,
#    15113,
#    15114,
#    15115,
#    15116,
#    15117,
#    15118,
#    15119,
#    15122,
#    15125,
#    15129,
#    15130,
#    15131,
#    15132,
#    15133,
#    15134),
#   74551: (74551,),
#   144698: (15394, 15398, 15400, 15403),
#   96061: (96061,),
#   96062: (96062,),
#   144191: (5262, 5266, 5269, 5272, 5275),
#   67392: (67392,),
#   148740: (119748,),
#   101698: (101698,),
#   101701: (101701,),
#   101702: (101702,),
#   101705: (101705,),
#   96076: (96076,),
#   101709: (101709,),
#   101710: (101710,),
#   146767: (66728,
#    66729,
#    66731,
#    66732,
#    66734,
#    66735,
#    66738,
#    66742,
#    66745,
#    66746,
#    66754,
#    66755,
#    66756),
#   101713: (101713,),
#   101716: (101716,),
#   144221: (5747,),
#   13150: (13150,),
#   13153: (13153,),
#   147809: (93066, 93068),
#   97634: (97634,),
#   100706: (100706,),
#   69989: (69989,),
#   13158: (13158,),
#   13159: (13159,),
#   100710: (100710,),
#   100712: (100712,),
#   13162: (13162,),
#   13163: (13163,),
#   146804: (67392,),
#   93066: (93066,),
#   148362: (111802,
#    111806,
#    111808,
#    111811,
#    111817,
#    111818,
#    111821,
#    111824,
#    111826,
#    111828,
#    111831),
#   93068: (93068,),
#   147866: (96061, 96062, 96076),
#   50083: (50083,),
#   78757: (78757,),
#   144807: (17090, 17094),
#   78761: (78761,),
#   78763: (78763,),
#   78767: (78767,),
#   17332: (17332,),
#   78774: (78774,),
#   147385: (77825,),
#   144827: (17332,),
#   78783: (78783,),
#   78785: (78785,),
#   119748: (119748,),
#   64460: (64460,),
#   148434: (115954, 115958),
#   72154: (72154,),
#   144859: (18052, 18070, 18071, 18072),
#   72156: (72156,),
#   72158: (72158,),
#   147936: (97634,),
#   72161: (72161,),
#   72163: (72163,),
#   147431: (78757, 78761, 78763, 78767, 78774, 78783, 78785),
#   146925: (69989,),
#   147441: (79038,),
#   110076: (110076,)}}

# %% [markdown]
# ## Finding a tablet
#
# Suppose we have the *p-number* of a tablet.
# How do we find that tablet?
# Remembering from the feature docs that the p-numbers are stored in the feature
# `catalogId`, we can write a *search template*.

# %%
query = '''
tablet catalogId=P005381
'''
results = CN.search(query)
CN.table(results)
# Out:
# 1 result
# n | tablet
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381</a>

# %% [markdown]
# The function `CN.table()` gives you a tabular overview of the results,
# with a link to the tablet on CDLI.
#
# But we can also get more information by using `CN.show()`:

# %%
CN.show(results)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAL</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TUR3~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUR3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tur3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N19)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|GISZ.TE|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qgisz(d)teq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GISZ</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TE</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAR</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nar.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig7.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <sp

# %% [markdown]
# Several things to note here
#
# * if you want to see the tablet on CDLI, you can click on the tablet header;
# * the display matches the layout on the tablet:
#   * faces and columns are delineated with red lines
#   * lines and cases are delineated with blue lines
#   * cases and subcases alternate their direction of division between horizontal and vertical:
#     lines are horizontally divided into cases, they are vertically divided into subcases, and they
#     in turn are horizontally divided in subsubcases, etc.
#   * quads and signs are delineated with grey lines
#   * clusters are delineated with brown lines (see further on)
#   * lineart is given for top-level signs and quads; those that are part of a bigger quad do not
#     get lineart;
#
# It is possible to switch off the lineart.

# %% [markdown]
# ## More info in the results
# You can show the line numbers that correspond to the ATF source files as well.
# Let us also switch off the lineart.

# %%
query = '''
tablet catalogId=P005381
'''
results = CN.search(query)
CN.table(results, lineNumbers=True)
CN.show(results, lineNumbers=True, lineart=False)
# Out:
# 1 result
# n | tablet
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381</a> @85111
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="srcLnNum">85116</span></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAL</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TUR3~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="srcLnNum">85117</span></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N19)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GISZ</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TE</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="srcLnNum">85118</span></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAR</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="srcLnNum">85119</span></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N04)#</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PIRIG~b1</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">URI3~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="srcLnNum">85121</span></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N04)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GISZ</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TE</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GAR</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZU2</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">HI</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">+</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N57)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="op">+</div>
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="

# %% [markdown]
# There is a big quad in `obverse:2 line 1`. We want to call up the lineart for it separately.
# First step: make the nodes visible.

# %%
query = '''
tablet catalogId=P005381
'''
results = CN.search(query)
CN.table(results, withNodes=True)
CN.show(results, withNodes=True, lineart=False)
# Out:
# 1 result
# n | tablet
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381</a> *148166*
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span></a>
#         <span class="nd">148166</span>
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#         <span class="nd">178162</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#         <span class="nd">156932</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#         <span class="nd">190362</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#         <span class="nd">254173</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#         <span class="nd">167736</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106585</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106586</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106587</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SAL</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106588</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">TUR3~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106589</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#         <span class="nd">167737</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106590</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">3(N19)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="lbl quad">
#
#         <span class="nd">143013</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106591</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GISZ</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106592</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">TE</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#         <span class="nd">254174</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106593</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106594</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">NAR</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106595</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106596</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#         <span class="nd">254175</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106597</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">2(N04)#</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106598</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">PIRIG~b1</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106599</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106600</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">URI3~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106601</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#         <span class="nd">190363</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#         <span class="nd">254176</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">106602</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">3(N04)</sp

# %% [markdown]
# We read off the node number of that quad and fetch the lineart.

# %%
CN.lineart(143015)
# Out:
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|SZU2.((HI+1(N57))+(HI+1(N57)))|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qszu2(d)((hi(p)1(n57))(p)(hi(p)1(n57)))q.jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">|SZU2.((HI+1(N57))+(HI+1(N57)))|</a></div></div></div></div>

# %% [markdown]
# ## Search templates
# Let's highlight all numerals on the tablet.

# %%
query = '''
tablet catalogId=P005381
  sign type=numeral
'''
results = CN.search(query)
CN.show(results)
# Out:
# 10 results
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P005381" title="to CDLI main page for this tablet">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAL</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TUR3~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUR3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tur3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N19)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|GISZ.TE|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qgisz(d)teq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GISZ</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">.</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TE</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAR</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nar.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SIG7</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig7.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PIRIG~b1</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/Sign

# %% [markdown]
# We can do the same for multiple tablets. But now we highlight the undivided lines,
# just for variation.

# %%
query = f'''
tablet catalogId=P003581|P000311
    line terminal
'''
results = CN.search(query)
CN.table(results)
CN.show(results, lineart=False)
# Out:
# 11 results
# n | tablet | line
# --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 1
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 2
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 1
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 2
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 3
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311</a>|line 1
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581</a>|line 1
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581</a>|line 2
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581</a>|line 2
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581</a>|line 1
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581</a>|line 2
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000311" title="to CDLI main page for this tablet">tablet P000311  <span class="name">CDLI Lexical 000034, ex. 01</span> <span class="period">uruk-iii</span> <span class="excavation">W 20266,065</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1'
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">IR~a#</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">ERIM2#</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2'
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NIMGIR</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SIG7#</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U2~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAGA~a</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">MUSZEN</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">ZATU647</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">rest broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)#</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">IM~a</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         reverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         0
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="con
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003581" title="to CDLI main page for this tablet">tablet P003581  <span class="name">W 20274,083</span> <span class="period">uruk-iii</span> <span class="excavation">W 20274,083</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">5(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U2~a#</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr case" style="background-color: None;">
#
#     <div class="lbl case">
#         1b
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children casev">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalh">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalh">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">I</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU3</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         3
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GA~a#</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB2</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr s

# %% [markdown]
# In an other chapter of this tutorial, [steps](steps.ipynb) we encounter a grapheme with a double prime.
# There is only one, and we showed the tablet on which it occurs, without highlighting the grapheme in question.
# Now we can do the highlight:

# %%
CN.show(CN.search('''
sign prime=2
'''))
# Out:
# 1 result
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411604" title="to CDLI main page for this tablet">tablet P411604  <span class="name">CUSAS 21, 074</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AN</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/AN.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-an.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUNUZ~a1</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUNUZ~a1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nunuz-a1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">ZATU788#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU788.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu788.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N39~a)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N39~a).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n39-a).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">MUD</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/MUD.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-mud.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NA~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-na-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N39~a)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N39~a).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n39-a).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KU6~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">A</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/A.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal"

# %% [markdown]
# ## Search for spatial patterns
# A few words on the construction of search templates.
#
# The idea is that you mimick the things you are looking for
# in your search template.
# Embedded things are mimicked by indentation.
#
# Let's search for a line with a case in it that is not further divided,
# in which there is a numeral and an ideograph.
#
# Here is our first attempt, and we show the first tablet only.
# Note that you can have comments in a search template.
# Lines that start with `#` are ignored.

# %%
query = '''
line
    case terminal=1
# order is not important
        sign type=ideograph
        sign type=numeral
'''
results = CN.search(query)
# Out:
# 10673 results

# %% [markdown]
# First a glance at the first 20 items in tabular view.

# %%
CN.table(results, end=20)
# Out:
# n | line | case | sign | sign
# --- | --- | --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|KASZ~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|N
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|KASZ~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|2(N14) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|KASZ~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|NUN~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|N
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|NUN~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|2(N14) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2a|NUN~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2b|KASZ~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">line 2</a>|case 2b|GI <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GI.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gi.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 1</a>|case 1a|APIN~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/APIN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-apin-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 1</a>|case 1a|APIN~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/APIN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-apin-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N57) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 1</a>|case 1a|UR4~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR4~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur4-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 1</a>|case 1a|UR4~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR4~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur4-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N57) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 2</a>|case 2b1|PAP~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PAP~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pap-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N57) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">line 1</a>|case 1a|ISZ~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ISZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-isz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|1(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 1</a>|case 1a|SZE~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|1(N14) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 1</a>|case 1b|TAR~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TAR~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tar-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|N
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 2</a>|case 2a|SZE~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 2</a>|case 2a|SZE~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 2</a>|case 2a|KASZ~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">line 2</a>|case 2a|KASZ~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>|3(N01) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>

# %% [markdown]
# Now the results on the first tablet.

# %%
CN.show(results, end=1)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ka-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line hl">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GI.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gi.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/6(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-6(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None

# %% [markdown]
# The order between the two signs is not defined by the template,
# despite the fact that the line with the ideograph
# precedes the line with the numeral.
# Results may have the numeral and the ideograph in any order.
#
# In fact, the highlights above represent multiple results.
# If a case has say 2 numerals and 3 ideographs, there are 6 possible
# pairs.
#
# By default, results are shown in *condensed* mode.
# That means that results are shown per tablet, and on the result tablets
# everything that is in some result is being highlighted.
#
# It is also possible to see the uncondensed results.
# That gives you an exact picture of each real result constellation.
#
# In order to illustrate the difference, we focus on one tablet and one case.
# This case has 3 numerals and 2 ideographs, so we expect 6 results.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
        sign type=ideograph
        sign type=numeral
'''
results = CN.search(query)
# Out:
# 6 results

# %% [markdown]
# We show them condensed (by default), so we expect 1 tablet with all ideographs and numerals in case `2a'` highlighted.

# %%
CN.show(results, lineart=False)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line hl">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAG</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color:

# %% [markdown]
# Now the same results in uncondensed mode. Expect 6 times the same tablet with
# different highlighted pairs of signs.
#
# Note that we can apply different highlight colors to different parts of the result.
# The words in the pair are member 4 and 5.
#
# The members that we do not map, will not be highlighted.
# The members that we map to the empty string will be highlighted with the default color.
#
# **NB:** Choose your colors from the
# [CSS specification](https://developer.mozilla.org/en-US/docs/Web/CSS/color_value).

# %%
CN.show(results, condensed=False, colorMap={3: '', 4: 'cyan', 5: 'magenta'}, lineart=False)
# Out:
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl
# ##### Result 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl
# ##### Result 3
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl
# ##### Result 4
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl
# ##### Result 5
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl
# ##### Result 6
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" styl

# %% [markdown]
# Color mapping works best for uncondensed results. If you condense results, some nodes may occupy
# different positions in different results. It is unpredictable which color will be used
# for such nodes:

# %%
CN.show(results, condensed=True, colorMap={3: '', 4: 'cyan', 5: 'magenta'}, lineart=False)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign

# %% [markdown]
# You can enforce order.
# We modify the template a little to state a
# relational condition, namely that the ideograph follows the numeral.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
        sign type=ideograph
        > sign type=numeral
'''
results = CN.search(query)
CN.table(results, lineart=False)
# Out:
# 6 results
# n | tablet | line | case | sign | sign
# --- | --- | --- | --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|KASZ~b|N
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|KASZ~b|2(N14)
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|KASZ~b|3(N01)
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|NUN~a|N
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|NUN~a|2(N14)
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|NUN~a|3(N01)

# %% [markdown]
# Still six results.
# No wonder, because the case has first three numerals in a row and then 2 ideographs.
#
# Do you want the ideograph and the numeral to be *adjacent* as well?
# We only have to add 1 character to the template to make it happen.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
        sign type=ideograph
        :> sign type=numeral
'''
results = CN.search(query)
CN.table(results, lineart=False)
CN.show(results, colorMap={4: 'cyan', 5: 'magenta'}, lineart=False)
# Out:
# 1 result
# n | tablet | line | case | sign | sign
# --- | --- | --- | --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|line 2|case 2a|KASZ~b|3(N01)
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702  <span class="name">Anonymous 448702</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KA~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2a'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: magenta;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: cyan;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~b</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~a?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">N</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">6(N14)#?</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N01)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N39~a)</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
#
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">blank space</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">U4</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# By now it pays off to study the possibilities of the
# [search template](https://dans-labs.github.io/text-fabric/Api/General/#search-templates).
#
# If you want a reminder of all possible spatial relationships between nodes, you can call it up
# here in your notebook:

# %%
S.relationsLegend()
# Out:
#                       = left equal to right (as node)
#                       # left unequal to right (as node)
#                       < left before right (in canonical node ordering)
#                       > left after right (in canonical node ordering)
#                      == left occupies same slots as right
#                      && left has overlapping slots with right
#                      ## left and right do not have the same slot set
#                      || left and right do not have common slots
#                      [[ left embeds right
#                      ]] left embedded in right
#                      << left completely before right
#                      >> left completely after right
#                      =: left and right start at the same slot
#                      := left and right end at the same slot
#                      :: left and right start and end at the same slot
#                      <: left immediately before right
#                      :> left immediately after right
#                     =k: left and right start at k-nearly the same slot
#                     :k= left and right end at k-nearly the same slot
#                     :k: left and right start and end at k-near slots
#                     <k: left k-nearly before right
#                     :k> left k-nearly after right
#              -comments> edge feature "comments"
#              <comments- edge feature "comments" (opposite direction)
#                    -op> edge feature "op" with value specification allowed
#                    <op- edge feature "op" with value specification allowed (opposite direction)
#                   -sub> edge feature "sub"
#                   <sub- edge feature "sub" (opposite direction)
# The warp feature "oslots" cannot be used in searches.
# One of the above relations on nodes and/or slots will suit you better!

# %% [markdown]
# ## Comparisons in templates: cases
#
# Cases have a feature depth which indicate their nesting depth within a line.
# It is not the depth *of* that case, but the depth *at* which that case occurs.
#
# Comparison queries are handy to select cases of a certain minimum or maximum depth.

# %%
query = '''
case depth=3
'''
results = CN.search(query)
CN.table(results, end=20)
# Out:
# 254 results
# n | case
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003357" title="to CDLI main page for this tablet">case 1b1A</a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003357" title="to CDLI main page for this tablet">case 1b1B</a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003537" title="to CDLI main page for this tablet">case 4b1A</a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003537" title="to CDLI main page for this tablet">case 4b1B</a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003537" title="to CDLI main page for this tablet">case 4b2A</a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003537" title="to CDLI main page for this tablet">case 4b2B</a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003589" title="to CDLI main page for this tablet">case 3b2A</a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003589" title="to CDLI main page for this tablet">case 3b2B</a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003822" title="to CDLI main page for this tablet">case 1a2A</a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003822" title="to CDLI main page for this tablet">case 1a2B</a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003822" title="to CDLI main page for this tablet">case 1b2A</a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003822" title="to CDLI main page for this tablet">case 1b2B</a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 1a2A</a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 1a2B</a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 1b2A</a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 1b2B</a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 2a2A</a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 2a2B</a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 2b2A</a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004448" title="to CDLI main page for this tablet">case 2b2B</a>

# %% [markdown]
# Are there deeper cases?

# %%
query = '''
case depth>3
'''
results = CN.search(query)
CN.table(results, end=20)
# Out:
# 119 results
# n | case
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B1</a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B2</a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B3</a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B4</a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 2b2B1</a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 2b2B2</a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P218054" title="to CDLI main page for this tablet">case 1a1A1</a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P218054" title="to CDLI main page for this tablet">case 1a1A2</a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b1</a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b2</a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b3</a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325234" title="to CDLI main page for this tablet">case 1c5a1</a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325234" title="to CDLI main page for this tablet">case 1c5a2</a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2a1</a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2a2</a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2b1</a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2b2</a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b01</a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b02</a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b03</a>

# %% [markdown]
# Still deeper?

# %%
query = '''
case depth>4
'''
results = CN.search(query)
CN.table(results, end=20)
# Out:
# 0 results

# %% [markdown]
# As a check: the cases with depth 4 should be exactly the cases with depth > 3:

# %%
query = '''
case depth=4
'''
results = CN.search(query)
CN.table(results, end=20)
tc4 = len(results)
# Out:
# 119 results
# n | case
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B1</a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B2</a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B3</a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 1b1B4</a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 2b2B1</a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004735" title="to CDLI main page for this tablet">case 2b2B2</a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P218054" title="to CDLI main page for this tablet">case 1a1A1</a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P218054" title="to CDLI main page for this tablet">case 1a1A2</a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b1</a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b2</a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325754" title="to CDLI main page for this tablet">case 1c2b3</a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325234" title="to CDLI main page for this tablet">case 1c5a1</a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P325234" title="to CDLI main page for this tablet">case 1c5a2</a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2a1</a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2a2</a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2b1</a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P411608" title="to CDLI main page for this tablet">case 1b2b2</a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b01</a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b02</a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P387752" title="to CDLI main page for this tablet">case 1b1b03</a>

# %% [markdown]
# Terminal cases at depth 1 are top-level divisions of lines that are not themselves divided further.

# %%
query = '''
case depth=1 terminal
'''
results = CN.search(query)
CN.table(results, end=20)
tc1 = len(results)
# Out:
# 5468 results
# n | case
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">case 2a</a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">case 2b</a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 1a</a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 2a</a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 1a</a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 1a</a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 1b</a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 2a</a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 2b</a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2a</a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2b</a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2c</a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2d</a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000735" title="to CDLI main page for this tablet">case 1a</a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000735" title="to CDLI main page for this tablet">case 1b</a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000743" title="to CDLI main page for this tablet">case 1b</a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000759" title="to CDLI main page for this tablet">case 1b</a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 1a</a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 1b</a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 2c</a>

# %% [markdown]
# Now let us select both the terminal cases of level 1 and 4.
# They are disjunct, so the amounts should add up.

# %%
query = '''
case depth=1|4 terminal
'''
results = CN.search(query)
CN.table(results, end=20)
tc14 = len(results)
print(f'{tc1} + {tc4} = {tc1 + tc4} = {tc14}')
# Out:
# 5587 results
# n | case
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">case 2a</a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">case 2b</a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 1a</a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 2a</a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">case 1a</a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 1a</a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 1b</a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 2a</a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">case 2b</a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2a</a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2b</a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2c</a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">case 2d</a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000735" title="to CDLI main page for this tablet">case 1a</a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000735" title="to CDLI main page for this tablet">case 1b</a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000743" title="to CDLI main page for this tablet">case 1b</a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000759" title="to CDLI main page for this tablet">case 1b</a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 1a</a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 1b</a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000760" title="to CDLI main page for this tablet">case 2c</a>
# 5468 + 119 = 5587 = 5587

# %% [markdown]
# ## Relational patterns: quads
#
# Quads are compositions of signs by means of *operators*, such as `.` and `x`.
# The operators are coded as an *edge* feature with values. The `op`-edges are between the signs/quads that are combined,
# and the values of the `op` edges are the names of the operators in question.
#
# Which operators do we have?

# %%
for (op, freq) in E.op.freqList():
    print(f'{op} : {freq:>5}x')
# Out:
# x :  2346x
# . :  1042x
# & :   222x
# + :   200x

# %% [markdown]
# Between how many sign pairs do we have an operator?

# %%
query = '''
sign
-op> sign
'''
results = CN.search(query)
# Out:
# 3642 results

# %% [markdown]
# Lets specifically ask for the `x` operator:

# %%
query = '''
sign
-op=x> sign
'''
results = CN.search(query)
# Out:
# 2238 results

# %% [markdown]
# Less than expected?
#
# We must not forget the combinations between quads and between quads and signs.
#
# We write a function that gives all pairs of sign/quads connected by a specific operator.
#
# This is a fine illustration of how you can use programming to compose search templates,
# instead of writing them out yourself.

# %%
def getCombi(op):
    types = ('sign', 'quad')
    allResults = []
    for type1 in types:
        for type2 in types:
            query = f'''
{type1}
-op{op}> {type2}
'''
            results = CN.search(query, silent=True)
            print(f'{len(results):>5} {type1} {op} {type2}')
            allResults += results
    print(f'{len(allResults):>5} {op}')

# %% [markdown]
# Now we can count all combinations with `x`:

# %%
getCombi('=x')
# Out:
#  2238 sign =x sign
#   105 sign =x quad
#     3 quad =x sign
#     0 quad =x quad
#  2346 =x

# %%
getCombi('=.')
# Out:
#   985 sign =. sign
#    43 sign =. quad
#    14 quad =. sign
#     0 quad =. quad
#  1042 =.

# %%
getCombi('=&')
# Out:
#   220 sign =& sign
#     1 sign =& quad
#     0 quad =& sign
#     1 quad =& quad
#   222 =&

# %%
getCombi('=+')
# Out:
#   199 sign =+ sign
#     0 sign =+ quad
#     0 quad =+ sign
#     1 quad =+ quad
#   200 =+

# %% [markdown]
# In exact agreement with the results of `E.op.freqList()` above.
# But we are more flexible!
#
# We can ask for more operators at the same time.

# %%
getCombi('=x|+')
# Out:
#  2437 sign =x|+ sign
#   105 sign =x|+ quad
#     3 quad =x|+ sign
#     1 quad =x|+ quad
#  2546 =x|+

# %%
getCombi('~[^a-z]')
# Out:
#  1404 sign ~[^a-z] sign
#    44 sign ~[^a-z] quad
#    14 quad ~[^a-z] sign
#     2 quad ~[^a-z] quad
#  1464 ~[^a-z]

# %% [markdown]
# Finally, we zoom in on the rare cases where the operator is `x` used between a quad and a sign.
# We want to see the show the lines where they occur.

# %%
query = '''
line
  quad
  -op=x> sign
'''
results = CN.search(query)
CN.show(results, withNodes=True)
# Out:
# 3 results
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002264" title="to CDLI main page for this tablet">tablet P002264  <span class="name">IM 023435,19</span> <span class="period">uruk-iii</span> <span class="excavation">W 15771,h</span></a>
#         <span class="nd">146811</span>
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#         <span class="nd">176501</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#         <span class="nd">154869</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#         <span class="nd">186837</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1
#         <span class="nd">244724</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">210220</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67704</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">210220</span>
#     </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="lbl quad">
#
#         <span class="nd">141950</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr quad hl">
#
#     <div class="lbl quad">
#
#         <span class="nd">141951</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67705</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">&</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67706</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign hl">
#
#     <div class="lbl sign">
#
#         <span class="nd">67707</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SZE3</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67708</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">UR2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">210221</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67709</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">210221</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#         <span class="nd">244725</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="lbl quad">
#
#         <span class="nd">141952</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|SILA3~axDUG~a|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qsila3-axdug-aq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67710</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SILA3~a</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67711</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">DUG~a</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67712</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">MEN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/MEN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-men-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67713</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SUKKAL#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUKKAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sukkal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67714</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67715</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">210222</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">67716</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">210222</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002624" title="to CDLI main page for this tablet">tablet P002624  <span class="name">W 17480,b</span> <span class="period">uruk-iii</span> <span class="excavation">W 17480,b</span></a>
#         <span class="nd">148296</span>
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#         <span class="nd">178317</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#         <span class="nd">157130</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#         <span class="nd">190707</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#         <span class="nd">255146</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110674</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">TUM~b#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUM~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tum-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">220130</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110675</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">220130</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#         <span class="nd">255147</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110676</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-su-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">220131</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110677</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">220131</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#         <span class="nd">255148</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110678</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">PIRIG~b1</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PIRIG~b1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pirig-b1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110679</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#         <span class="nd">255149</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110680</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">NA2~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NA2~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-na2-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">220132</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110681</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">220132</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#         <span class="nd">190708</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#         <span class="nd">255150</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110682</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">RU#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ru.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#         <span class="nd">220133</span>
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">110683</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#         <span class="nd">220133</span>
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#         <span class="nd">255151</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div c
# ##### Tablet 3
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P004659" title="to CDLI main page for this tablet">tablet P004659  <span class="name">ATU 7, pl. 091, W 22133</span> <span class="period">uruk-iv</span> <span class="excavation">W 22133</span></a>
#         <span class="nd">149624</span>
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#         <span class="nd">179698</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#         <span class="nd">158867</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#         <span class="nd">193298</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#         <span class="nd">260575</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131403</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">1(N34)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131404</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">3(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131405</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">2(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131406</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">SZE3</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE3.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze3.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2
#         <span class="nd">260576</span>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131407</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">1(N48)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N48).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n48).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131408</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">8(N34)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/8(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-8(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="lbl quad">
#
#         <span class="nd">143672</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|(GI&GI)xGISZ@t|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-q(gi(e)gi)xgisz(a)tq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr quad hl">
#
#     <div class="lbl quad">
#
#         <span class="nd">143673</span>
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131409</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">&</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131410</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign hl">
#
#     <div class="lbl sign">
#
#         <span class="nd">131411</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GISZ@t</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131412</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">ZATU659#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU659.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu659.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131413</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">USZ~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/USZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-usz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="lbl sign">
#
#         <span class="nd">131414</span>
#     </div>
#
#     <div class="meta">
#          <span class="srcLn">GU4#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GU4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gu4.jpg" style="display: inline;max-width: 2em; ma

# %% [markdown]
# ## Regular expressions in templates
# We can use regular expressions in our search templates.
#
# ### Digits in graphemes
# We search for non-numeral signs whose graphemes contains digits.

# %%
query = '''
sign type=ideograph grapheme~[0-9]
'''
results = CN.search(query)
CN.table(results, withNodes=True, end=5)
# Out:
# 14558 results
# n | sign
# --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">U4</a> *75*  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">U4</a> *76*  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">U4</a> *87*  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">U4</a> *90*  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">U4</a> *93*  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>

# %% [markdown]
# We can add a bit more context easily:

# %%
query = '''
tablet
  face
    column
      line
        sign type=ideograph grapheme~[0-9]
'''
results = CN.search(query)
CN.table(results, end=20)
# Out:
# 14558 results
# n | tablet | face | column | line | sign
# --- | --- | --- | --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|face obverse|column 2|line 1|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448702" title="to CDLI main page for this tablet">tablet P448702</a>|face obverse|column 2|line 1|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">tablet P448703</a>|face obverse|column 1|line 1|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">tablet P448703</a>|face obverse|column 1|line 2|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">tablet P448703</a>|face obverse|column 1|line 3|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">tablet P448703</a>|face obverse|column 1|line 4|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448703" title="to CDLI main page for this tablet">tablet P448703</a>|face obverse|column 1|line 5|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">tablet P471695</a>|face obverse|column 1|line 1|UR4~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR4~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur4-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">tablet P471695</a>|face obverse|column 1|line 1|ZATU759 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU759.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu759.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">tablet P471695</a>|face obverse|column 2|line 1|GIR3~c <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GIR3~c.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gir3-c.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482082" title="to CDLI main page for this tablet">tablet P482082</a>|face obverse|column 1|line 2|ZATU694~c <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU694~c.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu694-c.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P482083" title="to CDLI main page for this tablet">tablet P482083</a>|face obverse|column 1|line 2|U4 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P499393" title="to CDLI main page for this tablet">tablet P499393</a>|face obverse|column 1|line 1|U2~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U2~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u2-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P499393" title="to CDLI main page for this tablet">tablet P499393</a>|face obverse|column 1|line 2|U2~b <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U2~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u2-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P499393" title="to CDLI main page for this tablet">tablet P499393</a>|face obverse|column 1|line 5|SIG2~a1 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG2~a1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig2-a1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P499393" title="to CDLI main page for this tablet">tablet P499393</a>|face obverse|column 2|line 4|SZU2 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZU2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-szu2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P504412" title="to CDLI main page for this tablet">tablet P504412</a>|face obverse|column 1|line 3|TUN3~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUN3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tun3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P504412" title="to CDLI main page for this tablet">tablet P504412</a>|face obverse|column 1|line 5|MASZ2 <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/MASZ2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-masz2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P504412" title="to CDLI main page for this tablet">tablet P504412</a>|face obverse|column 1|line 6|SILA3~d
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P504412" title="to CDLI main page for this tablet">tablet P504412</a>|face obverse|column 2|line 3|KU6~a <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>

# %% [markdown]
# ### Pit numbers
#
# The feature `excavation` gives you the number of the pit where a tablet is found.
# The syntax of pit numbers is a bit involved, here are a few possible values:
#
# ```
# W 20497
# W 20335,3
# W 19948,10
# W 20493,26
# W 17890,b
# W 17729,o
# W 15920,b5
# W 17729,aq
# W 19548,a + W 19548,b
# W 17729,cn + W 17729,eq
# W 14337,a + W 14337,b + W 14337,c + W 14337,d + W 14337,e
# Ashm 1928-445b
# ```
#
# Let's assume we are interested in `SZITA~a1` signs occurring in cases of depth 1.
# The following query finds them all:

# %%
query = '''
tablet
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = CN.search(query)
# Out:
# 78 results

# %% [markdown]
# Now we want to organize them by excavation number:

# %%
signPerPit = {}

for (tablet, case, sign) in sorted(results):
    pit = F.excavation.v(tablet) or 'no pit information'
    signPerPit.setdefault(pit, []).append(sign)

for pit in sorted(signPerPit):
    print(f'{pit:<30} {len(signPerPit[pit]):>2}')
# Out:
# Ashm 1926,562                   1
# Ashm 1926,567                   1
# Ashm 1926,569                  13
# Ashm 1926,695+737+741           6
# Ashm 1926,716+732               1
# Ashm 1926,739                   1
# W 14731,z                       1
# W 14777,c                       4
# W 15776,i                       1
# W 15785,a2                      1
# W 15833,a01 + W 15833,aa04      1
# W 15897,b5                      1
# W 15897,c26                     1
# W 20274,001                     1
# W 20274,043                     1
# W 20274,095                     2
# W 20274,119                     1
# W 20327,01                      1
# W 20327,03                      1
# W 20511,01                      1
# W 20511,02                      6
# W 21157                         1
# W 21194                         1
# W 21733,1                       3
# W 22100,01                      4
# W 22100,03                      5
# W 22101,1                       1
# W 23950                         1
# W 23973,01                      1
# W 24033,05                      1
# no pit information             13

# %% [markdown]
# We can restrict results to those on tablets found in certain pits by constraining the search template.
# If we are interested in pit `20274` we can use a regular expression that matches all 4 detailed pit numbers
# based on `20274`.
# So, we do not say
#
# ```
# excavation=20274
# ```
# but
#
# ```
# excavation~20274
# ```

# %%
query = '''
tablet excavation~20274
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = CN.search(query)
CN.table(results, lineart=False)
# Out:
# 5 results
# n | tablet | case | sign
# --- | --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003617" title="to CDLI main page for this tablet">tablet P003617</a>|case 2b|SZITA~a1
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003499" title="to CDLI main page for this tablet">tablet P003499</a>|case 2a|SZITA~a1
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003541" title="to CDLI main page for this tablet">tablet P003541</a>|case 1b|SZITA~a1
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003593" title="to CDLI main page for this tablet">tablet P003593</a>|case 2a|SZITA~a1
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003593" title="to CDLI main page for this tablet">tablet P003593</a>|case 3b|SZITA~a1

# %% [markdown]
# Or if we want to restrict ourselves to pit numbers with a `W`, we can say:

# %%
query = '''
tablet excavation~W
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = CN.search(query)
# Out:
# 42 results

# %% [markdown]
# ## Quantifiers in templates
#
# So far we have seen only very positive templates.
# They express what you want to see in the result.
#
# It is also possible to state conditions about what you do not want to see in the results.

# %% [markdown]
# ### Tablets without case divisions
#
# Let's find all tablets in which all lines are undivided, i.e. lines without cases.

# %%
query = '''
tablet
/without/
  case
/-/
'''

# %% [markdown]
# The expression
#
# ```
# /without/
# template
# /-/
# ```
#
# is a [quantifier](https://dans-labs.github.io/text-fabric/Api/General/#quantifiers).
#
# It poses a condition on the preceding line in the template, in this case the `tablet`.
# And the condition is that the template
#
# ```
# tablet
#   case
# ```
#
# does not have results.

# %%
results = CN.search(query)
# Out:
# 5384 results

# %%
CN.show(results, end=2)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006427" title="to CDLI main page for this tablet">tablet P006427  <span class="name">Anonymous 006427</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SANGA~a?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006428" title="to CDLI main page for this tablet">tablet P006428  <span class="name">Anonymous 006428</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         3
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         5
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|DUG~bx1(N5

# %% [markdown]
# Now let's find cases without numerals.

# %%
query = '''
case
/without/
  sign type=numeral
/-/
'''
results = CN.search(query)
# Out:
# 2833 results

# %% [markdown]
# We show a few.

# %%
CN.show(results, end=2)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P471695" title="to CDLI main page for this tablet">tablet P471695  <span class="name">Anonymous 471695</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">APIN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/APIN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-apin-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N57)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">UR4~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR4~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur4-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr case hl">
#
#     <div class="lbl case">
#         1b
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children casev">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1b1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalh">
#
#
#     <div class="lbl clusterB">
#         =
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">EN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/EN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-en-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">DU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/DU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-du.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">ZATU759</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU759.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu759.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         =
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1b2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalh">
#
#
#     <div class="lbl clusterB">
#         =
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BAN~b</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BAN~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ban-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KASZ~c</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~c.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-c.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         =
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         1b3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalh">
#
#
#     <div class="lbl clusterB">
#         =
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KI@n</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KI@n.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ki(a)n.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAG</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAG.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sag.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         =
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-co
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KU6~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|AB~axSUKKAL|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qab-axsukkalq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB~a</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUKKAL</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2c
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAM2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAM2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nam2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PA~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pa-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-szu.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal hl">
#
#     <div class="lbl trminal">
#         2d
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr face" style="backgrou

# %% [markdown]
# Now we can use this to get something more sophisticated: the tablets that do not have numerals in their cases. So only undivided lines may contain numerals.
#
# Let's find tablets that do have cases, but just no cases with numerals.

# %%
query = '''
tablet
/where/
  case
/have/
  /without/
    sign type=numeral
  /-/
/-/
/with/
  case
/-/
'''

# %%
results = CN.search(query)
# Out:
# 53 results

# %%
CN.show(results, end=2)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KU6~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|AB~axSUKKAL|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qab-axsukkalq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB~a</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUKKAL</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2c
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAM2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAM2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nam2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PA~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pa-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-szu.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2d
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002044" title="to CDLI main page for this tablet">tablet P002044  <span class="name">ATU 6, pl. 043, W 14335,x</span> <span class="period">uruk-iii</span> <span class="excavation">W 14335,x</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GAL~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GAL~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gal-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PAP~a#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PAP~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pap-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Can we find such tablet which do have numerals on their undivided lines.
#
# We show here a way to use the results of one query in another one:
# *custom sets*.
#
# We put the set of tablets with cases but without numerals in cases in a set called `cntablet`.
#
# We run the query again, but now in shallow mode, so that the result is a set.
#
# By the way: read more about custom sets and shallow mode in the description of
# [`CN.search()`](https://dans-labs.github.io/text-fabric/Api/General/#search-api).

# %%
results = CN.search(query, shallow=True)
customSets = dict(cntablet=results)
# Out:
# 53 results

# %% [markdown]
# Now we can perform a very simple query for numerals on this set: we want tablets with numerals.
# By restricting ourselves to this set, we now that these numerals must occur on undivided lines.

# %%
query = '''
cntablet
  sign type=numeral
'''
results = CN.search(query, sets=customSets)
# Out:
# 160 results

# %%
CN.show(results, end=2)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KU6~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|AB~axSUKKAL|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qab-axsukkalq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB~a</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUKKAL</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2c
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAM2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAM2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nam2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PA~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pa-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-szu.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2d
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002082" title="to CDLI main page for this tablet">tablet P002082  <span class="name">ATU 6, pl. 047, W 14637</span> <span class="period">uruk-iii</span> <span class="excavation">W 14637</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAG</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAG.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sag.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUMASZ</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUMASZ.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sumasz.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N34)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n34).jpg" style="display: inline;max-width: 2em; max-height: 4

# %% [markdown]
# We could have found these results by one query as well.
# Judge for yourself which method causes the least friction.

# %%
query = '''
tablet
/without/
  case
    sign type=numeral
/-/
/with/
  case
/-/
  sign type=numeral
'''
results = CN.search(query)
CN.show(results, end=2)
# Out:
# 160 results
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006438" title="to CDLI main page for this tablet">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KU6~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|AB~axSUKKAL|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qab-axsukkalq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB~a</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUKKAL</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2c
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAM2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAM2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nam2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PA~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pa-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-szu.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2d
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">RAD~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RAD~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-rad-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002082" title="to CDLI main page for this tablet">tablet P002082  <span class="name">ATU 6, pl. 047, W 14637</span> <span class="period">uruk-iii</span> <span class="excavation">W 14637</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAG</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAG.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sag.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUHUR#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SUMASZ</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUMASZ.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sumasz.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N34)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n34).jpg" style="display: inline;max-width: 2em; max-height: 4

# %% [markdown]
# ## Search and hand-coding
#
# Now we want to find all the ShinPP numerals.

# %%
shinPP = dict(
    N41=0.2,
    N04=1,
    N19=6,
    N46=60,
    N36=180,
    N49=1800,
)

shinPPPat = '|'.join(shinPP)

# %% [markdown]
# We make use of the fact that we can construct our template.

# %%
query = f'''
tablet
  sign grapheme={shinPPPat}
'''
results = CN.search(query)
CN.table(results, end=20)
# Out:
# 1018 results
# n | tablet | sign
# --- | --- | ---
# 1|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448701" title="to CDLI main page for this tablet">tablet P448701</a>|1(N46) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 2|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448701" title="to CDLI main page for this tablet">tablet P448701</a>|2(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 3|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448701" title="to CDLI main page for this tablet">tablet P448701</a>|4(N41) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 4|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006005" title="to CDLI main page for this tablet">tablet P006005</a>|1(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 5|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002329" title="to CDLI main page for this tablet">tablet P002329</a>|2(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 6|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002342" title="to CDLI main page for this tablet">tablet P002342</a>|1(N36) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 7|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002342" title="to CDLI main page for this tablet">tablet P002342</a>|2(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 8|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002344" title="to CDLI main page for this tablet">tablet P002344</a>|1(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 9|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002398" title="to CDLI main page for this tablet">tablet P002398</a>|1(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 10|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002622" title="to CDLI main page for this tablet">tablet P002622</a>|5(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 11|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002622" title="to CDLI main page for this tablet">tablet P002622</a>|1(N46) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 12|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002622" title="to CDLI main page for this tablet">tablet P002622</a>|4(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 13|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002626" title="to CDLI main page for this tablet">tablet P002626</a>|1(N41) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 14|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003330" title="to CDLI main page for this tablet">tablet P003330</a>|3(N46) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 15|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003330" title="to CDLI main page for this tablet">tablet P003330</a>|2(N49) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N49).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n49).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 16|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003330" title="to CDLI main page for this tablet">tablet P003330</a>|5(N19) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 17|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003330" title="to CDLI main page for this tablet">tablet P003330</a>|2(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 18|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003330" title="to CDLI main page for this tablet">tablet P003330</a>|1(N41) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 19|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003357" title="to CDLI main page for this tablet">tablet P003357</a>|1(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>
# 20|<a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P003542" title="to CDLI main page for this tablet">tablet P003542</a>|1(N04) <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a>

# %% [markdown]
# Let's see a few tablets in more detail:

# %%
CN.show(results, end=5)
# Out:
# ##### Tablet 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P448701" title="to CDLI main page for this tablet">tablet P448701  <span class="name">Anonymous 448701</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N46)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N19)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">4(N41)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AB~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/AB~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ab-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">APIN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/APIN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-apin-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">DU</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/DU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-du.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         reverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">(not imaged)</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ##### Tablet 2
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006005" title="to CDLI main page for this tablet">tablet P006005  <span class="name">ATU 6, pl. 052, W 14731,ag07</span> <span class="period">uruk-iii</span> <span class="excavation">W 14731,ag07</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PAP~a#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PAP~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pap-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ##### Tablet 3
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002329" title="to CDLI main page for this tablet">tablet P002329  <span class="name">ATU 6, pl. 065, W 15774,d</span> <span class="period">uruk-iii</span> <span class="excavation">W 15774,d</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">KI</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KI.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ki.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUNUZ~a1</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUNUZ~a1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nunuz-a1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SANGA~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N57)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">EN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/EN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-en-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BA#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BA.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ba.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAGAR~b</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAGAR~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nagar-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
# ##### Tablet 4
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002342" title="to CDLI main page for this tablet">tablet P002342  <span class="name">ATU 6, pl. 067, W 15774,s</span> <span class="period">uruk-iii</span> <span class="excavation">W 15774,s</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N45)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N45).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n45).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">BU~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N34)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N45)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N45).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n45).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         3
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
# ##### Tablet 5
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002344" title="to CDLI main page for this tablet">tablet P002344  <span class="name">ATU 6, pl. 067, W 15774,u</span> <span class="period">uruk-iii</span> <span class="excavation">W 15774,u</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">A</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/A.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N50)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N50).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n50).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">UH3~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UH3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-uh3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         3
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-

# %% [markdown]
# ### A tablet calculator
#
# Rather than displaying search results, you can also *process* them in your program.
#
# Search results come as tuples of nodes that correspond directly to the elements
# of your search template.
#
# We query for shinPP numerals on the faces of tablets.
# The result of the query is a list of tuples `(t, f, s)` consisting of
# a tablet node, a face node and a node for a sign of a shinPP numeral.
#
# #### Rationale
# This task will require a higher level of programming skills and a deeper knowledge of how
# Python works.
# We include it in this tutorial to get the message across that Text-Fabric is not
# a black box that shields you from your data. Everything you handle in Text-Fabric is
# open to further programming and processing of your own design and choosing.

# %% [markdown]
# #### Data collection

# %%
query = f'''
tablet
    face
        sign type=numeral grapheme={shinPPPat}
'''
results = CN.search(query)
# Out:
# 1018 results

# %% [markdown]
# We are going to put all these numerals in buckets: for each face on each tablet a separate bucket.

# %%
numerals = {}
pNums = {}
for (tablet, face, sign) in results:
    pNums[F.catalogId.v(tablet)] = tablet
    numerals.setdefault(tablet, {}).setdefault(face, []).append(sign)
print(f'{len(pNums)} tablets')
print('\n'.join(list(pNums)[0:10]))
print('...')
# Out:
# 235 tablets
# P448701
# P006005
# P002329
# P002342
# P002344
# P002398
# P002622
# P002626
# P003330
# P003357
# ...

# %% [markdown]
# #### The calculator
# We define a function that given a tablet, adds the shinPP numerals by its faces.
# We also show the line art and a pretty transcription.
#
# The function is a bit involved.

# %%
# we generate Markdown strings and send them to the notebook formatter

def dm(x): display(Markdown(x))

def calcTablet(pNum): # pNum identifies the tablet in question
    # show a horizontal line in Markdown
    dm('---\n')     
    tablet = pNums.get(pNum, None)  # look up the node for this p-number
    if tablet is None:
        dm(f'**no results for {pNum}**')
        return                      # if not found the tablet has no ShinPP numerals: quit
    
    CN.lineart(tablet, withCaption="top", width="200")   # show lineart
    faces = numerals[tablet]                    # get the buckets for the faces
    mySigns = []
    for (face, signs) in faces.items():         # work per face 
        mySigns.extend(signs)
        dm(f'##### {F.type.v(face)}')           # show the name of the face
        distinctSigns = {}                      # collect the distinct numerals
        for s in signs:
            distinctSigns.setdefault(CN.atfFromSign(s), []).append(s)
        CN.lineart(distinctSigns)      # display the list of signs
        total = 0                               # start adding up
        for (signAtf, signs) in distinctSigns.items():
            value = 0
            for s in signs:
                value += F.repeat.v(s) * shinPP[F.grapheme.v(s)]
            total += value
            amount = len(signs)                 # we report our calculation
            shinPPval = shinPP[F.grapheme.v(signs[0])]
            repeat = F.repeat.v(signs[0])
            print(f'{amount} x {signAtf} = {amount} x {repeat} x {shinPPval} = {value}')
        dm(f'**total** = **{total}**')
    CN.prettyTuple([tablet] + mySigns, 1)                           # show pretty transcription

# %% [markdown]
# #### Calculate once

# %%
calcTablet('P006377')
# Out:
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P006377_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P006377</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006377" title="to CDLI main page for this item">P006377</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N41)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI ma ...
# 1 x 1(N46) = 1 x 1 x 60 = 60
# 1 x 5(N19) = 1 x 5 x 6 = 30
# 4 x 3(N04) = 4 x 3 x 1 = 12
# 2 x 1(N41) = 2 x 1 x 0.2 = 0.4
# 8 x 1(N19) = 8 x 1 x 6 = 48
# 2 x 3(N19) = 2 x 3 x 6 = 36
# 5 x 1(N04) = 5 x 1 x 1 = 5
# 3 x 2(N04) = 3 x 2 x 1 = 6
# 3 x 2(N19) = 3 x 2 x 6 = 36
# 1 x 2(N41) = 1 x 2 x 0.2 = 0.4
# 2 x 4(N04) = 2 x 4 x 1 = 8
# 1 x 3(N41) = 1 x 3 x 0.2 = 0.6000000000000001
# 1 x 4(N19) = 1 x 4 x 6 = 24
# **total** = **266.4**
# ##### reverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/8(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-8(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">8(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n41).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N41)</a></div></div></div></div>
# 1 x 1(N36) = 1 x 1 x 180 = 180
# 1 x 1(N46) = 1 x 1 x 60 = 60
# 1 x 8(N19) = 1 x 8 x 6 = 48
# 1 x 5(N04) = 1 x 5 x 1 = 5
# 1 x 3(N41) = 1 x 3 x 0.2 = 0.6000000000000001
# **total** = **293.6**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P006377" title="to CDLI main page for this tablet">tablet P006377  <span class="name">CUSAS 01, 105</span> <span class="period">uruk-iii</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N46)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">5(N19)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N41)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">UR5~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR5~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur5-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N19)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N41)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N24)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N24).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n24).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TAR~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TAR~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tar-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N04)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SAL</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TUR3~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUR3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tur3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N19)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to highe

# %% [markdown]
# #### Calculate ad lib
# Now the first 5 tablets.

# %%
for tablet in sorted(pNums)[0:5]:
    calcTablet(tablet)
# Out:
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P000266_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P000266</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000266" title="to CDLI main page for this item">P000266</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div></div>
# 1 x 1(N04) = 1 x 1 x 1 = 1
# **total** = **1**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P000266" title="to CDLI main page for this tablet">tablet P000266  <span class="name">CDLI Lexical 000019, ex. 003</span> <span class="period">uruk-iii</span> <span class="excavation">W 20266,020</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1'
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">IM~a#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/IM~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-im-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">IM~a#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/IM~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-im-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">rest broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GAN2#?</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GAN2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gan2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2'
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         ruling
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1'
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to h
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P001043_l.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-p001043.jpg" style="display: inline;max-width: 200px;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P001043" title="to CDLI main page for this item">P001043</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div></div>
# 2 x 1(N36) = 2 x 1 x 180 = 360
# **total** = **360**
# ##### reverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N36)</a></div></div></div></div>
# 1 x 3(N36) = 1 x 3 x 180 = 540
# **total** = **540**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P001043" title="to CDLI main page for this tablet">tablet P001043  <span class="name">ATU 5, pl. 037, W 9123,v</span> <span class="period">uruk-iv</span> <span class="excavation">W 09123,v</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N36)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NESAG2~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NESAG2~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nesag2-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">TE#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TE.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-te.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N36)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GI</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GI.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gi.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AL</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/AL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-al.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         reverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">3(N36)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">AN#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/AN.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-an.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P001270_l.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-p001270.jpg" style="display: inline;max-width: 200px;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P001270" title="to CDLI main page for this item">P001270</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">2(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI ma ...
# 1 x 5(N36) = 1 x 5 x 180 = 900
# 4 x 1(N46) = 4 x 1 x 60 = 240
# 2 x 1(N36) = 2 x 1 x 180 = 360
# 1 x 2(N46) = 1 x 2 x 60 = 120
# 1 x 1(N04) = 1 x 1 x 1 = 1
# 1 x 1(N19) = 1 x 1 x 6 = 6
# 2 x 2(N36) = 2 x 2 x 180 = 720
# 1 x 2(N19) = 1 x 2 x 6 = 12
# **total** = **2359**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P001270" title="to CDLI main page for this tablet">tablet P001270  <span class="name">ATU 5, pl. 065, W 9579,w</span> <span class="period">uruk-iv</span> <span class="excavation">W 09579,w</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">9(N34)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/9(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-9(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N45)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N45).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n45).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">7(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/7(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-7(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">5(N36)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N46)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N36)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">2(N46)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N04)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr quad" style="background-color: None;">
#
#     <div class="meta">
#
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|DU8~cxHI|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qdu8-cxhiq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div>
#
#     <div class="children quad">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">DU8~c</span>
#
#     </div>
#
#
# </div>
#
# <div class="op">x</div>
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">HI</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class=
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P002260_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P002260</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002260" title="to CDLI main page for this item">P002260</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div></div>
# 1 x 1(N04) = 1 x 1 x 1 = 1
# **total** = **1**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002260" title="to CDLI main page for this tablet">tablet P002260  <span class="name">IM 023435,14</span> <span class="period">uruk-iii</span> <span class="excavation">W 15771,d</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">GU#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gu.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NUN~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N04)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">NAM2</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAM2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nam2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         3
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">3(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">EN~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/EN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-en-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">PA~a#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pa-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         4
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminal">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N01)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lin
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P002275_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P002275</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002275" title="to CDLI main page for this item">P002275</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div></div>
# 1 x 1(N36) = 1 x 1 x 180 = 180
# **total** = **180**
# ##### Result 1
# <div class="contnr tablet" style="background-color: None;">
#
#     <div class="lbl tablet">
#         <a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&ObjectID=P002275" title="to CDLI main page for this tablet">tablet P002275  <span class="name">IM 023435,06</span> <span class="period">uruk-iii</span> <span class="excavation">W 15771,t</span></a>
#
#     </div>
#
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment" style="background-color: None;">
#
#     <div class="lbl comment">
#         meta
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
#
# </div>
# </div>
#     </div>
#
#
#     <div class="children tablet">
#
#
# <div class="contnr face" style="background-color: None;">
#
#     <div class="lbl face">
#         obverse
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">X</span>
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N45)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N45).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n45).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">SZE~a</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">4(N14)#</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         2b
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
#
#
#     <div class="children trminalv">
#
#
# <div class="contnr sign hl">
#
#     <div class="meta">
#          <span class="srcLn">1(N36)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">1(N45)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N45).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n45).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">2(N14)</span>
#
#     </div>
#
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div>
#
# </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     <div class="lbl clusterB">
#         ?
#
#     </div>
#
#
# <div class="contnr sign" style="background-color: None;">
#
#     <div class="meta">
#          <span class="srcLn">...</span>
#
#     </div>
#
#
# </div>
#
#
#     <div class="lbl clusterE" style="background-color: None;">
#         ?
#
#     </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr column" style="background-color: None;">
#
#     <div class="lbl column">
#         2
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children column">
#
#
# <div class="contnr line" style="background-color: None;">
#
#     <div class="lbl line">
#         1
#
#     </div>
#
#     <div class="meta">
#
#
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr trminal" style="background-color: None;">
#
#     <div class="lbl trminal">
#         1a
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>

# %% [markdown]
# ## More ...
#
# The capabilities of search are endless.
# Often it is the quickest way to focus on a phenomenon, quicker than hand coding all the logic
# to retrieve your patterns.
#
# That said, it is not a matter of either-or. You can use coding to craft your templates,
# and you can use coding to process your results.
#
# It's an explosive mix. A later chapter in this tutorial shows
# even more [cases](cases.ipynb).
#
# Have another look at
# [the manual](https://dans-labs.github.io/text-fabric/Api/General/#search-templates).

# %% [markdown]
# # Next
#
# [signs](signs.ipynb)
#
# *Back to the basics ...*
#
# All chapters:
# [start](start.ipynb)
# [imagery](imagery.ipynb)
# [steps](steps.ipynb)
# [search](search.ipynb)
# [signs](signs.ipynb)
# [quads](quads.ipynb)
# [jumps](jumps.ipynb)
# [cases](cases.ipynb)
