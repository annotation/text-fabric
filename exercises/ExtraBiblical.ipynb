# %%
from tf.fabric import Fabric

# %%
XBIB = 'hebrew/extrabiblical'
TF = Fabric(locations='~/github/etcbc-data', modules=[XBIB])
# Out:
# This is Text-Fabric 2.3.4
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
# Data docs     : https://etcbc.github.io/text-fabric-data
# Shebanq docs  : https://shebanq.ancient-data.org/text
# Slack team    : https://shebanq.slack.com/signup
# Questions? Ask shebanq@ancient-data.org for an invite to Slack
# 72 features found and 0 ignored

# %%
api = TF.load('''
    sp
    function
    typ
''')
api.makeAvailableIn(globals())
# Out:
#   0.00s loading features ...
#    |     0.07s T sp                   from /Users/dirk/github/etcbc-data/hebrew/extrabiblical
#    |     0.04s T function             from /Users/dirk/github/etcbc-data/hebrew/extrabiblical
#    |     0.07s T typ                  from /Users/dirk/github/etcbc-data/hebrew/extrabiblical
#    |     0.00s Feature overview: 68 nodes; 1 edges; 3 configs; 7 computeds
#   0.21s All features loaded/computed - for details use loadLog()

# %%
vn = T.nodeFromSection(('1QM', 1, 1))

# %%
T.text(L.d(vn, 'word'))
# Out:
# 'לם המלחמה '

# %%
cn = T.nodeFromSection(('1QM', 1))

# %%
cn
# Out:
# 13885

# %%
for sn in L.d(cn, 'sentence'):
    print('=======')
    for cn in L.d(sn, 'clause'):
        print('clause {}'.format(F.typ.v(cn)))
        for pn in L.d(cn, 'phrase'):
            print('\tphrase {}'.format(F.function.v(pn)))
            print('\t\t{}'.format(T.text(L.d(pn, 'word'))))
# Out:
# ...
# clause NmCl
# 	phrase Modi
# 		לם
# 	phrase Adju
# 		המלחמה
# ...
# clause NmCl
# 	phrase Subj
# 		ראשׁית משׁלוח יד בני אור
# clause InfC
# 	phrase Pred
# 		להחל
# 	phrase Cmpl
# 		בגורל בני חושׁך בחיל בליעל בגדוד אדום ומואב ובני עמון וח פלשׁת ובגדודי כתיי אשׁור
# ...
# clause NmCl
# 	phrase Conj
# 		ו
# 	phrase PreC
# 		עםהם
# clause InfC
# 	phrase Pred
# 		בעזר
# clause Ptcp
# 	phrase PreC
# 		מרשׁיעי
# 	phrase Objc
# 		ברית
# ...
# clause XYqt
# 	phrase Subj
# 		בני לוי ובני יהודה ובני בנימין גולת המדבר
# 	phrase Pred
# 		ילחמו
# 	phrase Cmpl
# 		במ
# clause InfC
# 	phrase Pred
# 		בשׁוב
# 	phrase Subj
# 		גולת בני אור
# 	phrase Cmpl
# 		ממדבר העמים
# clause InfC
# 	phrase Pred
# 		לחנות
# 	phrase Cmpl
# 		במדבר ירושׁלים
# ...
# clause NmCl
# 	phrase Modi
# 		ב
# ...
# clause NmCl
# 	phrase Adju
# 		לכול גדודיהם
# ...
# clause WxY0
# 	phrase Conj
# 		ו
# 	phrase Time
# 		אחר המלחמה
# 	phrase Pred
# 		יעלו
# 	phrase Cmpl
# 		משׁם
# ...
# clause NmCl
# 	phrase Adju
# 		הכתיים
# 	phrase Adju
# 		במצרים
# ...
# clause WxY0
# ...
