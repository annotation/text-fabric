# %% [markdown]
# <img align="right" src="tf-small.png"/>
#
# # SBLGNT and Text-Fabric
#
# The source of the SBLGNT data in TF is really a treebank, a hierarchical structure.
# We converted an XML representation of it into TF.
#
# As an exercise, we convert the TF back to a hierarchical structure, but not XML, we will produce
# [yaml](http://www.yaml.org)

# %%
import os,collections,yaml
from tf.fabric import Fabric

# %%
TF = Fabric(modules='greek/sblgnt')
# Out:
# This is Text-Fabric 2.3.6
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
# Data docs     : https://etcbc.github.io/text-fabric-data
# Shebanq docs  : https://shebanq.ancient-data.org/text
# Slack team    : https://shebanq.slack.com/signup
# Questions? Ask shebanq@ancient-data.org for an invite to Slack
# 60 features found and 0 ignored

# %%
api = TF.load('''
    Cat Gender Tense
    Unicode UnicodeLemma Mood
    book book@en chapter verse
    otype function psp
    freq_occ freq_lex
    Head End
    nodeId
    child
              ''')

api.makeAvailableIn(globals())
# Out:
#   0.00s loading features ...
#    |     0.02s B otype                from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.01s B book                 from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.01s B chapter              from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.03s B verse                from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.09s B Unicode              from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.08s B UnicodeLemma         from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.13s B Cat                  from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.04s B Gender               from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.04s B Tense                from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.02s B Mood                 from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.01s B book@en              from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.09s B function             from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.06s B psp                  from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.06s B freq_occ             from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.07s B freq_lex             from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.07s B Head                 from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.17s B End                  from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.41s B nodeId               from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.68s B child                from /Users/dirk/github/text-fabric-data/greek/sblgnt
#    |     0.00s Feature overview: 57 for nodes; 2 for edges; 1 configs; 7 computed
#   4.85s All features loaded/computed - for details use loadLog()

# %%
F.Unicode.freqList()
# Out:
# (('καὶ', 8559),
#  ('ὁ', 2800),
#  ('ἐν', 2682),
#  ('δὲ', 2609),
#  ('τοῦ', 2500),
#  ('εἰς', 1747),
#  ('τὸ', 1656),
#  ('τὸν', 1562),
#  ('τὴν', 1514),
#  ('τῆς', 1299),
#  ('ὅτι', 1282),
#  ('τῷ', 1224),
#  ('τῶν', 1208),
#  ('οἱ', 1079),
#  ('ἡ', 953),
#  ('γὰρ', 922),
#  ('μὴ', 904),
#  ('αὐτοῦ', 883),
#  ('τῇ', 861),
#  ('τὰ', 819),
#  ('οὐκ', 765),
#  ('τοὺς', 727),
#  ('ἐκ', 669),
#  ('πρὸς', 667),
#  ('ἵνα', 661),
#  ('ἐπὶ', 655),
#  ('αὐτὸν', 651),
#  ('οὐ', 628),
#  ('τοῖς', 614),
#  ('αὐτῷ', 512),
#  ('διὰ', 482),
#  ('ὡς', 480),
#  ('οὖν', 470),
#  ('ἀπὸ', 467),
#  ('θεοῦ', 423),
#  ('ἀλλὰ', 415),
#  ('ἐστιν', 400),
#  ('εἶπεν', 397),
#  ('ὑμῶν', 378),
#  ('Καὶ', 375),
#  ('αὐτῶν', 374),
#  ('ὑμῖν', 371),
#  ('εἰ', 365),
#  ('μου', 351),
#  ('τὰς', 337),
#  ('ἢ', 333),
#  ('Ἰησοῦς', 324),
#  ('κατὰ', 315),
#  ('περὶ', 312),
#  ('ὑμᾶς', 297),
#  ('αὐτοῖς', 280),
#  ('σου', 279),
#  ('ἡμῶν', 275),
#  ('ἦν', 275),
#  ('λέγει', 269),
#  ('μετὰ', 269),
#  ('τοῦτο', 259),
#  ('ἐὰν', 259),
#  ('ἐγὼ', 239),
#  ('θεὸς', 236),
#  ('Ἰησοῦ', 230),
#  ('τί', 228),
#  ('ἐξ', 227),
#  ('πάντα', 224),
#  ('τις', 223),
#  ('αὐτῷ·', 218),
#  ('αὐτοῦ,', 217),
#  ('αὐτοὺς', 214),
#  ('τε', 211),
#  ('ἀλλ’', 205),
#  ('αὐτοῦ.', 203),
#  ('ταῖς', 203),
#  ('με', 202),
#  ('ὃ', 199),
#  ('ὑμεῖς', 197),
#  ('αὐτοῖς·', 191),
#  ('ὃς', 185),
#  ('κυρίου', 182),
#  ('ὑπὸ', 182),
#  ('ταῦτα', 178),
#  ('εἶπεν·', 175),
#  ('οὕτως', 171),
#  ('μὲν', 170),
#  ('λέγω', 169),
#  ('καθὼς', 168),
#  ('ὃν', 163),
#  ('πάντες', 156),
#  ('ἂν', 156),
#  ('ἐγένετο', 156),
#  ('μοι', 154),
#  ('ὑπὲρ', 150),
#  ('δι’', 148),
#  ('ἕως', 143),
#  ('αὐτὸς', 142),
#  ('ἰδοὺ', 142),
#  ('οὗ', 141),
#  ('ἐπ’', 140),
#  ('αἱ', 138),
#  ('ὑμῖν,', 135),
#  ('λέγων·', 133),
#  ('μετ’', 132),
#  ('πνεῦμα', 129),
#  ('οὐδὲ', 128),
#  ('σὺν', 128),
#  ('ἔστιν', 127),
#  ('ἡμᾶς', 127),
#  ('υἱὸς', 126),
#  ('Χριστοῦ', 125),
#  ('νῦν', 125),
#  ('παρὰ', 125),
#  ('τότε', 125),
#  ('ἀπ’', 124),
#  ('θεοῦ,', 121),
#  ('κύριος', 121),
#  ('ἡμῖν', 120),
#  ('τίς', 118),
#  ('ᾧ', 118),
#  ('πάλιν', 117),
#  ('λέγοντες·', 115),
#  ('μου,', 114),
#  ('πάντων', 113),
#  ('Τί', 112),
#  ('λόγον', 111),
#  ('αὐτόν.', 110),
#  ('Ὁ', 110),
#  ('ἃ', 109),
#  ('Ἰησοῦς·', 109),
#  ('σε', 108),
#  ('σοι', 108),
#  ('ἐστὶν', 107),
#  ('ὅταν', 107),
#  ('δύο', 106),
#  ('σὺ', 106),
#  ('ἡμεῖς', 106),
#  ('οὗτος', 102),
#  ('ἡμέρας', 101),
#  ('δέ', 100),
#  ('ἔσται', 100),
#  ('θεοῦ.', 99),
#  ('ἄνθρωπος', 98),
#  ('αὐτόν,', 97),
#  ('οὐχ', 97),
#  ('ἣν', 95),
#  ('ἀνθρώπου', 94),
#  ('γάρ', 92),
#  ('εἷς', 92),
#  ('θεῷ', 92),
#  ('μαθηταὶ', 92),
#  ('τι', 92),
#  ('ὅτε', 92),
#  ('αὐτοῦ·', 91),
#  ('ἀποκριθεὶς', 89),
#  ('ἐνώπιον', 88),
#  ('πᾶς', 85),
#  ('ἔχων', 85),
#  ('αὐτῶν.', 84),
#  ('πῶς', 84),
#  ('αὐτῆς', 83),
#  ('κατ’', 83),
#  ('οὐδεὶς', 83),
#  ('οὔτε', 83),
#  ('ἦλθεν', 82),
#  ('Ἰησοῦν', 82),
#  ('αὐτοὶ', 81),
#  ('ὧν', 80),
#  ('ἐφ’', 79),
#  ('Πέτρος', 78),
#  ('ἦσαν', 78),
#  ('ὄνομα', 77),
#  ('Χριστῷ', 76),
#  ('αὐτόν·', 76),
#  ('πάντας', 76),
#  ('πατὴρ', 76),
#  ('ἀπεκρίθη', 76),
#  ('ὅπου', 76),
#  ('αὐτῇ', 75),
#  ('μᾶλλον', 75),
#  ('ὑμῶν,', 75),
#  ('ὥστε', 75),
#  ('Κύριε,', 74),
#  ('αὐτῶν,', 74),
#  ('θεὸν', 74),
#  ('πᾶν', 74),
#  ('αὐτὸ', 73),
#  ('ὑμᾶς,', 73),
#  ('Μὴ', 72),
#  ('ἐκεῖ', 72),
#  ('ἑπτὰ', 72),
#  ('ὀνόματι', 72),
#  ('ἀδελφοί,', 71),
#  ('γῆς', 70),
#  ('δεῖ', 70),
#  ('πατέρα', 70),
#  ('ἐμοὶ', 70),
#  ('ἡμέρᾳ', 69),
#  ('πνεύματος', 68),
#  ('ἐμοῦ', 68),
#  ('ἐστιν,', 68),
#  ('αὐτὴν', 67),
#  ('εἶναι', 67),
#  ('ἐμὲ', 67),
#  ('πνεύματι', 66),
#  ('ἀμὴν', 66),
#  ('ἔρχεται', 66),
#  ('αὐτῷ.', 65),
#  ('Παῦλος', 64),
#  ('δύναται', 64),
#  ('εἴ', 64),
#  ('εἴτε', 64),
#  ('πολλοὶ', 64),
#  ('εἶ', 63),
#  ('κυρίῳ', 63),
#  ('πίστεως', 63),
#  ('τούτῳ', 63),
#  ('ἔχει', 63),
#  ('ἡμῶν,', 63),
#  ('αὐτούς·', 62),
#  ('οὐρανοῦ', 62),
#  ('σου,', 62),
#  ('υἱὸν', 62),
#  ('εἶδον', 61),
#  ('κἀγὼ', 61),
#  ('μόνον', 61),
#  ('παρ’', 61),
#  ('ἔτι', 61),
#  ('Εἰ', 60),
#  ('Οὐκ', 60),
#  ('αὕτη', 60),
#  ('καθ’', 60),
#  ('λόγος', 60),
#  ('Χριστοῦ,', 59),
#  ('γυνὴ', 59),
#  ('εἰμι', 59),
#  ('πᾶσιν', 59),
#  ('ἐξῆλθεν', 59),
#  ('ἐστιν.', 59),
#  ('ὑμῶν.', 59),
#  ('παντὶ', 58),
#  ('ἐποίησεν', 57),
#  ('ἔδωκεν', 57),
#  ('ὅσα', 57),
#  ('οἵτινες', 56),
#  ('πατρὸς', 56),
#  ('χάρις', 56),
#  ('ἑαυτὸν', 56),
#  ('ἦλθον', 56),
#  ('Ἰδοὺ', 56),
#  ('βασιλεία', 55),
#  ('γῆν', 55),
#  ('εἰσιν', 55),
#  ('μηδὲ', 55),
#  ('βασιλείαν', 54),
#  ('μου.', 54),
#  ('τέκνα', 54),
#  ('τινες', 54),
#  ('ἤδη', 54),
#  ('ζωὴν', 53),
#  ('πρῶτον', 53),
#  ('πᾶσαν', 53),
#  ('σου.', 53),
#  ('Χριστὸς', 52),
#  ('δόξαν', 52),
#  ('οὐδὲν', 52),
#  ('τοῦτον', 52),
#  ('ἓν', 52),
#  ('ἔξω', 52),
#  ('ἰδὼν', 52),
#  ('ὅπως', 52),
#  ('δώδεκα', 51),
#  ('καρδίας', 51),
#  ('λέγει·', 51),
#  ('νόμου', 51),
#  ('οὓς', 51),
#  ('ἐξουσίαν', 51),
#  ('ἔργα', 51),
#  ('ὑμῖν.', 51),
#  ('εἶπαν', 50),
#  ('μή', 50),
#  ('ἑαυτοὺς', 50),
#  ('εὐθὺς', 49),
#  ('πόδας', 49),
#  ('τούτων', 49),
#  ('χεῖρας', 49),
#  ('ἔλεγον', 49),
#  ('ἧς', 49),
#  ('νόμον', 48),
#  ('οἴδατε', 48),
#  ('Οὐ', 47),
#  ('οὗτοι', 47),
#  ('σῶμα', 47),
#  ('ἐλθὼν', 47),
#  ('ὅ', 47),
#  ('Φαρισαῖοι', 46),
#  ('πόλιν', 46),
#  ('ἄχρι', 46),
#  ('κόσμου', 45),
#  ('λέγουσιν', 45),
#  ('λέγων', 45),
#  ('οἷς', 45),
#  ('πίστιν', 45),
#  ('ἀνθρώπων', 45),
#  ('ἀρχιερεῖς', 45),
#  ('Ἐν', 45),
#  ('ἡμέραν', 45),
#  ('Σὺ', 44),
#  ('οὐκέτι', 44),
#  ('πάσῃ', 44),
#  ('ἄνθρωπον', 44),
#  ('ἄρα', 44),
#  ('Ἀβραὰμ', 44),
#  ('ἐστε', 44),
#  ('αὐτῷ,', 43),
#  ('εἰσὶν', 43),
#  ('κύριον', 43),
#  ('μαθητῶν', 43),
#  ('οἶκον', 43),
#  ('οὗτός', 43),
#  ('πολλὰ', 43),
#  ('χωρὶς', 43),
#  ('ἀφ’', 43),
#  ('Ἰωάννης', 43),
#  ('αὐτοῖς.', 42),
#  ('βασιλεὺς', 42),
#  ('πάσης', 42),
#  ('πρὸ', 42),
#  ('τούτου', 42),
#  ('ἀκούσαντες', 42),
#  ('ἐγέννησεν', 42),
#  ('γυναῖκα', 41),
#  ('δόξης', 41),
#  ('εἶπαν·', 41),
#  ('μεθ’', 41),
#  ('νεκρῶν', 41),
#  ('σοῦ', 41),
#  ('ἐάν', 41),
#  ('ἔλεγεν', 41),
#  ('ἡμέραις', 41),
#  ('ὧδε', 41),
#  ('αὐτούς.', 40),
#  ('θανάτου', 40),
#  ('θεόν,', 40),
#  ('καλὸν', 40),
#  ('οἶδα', 40),
#  ('οὐχὶ', 40),
#  ('πᾶσα', 40),
#  ('ἀλλήλους', 40),
#  ('ἔμπροσθεν', 40),
#  ('Ἰερουσαλὴμ', 40),
#  ('Ἰουδαῖοι', 40),
#  ('Χριστοῦ.', 39),
#  ('αὐτοῖς,', 39),
#  ('εἶδεν', 39),
#  ('φῶς', 39),
#  ('ἐκεῖνος', 39),
#  ('ἤρξατο', 39),
#  ('ἰδόντες', 39),
#  ('ὄχλος', 39),
#  ('ὢν', 39),
#  ('Μωϋσῆς', 38),
#  ('αὐτῆς,', 38),
#  ('πρόσωπον', 38),
#  ('φωνὴν', 38),
#  ('ἁμαρτίας', 38),
#  ('ἄγγελος', 38),
#  ('ἑαυτοῖς', 38),
#  ('ἑαυτοῦ', 38),
#  ('εἰσῆλθεν', 37),
#  ('καρπὸν', 37),
#  ('λαβὼν', 37),
#  ('λόγῳ', 37),
#  ('τόπον', 37),
#  ('χάριν', 37),
#  ('χρείαν', 37),
#  ('ἕνα', 37),
#  ('Ἐγὼ', 37),
#  ('ἡμῶν.', 37),
#  ('Ἰησοῦ,', 37),
#  ('Ἰησοῦ.', 37),
#  ('ᾗ', 37),
#  ('γέγραπται', 36),
#  ('διὸ', 36),
#  ('μαθηταῖς', 36),
#  ('ἀνὴρ', 36),
#  ('ἔχω', 36),
#  ('ἕκαστος', 36),
#  ('ἥτις', 36),
#  ('ὁδὸν', 36),
#  ('ᾖ', 36),
#  ('αὐτούς,', 35),
#  ('λέγοντες', 35),
#  ('οἰκίαν', 35),
#  ('πίστει', 35),
#  ('ποιῆσαι', 35),
#  ('υἱοῦ', 35),
#  ('ἔργον', 35),
#  ('ἔχοντες', 35),
#  ('ὥσπερ', 35),
#  ('Τίς', 34),
#  ('αἷμα', 34),
#  ('αὐτὰ', 34),
#  ('εἶπον', 34),
#  ('θεός,', 34),
#  ('μήτε', 34),
#  ('μαθητὰς', 34),
#  ('πάντοτε', 34),
#  ('ἅγιον', 34),
#  ('Ἀμὴν', 34),
#  ('ἔθνη', 34),
#  ('ἔργων', 34),
#  ('ἔχετε', 34),
#  ('ἔχομεν', 34),
#  ('ἤκουσα', 34),
#  ('Δαυὶδ', 33),
#  ('Διὰ', 33),
#  ('Τότε', 33),
#  ('Χριστὸν', 33),
#  ('γένηται', 33),
#  ('γῆς,', 33),
#  ('εἰμὶ', 33),
#  ('εὐθέως', 33),
#  ('θέλημα', 33),
#  ('ταύτην', 33),
#  ('ἀδελφὸν', 33),
#  ('ἀπέστειλεν', 33),
#  ('ὅλον', 33),
#  ('Οἱ', 32),
#  ('Σίμων', 32),
#  ('αὐτῆς.', 32),
#  ('γραμματεῖς', 32),
#  ('δόξα', 32),
#  ('εὐαγγέλιον', 32),
#  ('πλὴν', 32),
#  ('τρεῖς', 32),
#  ('φωνῇ', 32),
#  ('ἀπῆλθεν', 32),
#  ('ἄνδρες', 32),
#  ('ἄρτον', 32),
#  ('Ἐγένετο', 32),
#  ('ὀπίσω', 32),
#  ('ὑμᾶς.', 32),
#  ('δέ,', 31),
#  ('θεοῦ·', 31),
#  ('μήτηρ', 31),
#  ('με,', 31),
#  ('οἳ', 31),
#  ('πίστις', 31),
#  ('παντὸς', 31),
#  ('ποῦ', 31),
#  ('σημεῖον', 31),
#  ('ψυχὴν', 31),
#  ('ἁγίου', 31),
#  ('Ἰσραὴλ', 31),
#  ('θέλω', 30),
#  ('μηδὲν', 30),
#  ('μου·', 30),
#  ('οἴδαμεν', 30),
#  ('οὐρανὸν', 30),
#  ('πολλῶν', 30),
#  ('σημεῖα', 30),
#  ('τινα', 30),
#  ('ἀδελφὸς', 30),
#  ('Ἰωάννην', 30),
#  ('ὀφθαλμοὺς', 30),
#  ('εἰρήνη', 29),
#  ('κυρίου,', 29),
#  ('νυκτὸς', 29),
#  ('πέντε', 29),
#  ('σαρκὸς', 29),
#  ('σοὶ', 29),
#  ('στόματος', 29),
#  ('φωνὴ', 29),
#  ('ἀδελφοὶ', 29),
#  ('ἀκούσας', 29),
#  ('ἐδόθη', 29),
#  ('ἐλάλησεν', 29),
#  ('ἑνὸς', 29),
#  ('ἔλθῃ', 29),
#  ('Ἰωσὴφ', 29),
#  ('ὑμῶν·', 29),
#  ('ὥρα', 29),
#  ('ζωῆς', 28),
#  ('καρδίᾳ', 28),
#  ('λέγειν', 28),
#  ('μίαν', 28),
#  ('με.', 28),
#  ('νόμος', 28),
#  ('νόμῳ', 28),
#  ('πατρός', 28),
#  ('πρός', 28),
#  ('σοι,', 28),
#  ('ἀγάπη', 28),
#  ('ἀδελφοί', 28),
#  ('ἀδελφοὺς', 28),
#  ('ἀναστὰς', 28),
#  ('ἀνθρώπους', 28),
#  ('ἁγίων', 28),
#  ('ἐθνῶν', 28),
#  ('ἐκείνῃ', 28),
#  ('ἑαυτῶν', 28),
#  ('ἔλεγον·', 28),
#  ('ἰδεῖν', 28),
#  ('Ἰουδαίων', 28),
#  ('Μετὰ', 27),
#  ('γενομένης', 27),
#  ('δοῦλος', 27),
#  ('δοῦναι', 27),
#  ('εὗρον', 27),
#  ('θεῷ,', 27),
#  ('κόσμον', 27),
#  ('κόσμος', 27),
#  ('μέσῳ', 27),
#  ('πόλεως', 27),
#  ('σάρκα', 27),
#  ('σήμερον', 27),
#  ('στόμα', 27),
#  ('ἄλλοι', 27),
#  ('ἐγώ', 27),
#  ('ἔχουσιν', 27),
#  ('Ἡ', 27),
#  ('ἱμάτια', 27),
#  ('εἰσελθεῖν', 26),
#  ('θρόνου', 26),
#  ('λαοῦ', 26),
#  ('ποιῶν', 26),
#  ('ἀγάπην', 26),
#  ('ἀνθρώποις', 26),
#  ('ἐλθεῖν', 26),
#  ('ἐστιν·', 26),
#  ('ἔχοντα', 26),
#  ('ὄχλοι', 26),
#  ('ὅσοι', 26),
#  ('ὅστις', 26),
#  ('ὑμῖν·', 26),
#  ('ὥρᾳ', 26),
#  ('Διδάσκαλε,', 25),
#  ('Πιλᾶτος', 25),
#  ('αἵματος', 25),
#  ('αὐτήν,', 25),
#  ('εἶναι,', 25),
#  ('καλῶς', 25),
#  ('λαὸν', 25),
#  ('οὐαὶ', 25),
#  ('οὔπω', 25),
#  ('ἀληθείας', 25),
#  ('Ἐὰν', 25),
#  ('ἡμέραι', 25),
#  ('Ἰωάννου', 25),
#  ('ὑπ’', 25),
#  ('Γαλιλαίας', 24),
#  ('Παῦλον', 24),
#  ('Τὸ', 24),
#  ('αὐτῶν·', 24),
#  ('δ’', 24),
#  ('θεῷ.', 24),
#  ('μεγάλῃ', 24),
#  ('μοι·', 24),
#  ('πατρὶ', 24),
#  ('πιστεύων', 24),
#  ('ποιεῖτε', 24),
#  ('πρῶτος', 24),
#  ('πῦρ', 24),
#  ('υἱοὶ', 24),
#  ('χειρὸς', 24),
#  ('ἀρχιερεὺς', 24),
#  ('ἄλλος', 24),
#  ('ἄρτους', 24),
#  ('ἐπεὶ', 24),
#  ('ἔπεσεν', 24),
#  ('ἔσονται', 24),
#  ('ἱερῷ', 24),
#  ('ῥήματα', 24),
#  ('Ταῦτα', 23),
#  ('βασιλείας', 23),
#  ('γέγραπται·', 23),
#  ('γενόμενος', 23),
#  ('δεξιῶν', 23),
#  ('διότι', 23),
#  ('κεφαλὴν', 23),
#  ('μήποτε', 23),
#  ('μείζων', 23),
#  ('πιστὸς', 23),
#  ('πλοῖον', 23),
#  ('ποτήριον', 23),
#  ('προσελθὼν', 23),
#  ('σαρκὶ', 23),
#  ('σώματος', 23),
#  ('σὲ', 23),
#  ('ταύτῃ', 23),
#  ('χάριτος', 23),
#  ('ἀνθρώπων,', 23),
#  ('ἀνθρώπῳ', 23),
#  ('ἄνδρα', 23),
#  ('ἔφη·', 23),
#  ('ἔχειν', 23),
#  ('ἕτερον', 23),
#  ('Ἐγώ', 23),
#  ('ἡμῖν,', 23),
#  ('ὁμοίως', 23),
#  ('ὄνομά', 23),
#  ('ὑμᾶς·', 23),
#  ('Φαρισαίων', 22),
#  ('βασιλείᾳ', 22),
#  ('δικαιοσύνης', 22),
#  ('δύναμιν', 22),
#  ('δύνασθε', 22),
#  ('λόγου', 22),
#  ('λόγους', 22),
#  ('οἰκίᾳ', 22),
#  ('πλῆθος', 22),
#  ('πρόβατα', 22),
#  ('τέλος', 22),
#  ('τρίτον', 22),
#  ('χρόνον', 22),
#  ('ἀγγέλων', 22),
#  ('ἁμαρτία', 22),
#  ('ἁμαρτιῶν', 22),
#  ('ἐστίν,', 22),
#  ('ἑαυτῷ', 22),
#  ('ἔχεις', 22),
#  ('Ἰερουσαλήμ,', 22),
#  ('ὄχλον', 22),
#  ('Ὡς', 22),
#  ('Πέτρον', 21),
#  ('γενέσθαι', 21),
#  ('γῆ', 21),
#  ('γῆς.', 21),
#  ('δέκα', 21),
#  ('δώσω', 21),
#  ('εἰδότες', 21),
#  ('εἰδὼς', 21),
#  ('ζωὴ', 21),
#  ('καί', 21),
#  ('καρδίαις', 21),
#  ('μένει', 21),
#  ('μοι.', 21),
#  ('νεκρῶν,', 21),
#  ('οὐρανῶν', 21),
#  ('σεαυτὸν', 21),
#  ('φωνῆς', 21),
#  ('ἀσπάσασθε', 21),
#  ('ἄγγελοι', 21),
#  ('ἐξελθὼν', 21),
#  ('ἐρχόμενος', 21),
#  ('ἔλαβον', 21),
#  ('ἡμερῶν', 21),
#  ('ἤγειρεν', 21),
#  ('Ἰησοῦν,', 21),
#  ('Ἰουδαίοις', 21),
#  ('Ἱεροσόλυμα', 21),
#  ('ὀνόματί', 21),
#  ('ὄχλου', 21),
#  ('αἰῶνας', 20),
#  ('αὐτήν·', 20),
#  ('γέγονεν', 20),
#  ('δυνάμει', 20),
#  ('θαλάσσης', 20),
#  ('κύριος,', 20),
#  ('λέγω,', 20),
#  ('λίθον', 20),
#  ('λαὸς', 20),
#  ('μοι,', 20),
#  ('παιδίον', 20),
#  ('παραβολὴν', 20),
#  ('ποιήσας', 20),
#  ('πολλῷ', 20),
#  ('ποτε', 20),
#  ('προφήτης', 20),
#  ('προφητῶν', 20),
#  ('πόθεν', 20),
#  ('πόλει', 20),
#  ('πόλις', 20),
#  ('σε.', 20),
#  ('φαγεῖν', 20),
#  ('φυλῆς', 20),
#  ('χαρᾶς', 20),
#  ('χεῖρα', 20),
#  ('ἁμαρτίαν', 20),
#  ('ἄνδρας', 20),
#  ('ἄρτι', 20),
#  ('ἐγγὺς', 20),
#  ('ἐκκλησίας', 20),
#  ('ἐλθόντες', 20),
#  ('ἑνὶ', 20),
#  ('ἔτη', 20),
#  ('ἡμέρα', 20),
#  ('Ἡρῴδης', 20),
#  ('ἰδίαν', 20),
#  ('Ἰησοῦν.', 20),
#  ('Ἰησοῦς,', 20),
#  ('Ἰουδαίας', 20),
#  ('ὄρος', 20),
#  ('ὅς', 20),
#  ('ὡσεὶ', 20),
#  ('ὥραν', 20),
#  ('ὥρας', 20),
#  ('Εἶπεν', 19),
#  ('Μαρία', 19),
#  ('Μαριὰμ', 19),
#  ('Πέτρος·', 19),
#  ('Πῶς', 19),
#  ('αὐτήν.', 19),
#  ('αὐτῇ·', 19),
#  ('διδάσκων', 19),
#  ('δυνάμεως', 19),
#  ('εἰμι,', 19),
#  ('εἰπὼν', 19),
#  ('εἶχεν', 19),
#  ('θάλασσαν', 19),
#  ('θέλει', 19),
#  ('θεός.', 19),
#  ('καιρὸν', 19),
#  ('καιρῷ', 19),
#  ('κόσμῳ', 19),
#  ('μέγας', 19),
#  ('μεγάλη', 19),
#  ('μηδενὶ', 19),
#  ('οὐρανοῦ,', 19),
#  ('οὐρανῷ', 19),
#  ('πέραν', 19),
#  ('ποδῶν', 19),
#  ('προφήτου', 19),
#  ('σώματι', 19),
#  ('ταύτης', 19),
#  ('τούτους', 19),
#  ('ἀμήν.', 19),
#  ('ἀφῆκεν', 19),
#  ('Ἄνδρες', 19),
#  ('ἐκεῖθεν', 19),
#  ('ἐπάνω', 19),
#  ('ἐσμεν', 19),
#  ('ἑκάστῳ', 19),
#  ('ἔλαβεν', 19),
#  ('ἔχει,', 19),
#  ('Ἰουδαίων,', 19),
#  ('Ἰούδας', 19),
#  ('Ἰσαὰκ', 19),
#  ('ὑμῖν;', 19),
#  ('Μωϋσέως', 18),
#  ('Οὗτός', 18),
#  ('Παύλου', 18),
#  ('Περὶ', 18),
#  ('αἰώνιον', 18),
#  ('βλέπετε', 18),
#  ('γινώσκετε', 18),
#  ('δαιμόνια', 18),
#  ('δικαιοσύνην', 18),
#  ('εἰσελθὼν', 18),
#  ('θεόν.', 18),
#  ('θηρίον', 18),
#  ('κυρίου.', 18),
#  ('λέγουσα·', 18),
#  ('μαρτυρίαν', 18),
#  ('μητέρα', 18),
#  ('μισθὸν', 18),
#  ('μιᾷ', 18),
#  ('νυνὶ', 18),
#  ('οἴκῳ', 18),
#  ('πατήρ', 18),
#  ('πολλοὺς', 18),
#  ('πολὺ', 18),
#  ('πρεσβύτεροι', 18),
#  ('προσκαλεσάμενος', 18),
#  ('προσώπου', 18),
#  ('πότε', 18),
#  ('σου·', 18),
#  ('τεσσεράκοντα', 18),
#  ('υἱός', 18),
#  ('ἀνέβη', 18),
#  ('ἄνθρωποι', 18),
#  ('ἐζήτουν', 18),
#  ('ἐξελθόντες', 18),
#  ('ἐξῆλθον', 18),
#  ('ἐστίν.', 18),
#  ('ἐστίν·', 18),
#  ('ἔβαλεν', 18),
#  ('ἔρχονται', 18),
#  ('ἔφη', 18),
#  ('ἠκολούθησαν', 18),
#  ('ἡμῶν·', 18),
#  ('ἤρξαντο', 18),
#  ('ὄντες', 18),
#  ('ὅλην', 18),
#  ('Ὑμεῖς', 18),
#  ('βιβλίον', 17),
#  ('γε', 17),
#  ('γραμματέων', 17),
#  ('δώσει', 17),
#  ('εἰρήνην', 17),
#  ('εἶ,', 17),
#  ('κρίμα', 17),
#  ('κύριε,', 17),
#  ('μαρτύριον', 17),
#  ('μηκέτι', 17),
#  ('πάσχα', 17),
#  ('παρέδωκεν', 17),
#  ('πατέρες', 17),
#  ('πνεύματα', 17),
#  ('σὰρξ', 17),
#  ('τινὲς', 17),
#  ('τοῦτο,', 17),
#  ('τοῦτ’', 17),
#  ('υἱῶν', 17),
#  ('χάριτι', 17),
#  ('χειρὶ', 17),
#  ('χριστὸς', 17),
#  ('ἀγαθὸν', 17),
#  ('ἀγγέλους', 17),
#  ('ἀνδρὶ', 17),
#  ('ἀντὶ', 17),
#  ('ἀπεκρίθησαν', 17),
#  ('ἀρχῆς', 17),
#  ('ἄλλον', 17),
#  ('ἐντολὴν', 17),
#  ('ἐρχόμενον', 17),
#  ('ἐστιν;', 17),
#  ('ἔθνεσιν', 17),
#  ('ἔλεγεν·', 17),
#  ('ἕνεκεν', 17),
#  ('ἴδε', 17),
#  ('ἴδιον', 17),
#  ('Ἰησοῦ·', 17),
#  ('ὑμῶν;', 17),
#  ('ὕδατος', 17),
#  ('ὤφθη', 17),
#  ('αἰῶνος', 16),
#  ('αὐτῆς·', 16),
#  ('βασιλεῖς', 16),
#  ('γυναικὸς', 16),
#  ('δούλους', 16),
#  ('δοῦλοι', 16),
#  ('δυνάμεις', 16),
#  ('εἴπῃ', 16),
#  ('εἶχον', 16),
#  ('εὐαγγελίου', 16),
#  ('θάνατος', 16),
#  ('κακὸν', 16),
#  ('λέγετε', 16),
#  ('λέγοντος·', 16),
#  ('λαβεῖν', 16),
#  ('λαλοῦντος', 16),
#  ('μεγάλην', 16),
#  ('πάντα,', 16),
#  ('πληρωθῇ', 16),
#  ('ποιεῖ', 16),
#  ('προσελθόντες', 16),
#  ('σε,', 16),
#  ('τίνα', 16),
#  ('ἀκούειν', 16),
#  ('ἀναστάσεως', 16),
#  ('ἀνθρώπων.', 16),
#  ('ἀπέθανεν', 16),
#  ('ἀπελθὼν', 16),
#  ('ἄγγελον', 16),
#  ('ἐκείνου', 16),
#  ('ἐκκλησίᾳ', 16),
#  ('ἐλάλει', 16),
#  ('ἐλπίδα', 16),
#  ('ἐπίστευσαν', 16),
#  ('ἔθνος', 16),
#  ('ὅλης', 16),
#  ('ὅσον', 16),
#  ('Ὅταν', 16),
#  ('ὦτα', 16),
#  ('Ποῦ', 15),
#  ('Τῇ', 15),
#  ('γραφὴ', 15),
#  ('δοθήσεται', 15),
#  ('δοκεῖ', 15),
#  ('δόξῃ', 15),
#  ('εἶπέν', 15),
#  ('εἶτα', 15),
#  ('καιρὸς', 15),
#  ('κακῶς', 15),
#  ('καρδία', 15),
#  ('λαβόντες', 15),
#  ('λαῷ', 15),
#  ('μέλλει', 15),
#  ('μέχρι', 15),
#  ('μικρὸν', 15),
#  ('οὖν,', 15),
#  ('πάντων,', 15),
#  ('πέμψας', 15),
#  ('παραχρῆμα', 15),
#  ('πλησίον', 15),
#  ('πνεύματι,', 15),
#  ('πνεύματος,', 15),
#  ('ποιεῖν', 15),
#  ('προσῆλθον', 15),
#  ('προφῆται', 15),
#  ('σπέρμα', 15),
#  ('συναγωγαῖς', 15),
#  ('ταῦτα,', 15),
#  ('ἀγάπης', 15),
#  ('ἀγάπῃ', 15),
#  ('ἀδελφῶν', 15),
#  ('ἀπήγγειλαν', 15),
#  ('ἀφέντες', 15),
#  ('ἄλλα', 15),
#  ('ἐμοῦ,', 15),
#  ('ἐμοῦ.', 15),
#  ('ἐξουσίᾳ', 15),
#  ('ἐπαγγελίας', 15),
#  ('ἐπαύριον', 15),
#  ('ἐπηρώτησεν', 15),
#  ('ἐρεῖ', 15),
#  ('ἔγνωσαν', 15),
#  ('ἔγραψα', 15),
#  ('ἔξεστιν', 15),
#  ('ἡμᾶς,', 15),
#  ('ἡμῖν.', 15),
#  ('ἤκουσεν', 15),
#  ('Ἠλίας', 15),
#  ('ἱερὸν', 15),
#  ('Ἰάκωβον', 15),
#  ('Ἰακὼβ', 15),
#  ('ὁδῷ', 15),
#  ('ὄντος', 15),
#  ('ὕδωρ', 15),
#  ('Οὕτως', 14),
#  ('Τοῦτο', 14),
#  ('αἰώνιον.', 14),
#  ('αἷς', 14),
#  ('αὐταῖς', 14),
#  ('αὐτοῦ;', 14),
#  ('αὐτόν;', 14),
#  ('βάπτισμα', 14),
#  ('γίνεσθε', 14),
#  ('γίνεται', 14),
#  ('γονεῖς', 14),
#  ('διαθήκης', 14),
#  ('δώδεκα,', 14),
#  ('θάνατον', 14),
#  ('καθήμενος', 14),
#  ('κυρίῳ,', 14),
#  ('κυρίῳ.', 14),
#  ('λαλεῖν', 14),
#  ('λαλῶν', 14),
#  ('λόγον,', 14),
#  ('μέλη', 14),
#  ('μία', 14),
#  ('μόνος', 14),
#  ('μῆνας', 14),
#  ('οἰκίας', 14),
#  ('οἶδεν', 14),
#  ('οἶνον', 14),
#  ('ποιήσω', 14),
#  ('πολλάκις', 14),
#  ('πολὺς', 14),
#  ('πρεσβυτέρων', 14),
#  ('πᾶσαι', 14),
#  ('σοι.', 14),
#  ('σῶμά', 14),
#  ('τίνι', 14),
#  ('τιμὴν', 14),
#  ('τινας', 14),
#  ('τούτοις', 14),
#  ('χαρὰ', 14),
#  ('χειρῶν', 14),
#  ('χριστὸν', 14),
#  ('ἀγαπητοί,', 14),
#  ('ἀδελφοῦ', 14),
#  ('ἀκούοντες', 14),
#  ('ἀλήθειαν', 14),
#  ('ἀπόστολοι', 14),
#  ('ἁγίοις', 14),
#  ('ἅπαξ', 14),
#  ('ἐκείναις', 14),
#  ('ἐκείνης', 14),
#  ('ἐντολὰς', 14),
#  ('ἐπετίμησεν', 14),
#  ('ἐτῶν', 14),
#  ('ἔδει', 14),
#  ('ἔλεος', 14),
#  ('ἔπειτα', 14),
#  ('ἔχοντας', 14),
#  ('ἠκούσατε', 14),
#  ('Ἰσραήλ.', 14),
#  ('Ἴδε', 14),
#  ('ὀνόματος', 14),
#  ('ὄντα', 14),
#  ('ὅλῃ', 14),
#  ('ᾔδει', 14),
#  ('ῥῆμα', 14),
#  ('Διὸ', 13),
#  ('Παύλῳ', 13),
#  ('Πιλᾶτος·', 13),
#  ('Σίμωνος', 13),
#  ('Σατανᾶς', 13),
#  ('Χριστῷ,', 13),
#  ('αἰτίαν', 13),
#  ('αἵματι', 13),
#  ('αὐτό,', 13),
#  ('δέ·', 13),
#  ('δένδρον', 13),
#  ('δίκαιος', 13),
#  ('δεξιᾷ', 13),
#  ('εὗρεν', 13),
#  ('θέλετε', 13),
#  ('θέλων', 13),
#  ('θελήματος', 13),
#  ...)

# %%
outputDir = os.path.expanduser('~/Downloads/yamlFromTf')
if not os.path.exists(outputDir): os.makedirs(outputDir)
outFile = 'sblgnt.yaml'
outPath = '{}/{}'.format(outputDir, outFile)

# %%
def addBooks(dest):
    for b in F.otype.s('book'):
        chapters = []
        dest.append({Fs('book@en').v(b): chapters})
        addChapters(b, chapters)

def addChapters(b, dest):
    for c in L.d(b, 'chapter'):
        sentences = []
        dest.append({F.chapter.v(c): sentences})
        addSentences(c, sentences)

curNodeId = None
def addSentences(c, dest):
    global curNodeId
    for s in L.d(c, 'sentence'):
        children = []
        nodeId = F.nodeId.v(s)
        curNodeId = nodeId
        dest.append({nodeId: children})
        addNodes(s, children, 0)

maxK = 0

def addNodes(n, dest, k):
    global maxK
    if k > maxK:
        maxK = k
        print('{} at {}'.format(k, curNodeId))
    descendants = E.child.f(n)
    if descendants == None or len(descendants) == 0:
        dest.append(F.Unicode.v(n))
    else:
        for d in descendants:
            children = []
            if k > 20:
                dest.append({F.Cat.v(d): ' '.join(F.Unicode.v(w) for w in L.d(d, 'word'))})
            else:
                dest.append({F.Cat.v(d): children})
                addNodes(d, children, k+1)

# %%
nest = []
addBooks(nest)
# Out:
# 1 at 400010010010083
# 2 at 400010010010083
# 3 at 400010010010083
# 4 at 400010010010083
# 5 at 400010010010083
# 6 at 400010010010083
# 7 at 400010010010083
# 8 at 400010010010083
# 9 at 400010010010083
# 10 at 400010120020741
# 11 at 400010120020741
# 12 at 400010120020741
# 13 at 400010120020741
# 14 at 400010120020741
# 15 at 400010120020741
# 16 at 400010120020741
# 17 at 400010200020501
# 18 at 400010220020361
# 19 at 400010220020361
# 20 at 400010220020361
# 21 at 400010220020361

# %%
indent(reset=True)
info('writing yaml')
with open(outPath, 'w', encoding='utf8') as of:
    yaml.dump(nest, of, allow_unicode=True, default_style=None)
    of.close()
info('Done')
# Out:
#   0.00s writing yaml
#     54s Done

# %% [markdown]
# ```
# - Matthew:
#   - 1:
#     - '400010010010083':
#       - CL:
#         - P:
#           - np:
#             - np:
#               - noun: [Βίβλος]
#             - np:
#               - np:
#                 - noun: [γενέσεως]
#               - np:
#                 - np:
#                   - np:
#                     - np:
#                       - noun: [Ἰησοῦ]
#                     - np:
#                       - noun: [χριστοῦ]
#                   - np:
#                     - np:
#                       - noun: [υἱοῦ]
#                     - np:
#                       - noun: [Δαυὶδ]
#                 - np:
#                   - np:
#                     - noun: [υἱοῦ]
#                   - np:
#                     - noun: [Ἀβραάμ.]
# ```

# %% [markdown]
# There is a tree with nesting depth 161 in the corpus. The YAML serializer complained about it.
# I have cut of levels at depth 20.

# %% [markdown]
# ```
#     - '420030230011651':
#       - CL:
#         - conj: [Καὶ]
#         - CL:
#           - S:
#             - np:
#               - pron: [αὐτὸς]
#               - np:
#                 - noun: [Ἰησοῦς]
#           - V:
#             - vp:
#               - verb: [ἦν]
#               - vp:
#                 - verb: [ἀρχόμενος]
#           - ADV:
#             - np:
#               - advp:
#                 - adv: [ὡσεὶ]
#               - np:
#                 - np:
#                   - noun: [ἐτῶν]
#                 - nump:
#                   - num: ['τριάκοντα,']
#           - ADV:
#             - CL:
#               - CL:
#                 - conj: [ὡς]
#                 - CL:
#                   - V:
#                     - vp:
#                       - verb: ['ἐνομίζετο,']
#               - CL:
#                 - VC:
#                   - vp:
#                     - verb: [ὢν]
#                 - P:
#                   - np:
#                     - np:
#                       - noun: ['υἱός,']
#                     - np:
#                       - np:
#                         - noun: [Ἰωσὴφ]
#                       - np:
#                         - np:
#                           - det: [τοῦ]
#                         - np:
#                           - np:
#                             - noun: [Ἠλὶ]
#                           - np:
#                             - np:
#                               - det: [τοῦ]
#                             - np:
#                               - np:
#                                 - noun: [Μαθθὰτ]
#                               - np:
#                                 - np:
#                                   - det: [τοῦ]
#                                 - np:
#                                   - np:
#                                     - noun: [Λευὶ]
#                                   - np:
#                                     - np:
#                                       - det: [τοῦ]
#                                     - np:
#                                       - np:
#                                         - noun: [Μελχὶ]
#                                       - np:
#                                         - np:
#                                           - det: [τοῦ]
#                                         - np:
#                                           - np:
#                                             - noun: [Ἰανναὶ]
#                                           - np:
#                                             - np:
#                                               - det: [τοῦ]
#                                             - np:
#                                               - np:
#                                                 - {noun: ''}
#                                               - np:
#                                                 - {np: τοῦ}
#                                                 - {np: Ματταθίου τοῦ Ἀμὼς τοῦ Ναοὺμ
#                                                     τοῦ Ἑσλὶ τοῦ Ναγγαὶ τοῦ Μάαθ τοῦ
#                                                     Ματταθίου τοῦ Σεμεῒν τοῦ Ἰωσὴχ
#                                                     τοῦ Ἰωδὰ τοῦ Ἰωανὰν τοῦ Ῥησὰ τοῦ
#                                                     Ζοροβαβὲλ τοῦ Σαλαθιὴλ τοῦ Νηρὶ
#                                                     τοῦ Μελχὶ τοῦ Ἀδδὶ τοῦ Κωσὰμ τοῦ
#                                                     Ἐλμαδὰμ τοῦ Ἢρ τοῦ Ἰησοῦ τοῦ Ἐλιέζερ
#                                                     τοῦ Ἰωρὶμ τοῦ Μαθθὰτ τοῦ Λευὶ
#                                                     τοῦ Συμεὼν τοῦ Ἰούδα τοῦ Ἰωσὴφ
#                                                     τοῦ Ἰωνὰμ τοῦ Ἐλιακὶμ τοῦ Μελεὰ
#                                                     τοῦ Μεννὰ τοῦ Ματταθὰ τοῦ Ναθὰμ
#                                                     τοῦ Δαυὶδ τοῦ Ἰεσσαὶ τοῦ Ἰωβὴλ
#                                                     τοῦ Βόος τοῦ Σαλὰ τοῦ Ναασσὼν
#                                                     τοῦ Ἀμιναδὰβ τοῦ Ἀδμὶν τοῦ Ἀρνὶ
#                                                     τοῦ Ἑσρὼμ τοῦ Φαρὲς τοῦ Ἰούδα
#                                                     τοῦ Ἰακὼβ τοῦ Ἰσαὰκ τοῦ Ἀβραὰμ
#                                                     τοῦ Θάρα τοῦ Ναχὼρ τοῦ Σεροὺχ
#                                                     τοῦ Ῥαγαὺ τοῦ Φάλεκ τοῦ Ἔβερ τοῦ
#                                                     Σαλὰ τοῦ Καϊνὰμ τοῦ Ἀρφαξὰδ τοῦ
#                                                     Σὴμ τοῦ Νῶε τοῦ Λάμεχ τοῦ Μαθουσαλὰ
#                                                     τοῦ Ἑνὼχ τοῦ Ἰάρετ τοῦ Μαλελεὴλ
#                                                     τοῦ Καϊνὰμ τοῦ Ἐνὼς τοῦ Σὴθ τοῦ
#                                                     Ἀδὰμ τοῦ θεοῦ.}
# ```
