# %%
import sys
sys.path.append('..')
from tf.fabric import Fabric

# %%
TF = Fabric(locations='~/github/text-fabric-data/hebrew/etcbc4c')
# Out:
#   0.00s Looking for available data features:
#   0.01s   __otype__            from /Users/dirk/github/text-fabric/notebooks/__otype__.tf
#   0.01s   book                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/book.tf
#   0.01s   chapter              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/chapter.tf
#   0.01s   code                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/code.tf
#   0.01s   det                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/det.tf
#   0.01s   dist                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist.tf
#   0.01s   dist_unit            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist_unit.tf
#   0.01s   domain               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/domain.tf
#   0.01s   function             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/function.tf
#   0.01s   g_cons               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons.tf
#   0.01s   g_cons_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons_utf8.tf
#   0.01s   g_lex                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex.tf
#   0.01s   g_lex_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex_utf8.tf
#   0.01s   g_nme                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme.tf
#   0.01s   g_nme_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme_utf8.tf
#   0.02s   g_pfm                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm.tf
#   0.02s   g_pfm_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm_utf8.tf
#   0.02s   g_prs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs.tf
#   0.02s   g_prs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs_utf8.tf
#   0.02s   g_uvf                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf.tf
#   0.02s   g_uvf_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf_utf8.tf
#   0.02s   g_vbe                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe.tf
#   0.02s   g_vbe_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe_utf8.tf
#   0.02s   g_vbs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs.tf
#   0.02s   g_vbs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs_utf8.tf
#   0.02s   g_voc_lex            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex.tf
#   0.03s   g_voc_lex_utf8       from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex_utf8.tf
#   0.03s   g_word               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word.tf
#   0.03s   g_word_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word_utf8.tf
#   0.03s   gn                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/gn.tf
#   0.03s   is_root              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/is_root.tf
#   0.03s   kind                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/kind.tf
#   0.03s   label                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/label.tf
#   0.03s   language             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/language.tf
#   0.03s   lex                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex.tf
#   0.03s   lex_utf8             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex_utf8.tf
#   0.03s   ls                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ls.tf
#   0.03s   monads               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/monads.tf
#   0.03s   mother_object_type   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/mother_object_type.tf
#   0.03s   nme                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nme.tf
#   0.03s   nu                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nu.tf
#   0.04s   number               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/number.tf
#   0.04s   otype                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/otype.tf
#   0.04s   pdp                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pdp.tf
#   0.04s   pfm                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pfm.tf
#   0.04s   prs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs.tf
#   0.04s   prs_gn               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_gn.tf
#   0.04s   prs_nu               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_nu.tf
#   0.04s   prs_ps               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_ps.tf
#   0.04s   ps                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ps.tf
#   0.04s   qere                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere.tf
#   0.04s   qere_utf8            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere_utf8.tf
#   0.04s   rela                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/rela.tf
#   0.04s   sp                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/sp.tf
#   0.05s   st                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/st.tf
#   0.05s   tab                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/tab.tf
#   0.05s   trailer              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer.tf
#   0.05s   trailer_utf8         from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer_utf8.tf
#   0.05s   txt                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/txt.tf
#   0.05s   typ                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/typ.tf
#   0.05s   uvf                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/uvf.tf
#   0.06s   vbe                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbe.tf
#   0.06s   vbs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbs.tf
#   0.06s   verse                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/verse.tf
#   0.06s   vs                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vs.tf
#   0.06s   vt                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vt.tf
#   0.06s 66 features found

# %%
features = '''
code
det
dist
dist_unit
domain
function
g_cons
g_cons_utf8
g_lex
g_lex_utf8
g_nme
g_nme_utf8
g_pfm
g_pfm_utf8
g_prs
g_prs_utf8
g_uvf
g_uvf_utf8
g_vbe
g_vbe_utf8
g_vbs
g_vbs_utf8
g_voc_lex
g_voc_lex_utf8
g_word
g_word_utf8
gn
is_root
kind
language
lex
lex_utf8
ls
mother_object_type
nme
nu
number
pdp
pfm
prs
prs_gn
prs_nu
prs_ps
ps
qere
qere_utf8
rela
sp
st
tab
trailer
trailer_utf8
txt
typ
uvf
vbe
vbs
vs
vt
book
chapter
label
verse
'''

# %%
T = TF.load(features) # initial load, all binary data has to be generated. Only 3m 48s
# Out:
#    |     0.86s T otype                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/otype.tf
#    |     9.72s T monads               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/monads.tf
#    |      |     0.00s c __levels__           monad type = word; max monad = 426580; max node = 1436893
#    |      |     0.00s c __levels__           max node = 1436893
#    |      |     0.00s c __levels__           get ranking of otypes
#    |      |     0.95s c __levels__           results:
#    |      |      |    c __levels__           book           : 10937.97
#    |      |      |    c __levels__           chapter        : 459.18
#    |      |      |    c __levels__           verse          : 18.38
#    |      |      |    c __levels__           half_verse     : 9.44
#    |      |      |    c __levels__           sentence       : 6.71
#    |      |      |    c __levels__           sentence_atom  : 6.63
#    |      |      |    c __levels__           clause         : 4.85
#    |      |      |    c __levels__           clause_atom    : 4.71
#    |      |      |    c __levels__           phrase         : 1.68
#    |      |      |    c __levels__           phrase_atom    : 1.59
#    |      |      |    c __levels__           subphrase      : 1.42
#    |      |      |    c __levels__           word           :    1
#    |       12s C __levels__           from otype, monads
#    |      |     0.00s c __order__            monad type = word; max monad = 426580; max node = 1436893
#    |      |     0.00s c __order__            assigning otype levels to nodes
#    |      |     0.00s c __order__            sorting nodes
#    |       18s C __order__            from otype, monads, __levels__
#    |      |     0.00s c __rank__             monad type = word; max monad = 426580; max node = 1436893
#    |      |     0.00s c __rank__             ranking nodes
#    |     0.95s C __rank__             from otype, __order__
#    |      |     0.00s c __levUp__            monad type = word; max monad = 426580; max node = 1436893
#    |      |     0.00s c __levUp__            making inverse of edge feature monads
#    |      |     3.25s c __levUp__            listing embedders of all nodes
#    |       18s C __levUp__            from otype, monads, __rank__
#    |      |     0.00s c __levDown__          monad type = word; max monad = 426580; max node = 1436893
#    |      |     0.00s c __levDown__          inverting embedders
#    |      |     4.93s c __levDown__          turning embeddees into list
#    |       11s C __levDown__          from otype, __levUp__, __rank__
#    |     0.34s T code                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/code.tf
#    |     1.87s T det                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/det.tf
#    |     2.33s T dist                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist.tf
#    |     2.44s T dist_unit            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist_unit.tf
#    |     0.32s T domain               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/domain.tf
#    |     0.92s T function             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/function.tf
#    |     1.57s T g_cons               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons.tf
#    |     1.89s T g_cons_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons_utf8.tf
#    |     1.63s T g_lex                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex.tf
#    |     1.90s T g_lex_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex_utf8.tf
#    |     1.05s T g_nme                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme.tf
#    |     1.18s T g_nme_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme_utf8.tf
#    |     0.76s T g_pfm                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm.tf
#    |     0.75s T g_pfm_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm_utf8.tf
#    |     0.76s T g_prs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs.tf
#    |     0.78s T g_prs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs_utf8.tf
#    |     0.66s T g_uvf                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf.tf
#    |     0.72s T g_uvf_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf_utf8.tf
#    |     1.04s T g_vbe                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe.tf
#    |     0.74s T g_vbe_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe_utf8.tf
#    |     0.70s T g_vbs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs.tf
#    |     0.70s T g_vbs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs_utf8.tf
#    |     1.90s T g_voc_lex            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex.tf
#    |     2.44s T g_voc_lex_utf8       from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex_utf8.tf
#    |     1.82s T g_word               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word.tf
#    |     2.45s T g_word_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word_utf8.tf
#    |     1.94s T gn                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/gn.tf
#    |     0.32s T is_root              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/is_root.tf
#    |     0.32s T kind                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/kind.tf
#    |     1.71s T language             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/language.tf
#    |     1.93s T lex                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex.tf
#    |     2.33s T lex_utf8             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex_utf8.tf
#    |     1.60s T ls                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ls.tf
#    |     0.88s T mother_object_type   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/mother_object_type.tf
#    |     1.53s T nme                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nme.tf
#    |     1.59s T nu                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nu.tf
#    |     4.70s T number               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/number.tf
#    |     1.58s T pdp                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pdp.tf
#    |     1.56s T pfm                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pfm.tf
#    |     1.84s T prs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs.tf
#    |     1.61s T prs_gn               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_gn.tf
#    |     1.61s T prs_nu               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_nu.tf
#    |     1.60s T prs_ps               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_ps.tf
#    |     1.60s T ps                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ps.tf
#    |     0.66s T qere                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere.tf
#    |     0.84s T qere_utf8            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere_utf8.tf
#    |     2.82s T rela                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/rela.tf
#    |     1.58s T sp                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/sp.tf
#    |     1.52s T st                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/st.tf
#    |     0.31s T tab                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/tab.tf
#    |     1.23s T trailer              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer.tf
#    |     1.45s T trailer_utf8         from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer_utf8.tf
#    |     0.31s T txt                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/txt.tf
#    |     2.68s T typ                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/typ.tf
#    |     1.57s T uvf                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/uvf.tf
#    |     1.47s T vbe                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbe.tf
#    |     1.56s T vbs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbs.tf
#    |     1.59s T vs                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vs.tf
#    |     1.75s T vt                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vt.tf
#    |     0.10s T book                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/book.tf
#    |     0.09s T chapter              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/chapter.tf
#    |     0.24s T label                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/label.tf
#    |     0.09s T verse                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/verse.tf
#  3m 48s All features loaded/computed

# %%
T = TF.load(features) # subsequent load, all binary data available. Only 23s
# Out:
#    |     0.00s B __levels__           from otype, monads
#    |     0.07s B __order__            from otype, monads, __levels__
#    |     0.05s B __rank__             from otype, __order__
#    |     1.03s B __levUp__            from otype, monads, __rank__
#    |     0.83s B __levDown__          from otype, __levUp__, __rank__
#    |     0.03s B otype                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/otype.tf
#    |     0.50s B monads               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/monads.tf
#    |     0.04s B code                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/code.tf
#    |     0.16s B det                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/det.tf
#    |     0.15s B dist                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist.tf
#    |     0.19s B dist_unit            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/dist_unit.tf
#    |     0.02s B domain               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/domain.tf
#    |     0.13s B function             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/function.tf
#    |     0.30s B g_cons               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons.tf
#    |     0.28s B g_cons_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_cons_utf8.tf
#    |     0.19s B g_lex                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex.tf
#    |     0.21s B g_lex_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_lex_utf8.tf
#    |     0.10s B g_nme                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme.tf
#    |     0.13s B g_nme_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_nme_utf8.tf
#    |     0.09s B g_pfm                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm.tf
#    |     0.09s B g_pfm_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_pfm_utf8.tf
#    |     0.09s B g_prs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs.tf
#    |     0.09s B g_prs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_prs_utf8.tf
#    |     0.08s B g_uvf                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf.tf
#    |     0.08s B g_uvf_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_uvf_utf8.tf
#    |     0.08s B g_vbe                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe.tf
#    |     0.08s B g_vbe_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbe_utf8.tf
#    |     0.08s B g_vbs                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs.tf
#    |     0.08s B g_vbs_utf8           from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_vbs_utf8.tf
#    |     0.16s B g_voc_lex            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex.tf
#    |     0.24s B g_voc_lex_utf8       from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_voc_lex_utf8.tf
#    |     0.34s B g_word               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word.tf
#    |     0.31s B g_word_utf8          from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/g_word_utf8.tf
#    |     0.12s B gn                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/gn.tf
#    |     0.04s B is_root              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/is_root.tf
#    |     0.04s B kind                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/kind.tf
#    |     0.14s B language             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/language.tf
#    |     0.14s B lex                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex.tf
#    |     0.21s B lex_utf8             from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/lex_utf8.tf
#    |     0.14s B ls                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ls.tf
#    |     0.07s B mother_object_type   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/mother_object_type.tf
#    |     0.13s B nme                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nme.tf
#    |     0.29s B nu                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/nu.tf
#    |     0.55s B number               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/number.tf
#    |     0.14s B pdp                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pdp.tf
#    |     0.13s B pfm                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/pfm.tf
#    |     0.15s B prs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs.tf
#    |     0.15s B prs_gn               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_gn.tf
#    |     0.15s B prs_nu               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_nu.tf
#    |     0.15s B prs_ps               from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/prs_ps.tf
#    |     0.14s B ps                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/ps.tf
#    |     0.09s B qere                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere.tf
#    |     0.09s B qere_utf8            from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/qere_utf8.tf
#    |     0.24s B rela                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/rela.tf
#    |     0.20s B sp                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/sp.tf
#    |     0.24s B st                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/st.tf
#    |     0.04s B tab                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/tab.tf
#    |     0.18s B trailer              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer.tf
#    |     0.12s B trailer_utf8         from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/trailer_utf8.tf
#    |     0.03s B txt                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/txt.tf
#    |     0.26s B typ                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/typ.tf
#    |     0.14s B uvf                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/uvf.tf
#    |     0.14s B vbe                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbe.tf
#    |     0.14s B vbs                  from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vbs.tf
#    |     0.15s B vs                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vs.tf
#    |     0.21s B vt                   from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/vt.tf
#    |     0.02s B book                 from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/book.tf
#    |     0.01s B chapter              from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/chapter.tf
#    |     0.03s B label                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/label.tf
#    |     0.01s B verse                from /Users/dirk/github/text-fabric-data/hebrew/etcbc4c/verse.tf
#     23s All features loaded/computed
