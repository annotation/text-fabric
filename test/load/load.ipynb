# %%
import os
from tf.app import use

# %%
A = use('banks:clone', checkout='clone', hoist=globals(), mod='annotation/banks/sim/tf:clone')
# Out:
# **Locating corpus resources ...**
# The requested app is not available offline
# 	~/github/annotation/app-banks/code not found
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/banks/sim/tf</span>
#   0.00s Not all of the warp features otype and oslots are present in
# None/banks/.
# 	~/github/annotation/banks/sim/tf
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
# Traceback (most recent call last):
#   File "/Users/me/github/annotation/text-fabric/tf/advanced/app.py", line 587, in findApp
#     app = appClass(
#           ^^^^^^^^^
#   File "/Users/me/github/annotation/text-fabric/tf/advanced/app.py", line 213, in __init__
#     linksApi(self, silent=silent)
#   File "/Users/me/github/annotation/text-fabric/tf/advanced/links.py", line 180, in linksApi
#     header(app, allMeta=silent == VERBOSE)
# ...

# %%
C.levels.data
# Out:
# (('book', 99.0, 100, 100),
#  ('chapter', 49.5, 101, 102),
#  ('sentence', 27.5, 115, 116),
#  ('line', 7.666666666666667, 103, 114),
#  ('word', 1, 1, 99))

# %%
E.sim.meta
# Out:
# {'converters': 'Dirk Roorda',
#  'description': 'similarity between words, as a percentage of the common material wrt the combined material',
#  'name': 'Banks (similar words)',
#  'sourceUrl': 'https://nbviewer.jupyter.org/github/annotation/tutorials/blob/master/text-fabric/use.ipynb',
#  'valueType': 'int',
#  'version': '0.2',
#  'writtenBy': 'Text-Fabric',
#  'dateWritten': '2019-05-17T11:29:52Z'}

# %%
A = use("saulocantanhede/tfgreekexperiment:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/saulocantanhede/tfgreekexperiment/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/saulocantanhede/tfgreekexperiment/tf/0.3</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.8</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreekexperiment/blob/master/app" title="saulocantanhede/tfgreekexperiment app">saulocantanhede/tfgreekexperiment/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
s = F.otype.s("sentence")[0]
w = L.d(s, otype="word")[0]

# %%
T.text(s)
# Out:
# 'Βίβλος γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱοῦ Ἀβραάμ..'

# %%
A.plain(s)
# Out:
# <div class=""><span class="tfsechead "><span class="ltr">MAT 1:1</span></span>  <span class="txtu">Βίβλος </span><span class="txtu">γενέσεως </span><span class="txtu">Ἰησοῦ </span><span class="txtu">Χριστοῦ </span><span class="txtu">υἱοῦ </span><span class="txtu">Δαυεὶδ </span><span class="txtu">υἱοῦ </span><span class="txtu">Ἀβραάμ..</span></div>

# %%
F.text.v(w)

# %%
F.after.v(w)
# Out:
# ' '

# %%
F.otype.v(w)
# Out:
# 'word'

# %%
F.otype.v(1)
# Out:
# 'w'

# %%
A.pretty(1, multiFeatures=True)
# Out:
# <div class="tfsechead "><span class="ltr">MAT 1:1</span></div><div class=" children"><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Βίβλος</span></div><div class="features"><span class="text xft" ><span class="f">text=</span>Βίβλος</span></div></div></div>
