# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ```
#    |     1.58s T otype                from ~/github/clariah/wp6-missieven/tf/1.0
#    |       17s T oslots               from ~/github/clariah/wp6-missieven/tf/1.0
#    |       18s T punc                 from ~/github/clariah/wp6-missieven/tf/1.0
#    |       11s T punco                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.01s T title                from ~/github/clariah/wp6-missieven/tf/1.0
#    |       21s T trans                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.82s T transn               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.71s T puncn                from ~/github/clariah/wp6-missieven/tf/1.0
#    |       13s T transo               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     6.90s T transr               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     1.57s T n                    from ~/github/clariah/wp6-missieven/tf/1.0
#    |     5.85s T puncr                from ~/github/clariah/wp6-missieven/tf/1.0
#    |      |     0.21s C __levels__           from otype, oslots, otext
#    |      |       40s C __order__            from otype, oslots, __levels__
#    |      |     1.33s C __rank__             from otype, __order__
#    |      |       36s C __levUp__            from otype, oslots, __rank__
#    |      |     7.46s C __levDown__          from otype, __levUp__, __rank__
#    |      |     2.88s C __characters__       from otext
#    |      |       17s C __boundary__         from otype, oslots, __rank__
#    |      |     1.89s C __sections__         from otype, oslots, otext, __levUp__, __levels__, n, n, n
#    |      |     0.89s C __structure__        from otype, oslots, otext, __rank__, __levUp__, n, title, n
#    |     0.00s T author               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T authorFull           from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.06s T col                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T day                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.04s T facs                 from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.02s T isemph               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.03s T isfolio              from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.62s T isnote               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     9.27s T isorig               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.05s T isref                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     4.96s T isremark             from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T isspecial            from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T issub                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.03s T issuper              from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.01s T isund                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.04s T mark                 from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T month                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.08s T note                 from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T page                 from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T place                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T rawdate              from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.07s T row                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T seq                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T status               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.03s T tpl                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.03s T vol                  from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.00s T year                 from ~/github/clariah/wp6-missieven/tf/1.0
# ```

# %%
from tf.app import use
A = use("clariah/wp6-missieven:clone", checkout="clone", hoist=globals())
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/clariah/wp6-missieven/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/clariah/wp6-missieven/tf/1.0</span>
# This is Text-Fabric 9.4.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 40 features found and 0 ignored
#    |     1.41s T otype                from ~/github/clariah/wp6-missieven/tf/1.0
#    |       15s T oslots               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     5.55s T puncr                from ~/github/clariah/wp6-missieven/tf/1.0
#    |       20s T trans                from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.82s T transn               from ~/github/clariah/wp6-missieven/tf/1.0
#    |       12s T transo               from ~/github/clariah/wp6-missieven/tf/1.0
#    |     0.68s T puncn                from ~/github/clariah/wp6-missieven/tf/1.0
# ...

# %%
import numpy as np

# %%
a = np.array([(i % 10) + 2 for i in range(10000)])
b = np.array(['a' * ((i % 10) + 2) for i in range(10000)], dtype=np.str_)

# %%
c = ['a' * ((i % 10) + 2) for i in range(10000)]

# %%
# %timeit a.copy()
# Out:
# 2.75 µs ± 767 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit b.copy()
# Out:
# 13 µs ± 917 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit np.char.upper(b)
# Out:
# 4.15 ms ± 20.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit [x.upper() for x in c]
# Out:
# 452 µs ± 531 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit b = np.array(['a' * ((i % 10) + 2) for i in range(10000)], dtype=np.str_)
# Out:
# 3.01 ms ± 21 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit c = ['a' * ((i % 10) + 2) for i in range(10000)]
# Out:
# 729 µs ± 673 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
d = np.array([i % 10 + 2 for i in range(10000)], dtype=int)
e = [i % 10 + 2 for i in range(10000)]

# %%
# %timeit d + 10
# Out:
# 2.22 µs ± 6.25 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit [x + 10 for x in e]
# Out:
# 206 µs ± 1.05 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
