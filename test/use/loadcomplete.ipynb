# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %% [markdown]
# # BHSA

# %%
# B = use("ETCBC/bhsa:clone", checkout="clone")
B = use("ETCBC/bhsa:latest")
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>v1.8</b> is locally available
# <b title="latest release">app:</b> <span title="rv1.8=#gd905e3fb6e80d0fa537600337614adc2af157309">~/text-fabric-data/github/ETCBC/bhsa/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/ETCBC/bhsa/tf/2021 not found
# Status: latest release online <b>v1.8</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/ETCBC/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#gaba4367b49750089e4e4122415a77cac43bd97bc offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/ETCBC/phono/tf/2021</span>
# ...

# %% [raw]
# https://github.com/ETCBC/bhsa/releases/download/v1.8/complete.zip

# %%
B.repoLocation
# Out:
# '/Users/me/text-fabric-data/github/ETCBC/bhsa'

# %%
from tf.advanced.helpers import run

# %%
(good, stdErr, stdOut) = run("ls -l", workDir=B.repoLocation)
print(f"{good=}")
print(f"STDERR: {stdErr}")
print(f"STDOUT: {stdOut}")
# Out:
# good=True
# STDERR: total 0
# drwxr-xr-x   3 me  staff   96 Mar 23 12:32 _temp
# drwxr-xr-x   8 me  staff  256 Nov 11 14:50 app
# drwxr-xr-x   3 me  staff   96 Mar 23 12:33 pandas
# drwxr-xr-x  11 me  staff  352 Apr  6 16:39 tf
# STDOUT:

# %%
B.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (v1.8 157309)       : ~/github/ETCBC/bhsa/app
# 	OK       main data                (v1.8 157309)       : ~/github/ETCBC/bhsa/tf/2021
# 	OK       module phono             (v2.1 bd97bc)       : ~/github/ETCBC/phono/tf/2021
# 	OK       module parallels         (v2.1 cf333f)       : ~/github/ETCBC/parallels/tf/2021
# Writing zip file ...
# Result: ~/Downloads/github/ETCBC/bhsa/complete.zip

# %% [markdown]
# # Uruk

# %%
U = use("Nino-cunei/uruk:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/uruk/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/uruk/tf/1.0</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.0</a>, <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/app" title="Nino-cunei/uruk app">Nino-cunei/uruk/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
U.zipAll()
# Out:
# Data to be zipped:
# WARNING: no tags found.
# Maybe you have to do go to this repo and do `git pull --tags`
# We'll fect the commit anyway.
# 	OK       app                      (v?? 7a90e7)        : ~/github/Nino-cunei/uruk/app
# WARNING: no tags found.
# Maybe you have to do go to this repo and do `git pull --tags`
# We'll fect the commit anyway.
# 	OK       main data                (v?? 7a90e7)        : ~/github/Nino-cunei/uruk/tf/1.0
# WARNING: no tags found.
# Maybe you have to do go to this repo and do `git pull --tags`
# We'll fect the commit anyway.
# 	OK       graphics                 (v?? 7a90e7)        : ~/github/Nino-cunei/uruk/sources/cdli/images
# Writing zip file ...
# Result: ~/Downloads/github/Nino-cunei/uruk/complete.zip

# %%
U = use("Nino-cunei/uruk")
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#2ceef1cc30761c2bb9517cae1039bafceb6a7a5e offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/Nino-cunei/uruk/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0 not found
# Status: latest release online <b>v2.0</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0</span>
#    |     0.11s T otype                from ~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0
#    |     1.07s T oslots               from ~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0
#    |     0.02s T catalogId            from ~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0
#    |     0.13s T number               from ~/text-fabric-data/github/Nino-cunei/uruk/tf/1.0
# ...

# %% [markdown]
# # Banks

# %%
# A = use("annotation/banks:clone", checkout="clone")
A = use("annotation/banks")
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.1=#g5e28b54aaf679d5fbbbf7e879a6316f323b9d330 offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/annotation/banks/app</span>
# <b title="local release">data:</b> <span title="rv3.1=#g5e28b54aaf679d5fbbbf7e879a6316f323b9d330 offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/annotation/banks/tf/0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.0</a>, <a target="_blank" href="https://github.com/annotation/banks/blob/master/app" title="annotation/banks app">annotation/banks/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
A.showProvenance()
# Out:
#     <div class="pline">      <div class="pname">Job:</div><div class="pval">program code</div>
#     </div>
#     <div class="pline">
#       <div class="pname">Author:</div><div class="pval">program author</div>
#     </div>
#     <div class="pline">
#       <div class="pname">Created:</div><div class="pval">2023-04-11T17:08:28+02:00</div>
#     </div>
#         <div class="pline">
#       <div class="pname">Data:</div>
#       <div class="pval">Two quotes from Consider Phlebas by Iain M. Banks</div>
#     </div>
#     <div class="p2line">
#       <div class="pname">version</div>
#       <div class="pval">0.2</div>
#     </div>
#     <div class="p2line">
#       <div class="pname">release</div>
#       <div class="pval">v3.1</div>
#     </div>
#     <div class="p2line">
#       <div class="pname">download</div>
# ...

# %%
A.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (v3.1 b9d330)       : ~/github/annotation/banks/app
# 	OK       main data                (v3.1 b9d330)       : ~/github/annotation/banks/tf/0.2
# Result: ~/Downloads/github/annotation/banks/complete.zip

# %% [markdown]
# # Banks GitLab

# %%
A = use("annotation-huc/banks", backend="gitlab")
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv3.1=#5df379a68800729cc207cde836cd3ba77a0ed018 offline under /Users/me/text-fabric-data/gitlab">~/text-fabric-data/gitlab/annotation-huc/banks/app</span>
# <b title="local release">data:</b> <span title="rv3.1=#5df379a68800729cc207cde836cd3ba77a0ed018 offline under /Users/me/text-fabric-data/gitlab">~/text-fabric-data/gitlab/annotation-huc/banks/tf/0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.0</a>, <a target="_blank" href="https://gitlab.com/annotation-huc/banks/blob/master/app" title="annotation-huc/banks app">annotation-huc/banks/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %% [raw]
# https://gitlab.com/annotation-huc/banks/-/archive/v3.1/complete.zip

# %%
A.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (v3.1 b9d330)       : ~/github/annotation/banks/app
# 	OK       main data                (v3.1 b9d330)       : ~/github/annotation/banks/tf/0.2
# Writing zip file ...
# Result: ~/Downloads/github/annotation/banks/complete.zip

# %% [markdown]
# # Other corpora

# %%
X = use("annotation/mobydick:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/annotation/mobydick/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/annotation/mobydick/blob/main/app" title="annotation/mobydick app">annotation/mobydick/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("CLARIAH/descartes-tf:clone", checkout="clone")
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/descartes-tf/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/descartes-tf/tf/1.1</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/descartes-tf/parallels/tf/1.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/CLARIAH/descartes-tf/blob/master/app" title="CLARIAH/descartes-tf app">CLARIAH/descartes-tf/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (v1.1 7632e5)       : ~/github/CLARIAH/descartes-tf/app
# 	OK       main data                (v1.1 7632e5)       : ~/github/CLARIAH/descartes-tf/tf/1.1
# 	OK       graphics                 (v1.1 7632e5)       : ~/github/CLARIAH/descartes-tf/source/illustrations
# 	OK       module /parallels/tf     (v1.1 7632e5)       : ~/github/CLARIAH/descartes-tf/parallels/tf/1.1
# Writing zip file ...
# Result: ~/Downloads/github/CLARIAH/descartes-tf/complete.zip

# %%
X = use("CLARIAH/wp6-ferdinandhuyck:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-ferdinandhuyck/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-ferdinandhuyck/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/CLARIAH/wp6-ferdinandhuyck/blob/main/app" title="CLARIAH/wp6-ferdinandhuyck app">CLARIAH/wp6-ferdinandhuyck/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("CLARIAH/wp6-missieven:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-missieven/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-missieven/tf/1.0</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/CLARIAH/wp6-missieven/blob/master/app" title="CLARIAH/wp6-missieven app">CLARIAH/wp6-missieven/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("CLARIAH/wp6-daghregisters:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-daghregisters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-daghregisters/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/CLARIAH/wp6-daghregisters/blob/master/app" title="CLARIAH/wp6-daghregisters app">CLARIAH/wp6-daghregisters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("ETCBC/dhammapada:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/dhammapada/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/dhammapada/tf/0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/ETCBC/dhammapada/blob/master/app" title="ETCBC/dhammapada app">ETCBC/dhammapada/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("ETCBC/dss:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/dss/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/dss/tf/1.8.3</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/dss/parallels/tf/1.8.3</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/ETCBC/dss/blob/master/app" title="ETCBC/dss app">ETCBC/dss/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("ETCBC/peshitta:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/peshitta/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/peshitta/tf/0.2</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/ETCBC/peshitta/blob/master/app" title="ETCBC/peshitta app">ETCBC/peshitta/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("ETCBC/syrnt:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/syrnt/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/syrnt/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/ETCBC/syrnt/blob/master/app" title="ETCBC/syrnt app">ETCBC/syrnt/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("Nino-cunei/ninmed:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/ninmed/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/ninmed/tf/0.3</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/Nino-cunei/ninmed/blob/master/app" title="Nino-cunei/ninmed app">Nino-cunei/ninmed/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("Nino-cunei/oldassyrian:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/oldassyrian/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/oldassyrian/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/Nino-cunei/oldassyrian/blob/master/app" title="Nino-cunei/oldassyrian app">Nino-cunei/oldassyrian/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("Nino-cunei/oldbabylonian:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/oldbabylonian/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/Nino-cunei/oldbabylonian/tf/1.0.6</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/app" title="Nino-cunei/oldbabylonian app">Nino-cunei/oldbabylonian/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("q-ran/quran:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/q-ran/quran/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/q-ran/quran/tf/0.4</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/q-ran/quran/blob/master/app" title="q-ran/quran app">q-ran/quran/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
X = use("among/fusus:clone", checkout="clone")
X.zipAll()
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/among/fusus/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/among/fusus/tf/0.7</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/among/fusus/blob/master/app" title="among/fusus app">among/fusus/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...
