# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("CenterBLC/NA")
# Out:
# appName='CenterBLC/NA' appLoc=None dataLoc=None
# <b title="local release">TF-app:</b> <span title="rv1.0.24=#1416756d3b7c9aed1530d207d087ab30707f82cc offline under ~/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/NA/app</span>
# <b title="local release">data:</b> <span title="rv1.0.24=#1416756d3b7c9aed1530d207d087ab30707f82cc offline under ~/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/NA/tf/1904</span>
# ...

# %%
A = use("CenterBLC/NA", version="1904")
# Out:
# <b title="local release">TF-app:</b> <span title="rv1.0.24=#1416756d3b7c9aed1530d207d087ab30707f82cc offline under ~/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/NA/app</span>
# <b title="local release">data:</b> <span title="rv1.0.24=#1416756d3b7c9aed1530d207d087ab30707f82cc offline under ~/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/NA/tf/1904</span>
# ...

# %%
from tf.parameters import VERSION
print(VERSION)
# Out:
# 10.2.1
