# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("app:~/github/etcbc/dhammapada/app")
# Out:
# appName='app:~/github/etcbc/dhammapada/app' dataLoc=None
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("etcbc/dhammapada")
# Out:
# The requested TF-app is not available offline
# 	~/text-fabric-data/etcbc/dhammapada/app not found
# rate limit is 5000 requests per hour, with 4922 left for this hour
# 	connecting to online GitHub repo etcbc/dhammapada ... connected
# No directory app in #aa872b672057dafc3fa55663b8b611b876aad4fcWill try something else
# 	Failed	app/__init__.py...downloaded
# 	app/app.py...downloaded
# 	app/config.yaml...downloaded
# 	app/static...directory
# 		app/static/display.css...downloaded
# 		app/static/logo.png...downloaded
# 	OK
# <b title="latest commit">TF-app:</b> <span title="#192fe21dcd12424bf191e881230f52c5dee07fec">~/text-fabric-data/etcbc/dhammapada/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/etcbc/dhammapada/tf not found
# rate limit is 5000 requests per hour, with 4901 left for this hour
# 	connecting to online GitHub repo etcbc/dhammapada ... connected
# 	downloading https://github.com/ETCBC/dhammapada/releases/download/v0.2/tf-0.2.zip ...
# ...

# %%
A = use("etcbc/dhammapada/app")
# Out:
# appName='etcbc/dhammapada/app' dataLoc=None
# <b title="local commit">TF-app:</b> <span title="#c2cf30687c4ecf0d5fc5afe0d2033c65ab5c0b96 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("etcbc/dhammapada:local")
# Out:
# appName='etcbc/dhammapada' dataLoc=None
# <b title="local commit">TF-app:</b> <span title="#c2cf30687c4ecf0d5fc5afe0d2033c65ab5c0b96 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("etcbc/dhammapada:hot")
# Out:
# appName='etcbc/dhammapada' dataLoc=None
# rate limit is 5000 requests per hour, with 4988 left for this hour
# 	connecting to online GitHub repo etcbc/dhammapada ... connected
# <b title="latest commit">TF-app:</b> <span title="#c2cf30687c4ecf0d5fc5afe0d2033c65ab5c0b96">~/text-fabric-data/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("etcbc/dhammapada:clone")
# Out:
# appName='etcbc/dhammapada' dataLoc=None
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("dhammapada:clone")
# Out:
# appName='dhammapada' dataLoc=None
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-dhammapada/code</span>
# WARNING: in the future, pass `etcbc/dhammapada` instead of `dhammapada`
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("dhammapada:hot")
# Out:
# rate limit is 5000 requests per hour, with 4967 left for this hour
# 	connecting to online GitHub repo annotation/app-dhammapada ... connected
# <b title="latest commit">TF-app:</b> <span title="#c5a6da2795ac98b0a81504966317b22fa4ccea30">~/text-fabric-data/annotation/app-dhammapada/code</span>
# WARNING: in the future, pass `etcbc/dhammapada` instead of `dhammapada`
# rate limit is 5000 requests per hour, with 4964 left for this hour
# 	connecting to online GitHub repo etcbc/dhammapada ... connected
# <b title="latest commit">TF-app:</b> <span title="#c2cf30687c4ecf0d5fc5afe0d2033c65ab5c0b96">~/text-fabric-data/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use("dhammapada")
# Out:
# <b title="local commit">TF-app:</b> <span title="#c5a6da2795ac98b0a81504966317b22fa4ccea30 offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-dhammapada/code</span>
# WARNING: in the future, pass `etcbc/dhammapada` instead of `dhammapada`
# <b title="local commit">TF-app:</b> <span title="#c2cf30687c4ecf0d5fc5afe0d2033c65ab5c0b96 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/app</span>
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# ...

# %%
A = use(f"data:etcbc/dhammapada/tf:local", version="0.2")
# Out:
# appName=None dataLoc='etcbc/dhammapada/tf:local'
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> 0.2<br><b>Features:</b><br>
# <details><summary><b>etcbc/dhammapada/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dhammapada/tree/master/tf" title="~/text-fabric-data/etcbc/dhammapada/tf/0.2/clarity.tf">clarity</a>
# </div>
# <div class="fmono">int</div>
# <details>
# ...

# %%
A = use(f"data:etcbc/dhammapada/tf/0.2:local")
# Out:
# appName=None dataLoc='etcbc/dhammapada/tf/0.2:local'
# <b title="local release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc offline under ~/text-fabric-data">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> <br><b>Features:</b><br>
# <details><summary><b>etcbc/dhammapada/tf/0.2</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dhammapada/tree/master/tf/0.2" title="~/text-fabric-data/etcbc/dhammapada/tf/0.2//clarity.tf">clarity</a>
# </div>
# <div class="fmono">int</div>
# <details>
# ...

# %%
A = use(f"data:etcbc/dhammapada/tf/0.2:clone")
# Out:
# appName=None dataLoc='etcbc/dhammapada/tf/0.2:clone'
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> <br><b>Features:</b><br>
# <details><summary><b>etcbc/dhammapada/tf/0.2</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dhammapada/tree/master/tf/0.2" title="~/github/etcbc/dhammapada/tf/0.2//clarity.tf">clarity</a>
# </div>
# <div class="fmono">int</div>
# <details>
#     <summary>word is inserted for clarity, marked by inclusion in ( and ); only in Latin translation</summary>
# ...

# %%
A = use(f"data:etcbc/dhammapada/tf/0.2:latest")
# Out:
# appName=None dataLoc='etcbc/dhammapada/tf/0.2:latest'
# rate limit is 5000 requests per hour, with 4976 left for this hour
# 	connecting to online GitHub repo etcbc/dhammapada ... connected
# <b title="latest release">data:</b> <span title="rv0.2=#aa872b672057dafc3fa55663b8b611b876aad4fc">~/text-fabric-data/etcbc/dhammapada/tf/0.2</span>
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> <br><b>Features:</b><br>
# <details><summary><b>etcbc/dhammapada/tf/0.2</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# ...

# %%
A = use(f"data:~/github/etcbc/dhammapada/tf/0.2")
# Out:
# appName=None dataLoc='~/github/etcbc/dhammapada/tf/0.2'
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> ~/github/etcbc/dhammapada/tf/0.2<br><b>Features:</b><br>
# <details><summary><b>TF dataset (unspecified)</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/github/etcbc/dhammapada/tf/0.2//clarity.tf">clarity</span>
# </div>
# <div class="fmono">int</div>
# <details>
#     <summary>word is inserted for clarity, marked by inclusion in ( and ); only in Latin translation</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# ...

# %%
A = use(f"data:~/github/etcbc/dhammapada/tf", version="0.2")
# Out:
# appName=None dataLoc='~/github/etcbc/dhammapada/tf'
# This is Text-Fabric 9.1.13
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 16 features found and 0 ignored
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 9.1.13</a>, no app configured<br><b>Data:</b> ~/github/etcbc/dhammapada/tf/0.2<br><b>Features:</b><br>
# <details><summary><b>TF dataset (unspecified)</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/github/etcbc/dhammapada/tf/0.2/clarity.tf">clarity</span>
# </div>
# <div class="fmono">int</div>
# <details>
#     <summary>word is inserted for clarity, marked by inclusion in ( and ); only in Latin translation</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">converters:</div>
#     <div>Dirk Roorda (Text-Fabric)</div>
# </div>
#
# ...
