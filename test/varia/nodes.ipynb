# %%
from tf.app import use

# %%
A = use("ETCBC/bhsa", hoist=globals())
# Out:
# <b title="local commit">TF-app:</b> <span title="#11af8d2876bee74d7b70ff9ba0fe68e9b6ed4bce offline under ~/text-fabric-data/github">~/text-fabric-data/github/ETCBC/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.7.3=#af70cebe9d23ea736bb40e3ccd6768875b52a49d offline under ~/text-fabric-data/github">~/text-fabric-data/github/ETCBC/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#aba4367b49750089e4e4122415a77cac43bd97bc offline under ~/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#f45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under ~/text-fabric-data/github">~/text-fabric-data/github/ETCBC/parallels/tf/2021</span>
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 10.2.5</a>, <a target="_blank" href="https://github.com/ETCBC/bhsa/blob/master/app" title="ETCBC/bhsa TF-app">ETCBC/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://ETCBC.github.io/bhsa/0_home" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://ETCBC.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a><br><b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/ETCBC/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/ETCBC/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/book" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/code" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/det" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(atom) (det; und; NA.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/domain" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/freq_lex.tf">freq_lex</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ frequency of lexemes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/function" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ syntactic function of phrase (Cmpl; Objc; Pred; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_word" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_word.tf">g_word</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/g_word_utf8.tf">g_word_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/gloss" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> 🆗 english translation of lexeme (beginning create god(s))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/gn" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ grammatical gender (m; f; NA; unknown.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/label" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/label.tf">label</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ (half-)verse label (half verses: A; B; C; verses:  GEN 01,02)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/language" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/language.tf">language</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ of word or lexeme (Hebrew; Aramaic.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/lex" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/lex.tf">lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme consonantal-transliterated (B R>CJT/ BR>[ >LHJM/)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/lex_utf8" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/lex_utf8.tf">lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme consonantal-Hebrew (ב ראשׁית֜ ברא אלהים֜)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/ls" title="~/text-fabric-data/github/ETCBC/bhsa/tf/2021/ls.tf">ls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexical set, subclassification of part-of-speech (card; ques; mult)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://ETCBC.github.io/bhsa/features/nametyp
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# const copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %%
c1 = F.otype.s("chapter")[0]

# %%
for (node, boundary) in N.walk(nodes=L.d(c1), events=True):
    boundaryRep = "slot" if boundary is None else "end" if boundary else "start"
    nodeRep = f"{F.otype.v(node):<20} {node}"
    print(f"{boundaryRep:<5} {nodeRep}")
# Out:
# start verse                1414389
# start sentence             1172308
# start sentence_atom        1236025
# start clause               427559
# start clause_atom          515690
# start half_verse           606394
# start phrase               651573
# start phrase_atom          904776
# slot  word                 1
# slot  word                 2
# end   phrase_atom          904776
# end   phrase               651573
# start phrase               651574
# start phrase_atom          904777
# slot  word                 3
# end   phrase_atom          904777
# end   phrase               651574
# start phrase               651575
# start phrase_atom          904778
# slot  word                 4
# end   phrase_atom          904778
# end   phrase               651575
# end   half_verse           606394
# start half_verse           606395
# start phrase               651576
# start phrase_atom          904779
# start subphrase            1300539
# slot  word                 5
# slot  word                 6
# slot  word                 7
# end   subphrase            1300539
# slot  word                 8
# start subphrase            1300540
# slot  word                 9
# slot  word                 10
# slot  word                 11
# end   subphrase            1300540
# end   phrase_atom          904779
# end   phrase               651576
# end   half_verse           606395
# end   clause_atom          515690
# end   clause               427559
# end   sentence_atom        1236025
# end   sentence             1172308
# end   verse                1414389
# start verse                1414390
# start half_verse           606396
# start sentence             1172309
# start sentence_atom        1236026
# start clause               427560
# start clause_atom          515691
# start phrase               651577
# start phrase_atom          904780
# slot  word                 12
# end   phrase_atom          904780
# end   phrase               651577
# start phrase               651578
# start phrase_atom          904781
# slot  word                 13
# slot  word                 14
# end   phrase_atom          904781
# end   phrase               651578
# start phrase               651579
# start phrase_atom          904782
# slot  word                 15
# end   phrase_atom          904782
# end   phrase               651579
# start phrase               651580
# start phrase_atom          904783
# start subphrase            1300541
# slot  word                 16
# end   subphrase            1300541
# slot  word                 17
# start subphrase            1300542
# slot  word                 18
# end   subphrase            1300542
# end   phrase_atom          904783
# end   phrase               651580
# end   clause_atom          515691
# end   clause               427560
# end   sentence_atom        1236026
# end   sentence             1172309
# start sentence             1172310
# start sentence_atom        1236027
# start clause               427561
# start clause_atom          515692
# start phrase               651581
# start phrase_atom          904784
# slot  word                 19
# end   phrase_atom          904784
# end   phrase               651581
# start phrase               651582
# start phrase_atom          904785
# slot  word                 20
# end   phrase_atom          904785
# end   phrase               651582
# start phrase               651583
# start phrase_atom          904786
# slot  word                 21
# start subphrase            1300543
# slot  word                 22
# end   subphrase            1300543
# start subphrase            1300544
# slot  word                 23
# end   subphrase            1300544
# end   phrase_atom          904786
# end   phrase               651583
# end   clause_atom          515692
# end   clause               427561
# end   sentence_atom        1236027
# end   sentence             1172310
# end   half_verse           606396
# start half_verse           606397
# start sentence             1172311
# start sentence_atom        1236028
# start clause               427562
# start clause_atom          515693
# start phrase               651584
# start phrase_atom          904787
# slot  word                 24
# end   phrase_atom          904787
# end   phrase               651584
# start phrase               651585
# start phrase_atom          904788
# start subphrase            1300545
# slot  word                 25
# end   subphrase            1300545
# start subphrase            1300546
# slot  word                 26
# end   subphrase            1300546
# end   phrase_atom          904788
# end   phrase               651585
# start phrase               651586
# start phrase_atom          904789
# slot  word                 27
# end   phrase_atom          904789
# end   phrase               651586
# start phrase               651587
# start phrase_atom          904790
# slot  word                 28
# start subphrase            1300547
# slot  word                 29
# end   subphrase            1300547
# start subphrase            1300548
# slot  word                 30
# slot  word                 31
# end   subphrase            1300548
# end   phrase_atom          904790
# end   phrase               651587
# end   clause_atom          515693
# end   clause               427562
# end   sentence_atom        1236028
# end   sentence             1172311
# end   half_verse           606397
# end   verse                1414390
# start verse                1414391
# start half_verse           606398
# start sentence             1172312
# start sentence_atom        1236029
# start clause               427563
# start clause_atom          515694
# start phrase               651588
# start phrase_atom          904791
# slot  word                 32
# end   phrase_atom          904791
# end   phrase               651588
# start phrase               651589
# start phrase_atom          904792
# slot  word                 33
# end   phrase_atom          904792
# end   phrase               651589
# start phrase               651590
# start phrase_atom          904793
# slot  word                 34
# end   phrase_atom          904793
# end   phrase               651590
# end   clause_atom          515694
# end   clause               427563
# end   sentence_atom        1236029
# end   sentence             1172312
# start sentence             1172313
# start sentence_atom        1236030
# start clause               427564
# start clause_atom          515695
# start phrase               651591
# start phrase_atom          904794
# slot  word                 35
# end   phrase_atom          904794
# end   phrase               651591
# start phrase               651592
# start phrase_atom          904795
# slot  word                 36
# end   phrase_atom          904795
# end   phrase               651592
# end   clause_atom          515695
# end   clause               427564
# end   sentence_atom        1236030
# end   sentence             1172313
# end   half_verse           606398
# start half_verse           606399
# start sentence             1172314
# start sentence_atom        1236031
# start clause               427565
# start clause_atom          515696
# start phrase               651593
# start phrase_atom          904796
# slot  word                 37
# end   phrase_atom          904796
# end   phrase               651593
# start phrase               651594
# start phrase_atom          904797
# slot  word                 38
# end   phrase_atom          904797
# end   phrase               651594
# start phrase               651595
# start phrase_atom          904798
# slot  word                 39
# end   phrase_atom          904798
# end   phrase               651595
# end   clause_atom          515696
# end   clause               427565
# end   sentence_atom        1236031
# end   sentence             1172314
# end   half_verse           606399
# end   verse                1414391
# start verse                1414392
# start half_verse           606400
# start sentence             1172315
# start sentence_atom        1236032
# start clause               427566
# start clause_atom          515697
# start phrase               651596
# start phrase_atom          904799
# slot  word                 40
# end   phrase_atom          904799
# end   phrase               651596
# start phrase               651597
# start phrase_atom          904800
# slot  word                 41
# end   phrase_atom          904800
# end   phrase               651597
# start phrase               651598
# start phrase_atom          904801
# slot  word                 42
# end   phrase_atom          904801
# end   phrase               651598
# start phrase               651599
# start phrase_atom          904802
# slot  word                 43
# slot  word                 44
# slot  word                 45
# end   phrase_atom          904802
# end   phrase               651599
# end   clause_atom          515697
# end   clause               427566
# start clause               427567
# start clause_atom          515698
# start phrase               651600
# start phrase_atom          904803
# slot  word                 46
# end   phrase_atom          904803
# end   phrase               651600
# start phrase               651601
# start phrase_atom          904804
# slot  word                 47
# end   phrase_atom          904804
# end   phrase               651601
# end   clause_atom          515698
# end   clause               427567
# end   sentence_atom        1236032
# end   sentence             1172315
# end   half_verse           606400
# start half_verse           606401
# start sentence             1172316
# start sentence_atom        1236033
# start clause               427568
# start clause_atom          515699
# start phrase               651602
# start phrase_atom          904805
# slot  word                 48
# end   phrase_atom          904805
# end   phrase               651602
# start phrase               651603
# start phrase_atom          904806
# slot  word                 49
# end   phrase_atom          904806
# end   phrase               651603
# start phrase               651604
# start phrase_atom          904807
# slot  word                 50
# end   phrase_atom          904807
# end   phrase               651604
# start phrase               651605
# start phrase_atom          904808
# start subphrase            1300549
# slot  word                 51
# slot  word                 52
# slot  word                 53
# end   subphrase            1300549
# slot  word                 54
# start subphrase            1300550
# slot  word                 55
# slot  word                 56
# slot  word                 57
# end   subphrase            1300550
# end   phrase_atom          904808
# end   phrase               651605
# end   clause_atom          515699
# end   clause               427568
# end   sentence_atom        1236033
# end   sentence             1172316
# end   half_verse           606401
# end   verse                1414392
# start verse                1414393
# start half_verse           606402
# start sentence             1172317
# start sentence_atom        1236034
# start clause               427569
# start clause_atom          515700
# start phrase               651606
# start phrase_atom          904809
# slot  word                 58
# end   phrase_atom          904809
# end   phrase               651606
# start phrase               651607
# start phrase_atom          904810
# slot  word                 59
# end   phrase_atom          904810
# end   phrase               651607
# start phrase               651608
# start phrase_atom          904811
# slot  word                 60
# end   phrase_atom          904811
# end   phrase               651608
# start phrase               651609
# start phrase_atom          904812
# slot  word                 61
# slot  word                 62
# slot  word                 63
# end   phrase_atom          904812
# end   phrase               651609
# start phrase               651610
# start phrase_atom          904813
# slot  word                 64
# end   phrase_atom          904813
# end   phrase               651610
# end   clause_atom          515700
# end   clause               427569
# end   sentence_atom        1236034
# end   sentence             1172317
# start sentence             1172318
# start sentence_atom        1236035
# start clause               427570
# start clause_atom          515701
# start phrase               651611
# start phrase_atom          904814
# slot  word                 65
# end   phrase_atom          904814
# end   phrase               651611
# start phrase               651612
# start phrase_atom          904815
# slot  word                 66
# slot  word                 67
# slot  word                 68
# end   phrase_atom          904815
# end   phrase               651612
# start phrase               651613
# start phrase_atom          904816
# slot  word                 69
# end   phrase_atom          904816
# end   phrase               651613
# start phrase               651614
# start phrase_atom          904817
# slot  word                 70
# end   phrase_atom          904817
# end   phrase               651614
# end   clause_atom          515701
# end   clause               427570
# end   sentence_atom        1236035
# end   sentence             1172318
# end   half_verse           606402
# start half_verse           606403
# start sentence             1172319
# start sentence_atom        1236036
# start clause               427571
# start clause_atom          515702
# start phrase               651615
# start phrase_atom          904818
# slot  word                 71
# end   phrase_atom          904818
# end   phrase               651615
# start phrase               651616
# start phrase_atom          904819
# slot  word                 72
# end   phrase_atom          904819
# end   phrase               651616
# start phrase               651617
# start phrase_atom          904820
# slot  word                 73
# end   phrase_atom          904820
# end   phrase               651617
# end   clause_atom          515702
# end   clause               427571
# end   sentence_atom        1236036
# end   sentence             1172319
# start sentence             1172320
# start sentence_atom        1236037
# start clause               427572
# start clause_atom          515703
# start phrase               651618
# start phrase_atom          904821
# slot  word                 74
# end   phrase_atom          904821
# end   phrase               651618
# start phrase               651619
# start phrase_atom          904822
# slot  word                 75
# end   phrase_atom          904822
# end   phrase               651619
# start phrase               651620
# start phrase_atom          904823
# slot  word                 76
# end   phrase_atom          904823
# end   phrase               651620
# end   clause_atom          515703
# end   clause               427572
# end   sentence_atom        1236037
# end   sentence             1172320
# start sentence             1172321
# start sentence_atom        1236038
# start clause               427573
# start clause_atom          515704
# start phrase               651621
# start phrase_atom          904824
# start subphrase            1300551
# slot  word                 77
# end   subphrase            1300551
# start subphrase            1300552
# slot  word                 78
# end   subphrase            1300552
# end   phrase_atom          904824
# end   phrase               651621
# end   clause_atom          515704
# end   clause               427573
# end   sentence_atom        1236038
# end   sentence             1172321
# end   half_verse           606403
# end   verse                1414393
# start verse                1414394
# start half_verse           606404
# start sentence             1172322
# start sentence_atom        1236039
# start clause               427574
# start clause_atom          515705
# start phrase               651622
# start phrase_atom          904825
# slot  word                 79
# end   phrase_atom          904825
# end   phrase               651622
# start phrase               651623
# start phrase_atom          904826
# slot  word                 80
# end   phrase_atom          904826
# end   phrase               651623
# start phrase               651624
# start phrase_atom          904827
# slot  word                 81
# end   phrase_atom          904827
# end   phrase               651624
# end   clause_atom          515705
# end   clause               427574
# end   sentence_atom        1236039
# end   sentence             1172322
# start sentence             1172323
# start sentence_atom        1236040
# start clause               427575
# start clause_atom          515706
# start phrase               651625
# start phrase_atom          904828
# slot  word                 82
# end   phrase_atom          904828
# end   phrase               651625
# start phrase               651626
# start phrase_atom          904829
# slot  word                 83
# end   phrase_atom          904829
# end   phrase               651626
# start phrase               651627
# start phrase_atom          904830
# slot  word                 84
# start subphrase            1300553
# slot  word                 85
# end   subphrase            1300553
# start subphrase            1300554
# slot  word                 86
# slot  word                 87
# end   subphrase            1300554
# end   phrase_atom          904830
# end   phrase               651627
# end   clause_atom          515706
# end   clause               427575
# end   sentence_atom        1236040
# end   sentence             1172323
# end   half_verse           606404
# start half_verse           606405
# start sentence             1172324
# start sentence_atom        1236041
# start clause               427576
# start clause_atom          515707
# start phrase               651628
# start phrase_atom          904831
# slot  word                 88
# end   phrase_atom          904831
# end   phrase               651628
# start phrase               651629
# start phrase_atom          904832
# slot  word                 89
# end   phrase_atom          904832
# end   phrase               651629
# start phrase               651630
# start phrase_atom          904833
# slot  word                 90
# end   phrase_atom          904833
# end   phrase               651630
# start phrase               651631
# start phrase_atom          904834
# slot  word                 91
# slot  word                 92
# end   phrase_atom          904834
# start phrase_atom          904835
# slot  word                 93
# slot  word                 94
# end   phrase_atom          904835
# end   phrase               651631
# end   clause_atom          515707
# end   clause               427576
# end   sentence_atom        1236041
# end   sentence             1172324
# end   half_verse           606405
# end   verse                1414394
# start verse                1414395
# start half_verse           606406
# start sentence             1172325
# start sentence_atom        1236042
# start clause               427577
# start clause_atom          515708
# start phrase               651632
# start phrase_atom          904836
# slot  word                 95
# end   phrase_atom          904836
# end   phrase               651632
# start phrase               651633
# start phrase_atom          904837
# slot  word                 96
# end   phrase_atom          904837
# end   phrase               651633
# start phrase               651634
# start phrase_atom          904838
# slot  word                 97
# end   phrase_atom          904838
# end   phrase               651634
# start phrase               651635
# start phrase_atom          904839
# slot  word                 98
# slot  word                 99
# slot  word                 100
# end   phrase_atom          904839
# end   phrase               651635
# end   clause_atom          515708
# end   clause               427577
# end   sentence_atom        1236042
# end   sentence             1172325
# start sentence             1172326
# start sentence_atom        1236043
# start clause               427578
# start clause_atom          515709
# start phrase               651636
# start phrase_atom          904840
# slot  word                 101
# end   phrase_atom          904840
# end   phrase               651636
# start phrase               651637
# start phrase_atom          904841
# slot  word                 102
# end   phrase_atom          904841
# end   phrase               651637
# start phrase               651638
# start phrase_atom          904842
# slot  word                 103
# slot  word                 104
# slot  word                 105
# end   phrase_atom          904842
# end   clause_atom          515709
# start clause               427579
# start clause_atom          515710
# start phrase               651639
# start phrase_atom          904843
# slot  word                 106
# end   phrase_atom          904843
# end   phrase               651639
# start phrase               651640
# start phrase_atom          904844
# slot  word                 107
# slot  word                 108
# end   phrase_atom          904844
# start phrase_atom          904845
# slot  word                 109
# slot  word                 110
# slot  word                 111
# end   phrase_atom          904845
# end   phrase               651640
# end   clause_atom          515710
# end   clause               427579
# start clause_atom          515711
# start phrase_atom          904846
# slot  word                 112
# end   phrase_atom          904846
# start phrase_atom          904847
# slot  word                 113
# slot  word                 114
# slot  word                 115
# end   phrase_atom          904847
# end   clause_atom          515711
# end   phrase               651638
# end   clause               427578
# start clause               427580
# start clause_atom          515712
# start phrase               651641
# start phrase_atom          904848
# slot  word                 116
# end   phrase_atom          904848
# end   phrase               651641
# start phrase               651642
# start phrase_atom          904849
# slot  word                 117
# slot  word                 118
# slot  word                 119
# slot  word                 120
# slot  word                 121
# end   phrase_atom          904849
# end   phrase               651642
# end   clause_atom          515712
# end   clause               427580
# end   sentence_atom        1236043
# end   sentence             1172326
# end   half_verse           606406
# start half_verse           606407
# start sentence             1172327
# start sentence_atom        1236044
# start clause               427581
# start clause_atom          515713
# start phrase               651643
# start phrase_atom          904850
# slot  word                 122
# end   phrase_atom          904850
# end   phrase               651643
# start phrase               651644
# start phrase_atom          904851
# slot  word                 123
# end   phrase_atom          904851
# end   phrase               651644
# start phrase               651645
# start phrase_atom          904852
# slot  word                 124
# end   phrase_atom          904852
# end   phrase               651645
# end   clause_atom          515713
# end   clause               427581
# end   sentence_atom        1236044
# end   sentence             1172327
# end   half_verse           606407
# end   verse                1414395
# start verse                1414396
# start half_verse           606408
# start sentence             1172328
# start sentence_atom        1236045
# start clause               427582
# start clause_atom          515714
# start phrase               651646
# start phrase_atom          904853
# slot  word                 125
# end   phrase_atom          904853
# end   phrase               651646
# start phrase               651647
# start phrase_atom          904854
# slot  word                 126
# end   phrase_atom          904854
# end   phrase               651647
# start phrase               651648
# start phrase_atom          904855
# slot  word                 127
# end   phrase_atom          904855
# end   phrase               651648
# start phrase               651649
# start phrase_atom          904856
# slot  word                 128
# slot  word                 129
# slot  word                 130
# end   phrase_atom          904856
# end   phrase               651649
# start phrase               651650
# start phrase_atom          904857
# slot  word                 131
# end   phrase_atom          904857
# end   phrase               651650
# end   clause_atom          515714
# end   clause               427582
# end   sentence_atom        1236045
# end   sentence             1172328
# end   half_verse           606408
# start half_verse           606409
# start sentence             1172329
# start sentence_atom        1236046
# start clause               427583
# start clause_atom          515715
# start phrase               651651
# start phrase_atom          904858
# slot  word                 132
# end   phrase_atom          904858
# end   phrase               651651
# start phrase               651652
# start phrase_atom          904859
# slot  word                 133
# end   phrase_atom          904859
# end   phrase               651652
# start phrase               651653
# start phrase_atom          904860
# slot  word                 134
# end   phrase_atom          904860
# end   phrase               651653
# end   clause_atom          515715
# end   clause               427583
# end   sentence_atom        1236046
# end   sentence             1172329
# start sentence             1172330
# start sentence_atom        1236047
# start clause               427584
# start clause_atom          515716
# start phrase               651654
# start phrase_atom          904861
# slot  word                 135
# end   phrase_atom          904861
# end   phrase               651654
# start phrase               651655
# start phrase_atom          904862
# slot  word                 136
# end   phrase_atom          904862
# end   phrase               651655
# start phrase               651656
# start phrase_atom          904863
# slot  word                 137
# end   phrase_atom          904863
# end   phrase               651656
# end   clause_atom          515716
# end   clause               427584
# end   sentence_atom        1236047
# end   sentence             1172330
# start sentence             1172331
# start sentence_atom        1236048
# start clause               427585
# start clause_atom          515717
# start phrase               651657
# start phrase_atom          904864
# start subphrase            1300555
# slot  word                 138
# end   subphrase            1300555
# start subphrase            1300556
# slot  word                 139
# end   subphrase            1300556
# end   phrase_atom          904864
# end   phrase               651657
# end   clause_atom          515717
# end   clause               427585
# end   sentence_atom        1236048
# end   sentence             1172331
# end   half_verse           606409
# end   verse                1414396
# start verse                1414397
# start half_verse           606410
# start sentence             1172332
# start sentence_atom        1236049
# start clause               427586
# start clause_atom          515718
# start phrase               651658
# start phrase_atom          904865
# slot  word                 140
# end   phrase_atom          904865
# end   phrase               651658
# start phrase               651659
# start phrase_atom          904866
# slot  word                 141
# end   phrase_atom          904866
# end   phrase               651659
# start phrase               651660
# start phrase_atom          904867
# slot  word                 142
# end   phrase_atom          904867
# end   phrase               651660
# end   clause_atom          515718
# end   clause               427586
# end   sentence_atom        1236049
# end   sentence             1172332
# start sentence             1172333
# start sentence_atom        1236050
# start clause               427587
# start clause_atom          515719
# start phrase               651661
# start phrase_atom          904868
# slot  word                 143
# end   phrase_atom          904868
# end   phrase               651661
# start phrase               651662
# start phrase_atom          904869
# slot  word                 144
# slot  word                 145
# end   phrase_atom          904869
# start phrase_atom          904870
# slot  word                 146
# start subphrase            1300557
# slot  word                 147
# end   subphrase            1300557
# start subphrase            1300558
# slot  word                 148
# slot  word                 149
# end   subphrase            1300558
# end   phrase_atom          904870
# end   phrase               651662
# start phrase               651663
# start phrase_atom          904871
# slot  word                 150
# start subphrase            1300559
# slot  word                 151
# end   subphrase            1300559
# start subphrase            1300560
# slot  word                 152
# end   subphrase            1300560
# end   phrase_atom          904871
# end   phrase               651663
# end   clause_atom          515719
# end   clause               427587
# end   sentence_atom        1236050
# end   sentence             1172333
# start sentence             1172334
# start sentence_atom        1236051
# start clause               427588
# start clause_atom          515720
# start phrase               651664
# start phrase_atom          904872
# slot  word                 153
# end   phrase_atom          904872
# end   phrase               651664
# start phrase               651665
# start phrase_atom          904873
# slot  word                 154
# end   phrase_atom          904873
# end   phrase               651665
# start phrase               651666
# start phrase_atom          904874
# slot  word                 155
# slot  word                 156
# end   phrase_atom          904874
# end   phrase               651666
# end   clause_atom          515720
# end   clause               427588
# end   sentence_atom        1236051
# end   sentence             1172334
# end   half_verse           606410
# start half_verse           606411
# start sentence             1172335
# start sentence_atom        1236052
# start clause               427589
# start clause_atom          515721
# start phrase               651667
# start phrase_atom          904875
# slot  word                 157
# end   phrase_atom          904875
# end   phrase               651667
# start phrase               651668
# start phrase_atom          904876
# slot  word                 158
# end   phrase_atom          904876
# end   phrase               651668
# start phrase               651669
# start phrase_atom          904877
# slot  word                 159
# end   phrase_atom          904877
# end   phrase               651669
# end   clause_atom          515721
# end   clause               427589
# end   sentence_atom        1236052
# end   sentence             1172335
# end   half_verse           606411
# end   verse                1414397
# start verse                1414398
# start half_verse           606412
# start sentence             1172336
# start sentence_atom        1236053
# start clause               427590
# start clause_atom          515722
# start phrase               651670
# start phrase_atom          904878
# slot  word                 160
# end   phrase_atom          904878
# end   phrase               651670
# start phrase               651671
# start phrase_atom          904879
# slot  word                 161
# end   phrase_atom          904879
# end   phrase               651671
# start phrase               651672
# start phrase_atom          904880
# slot  word                 162
# end   phrase_atom          904880
# end   phrase               651672
# start phrase               651673
# start phrase_atom          904881
# slot  word                 163
# slot  word                 164
# slot  word                 165
# end   phrase_atom          904881
# end   phrase               651673
# start phrase               651674
# start phrase_atom          904882
# slot  word                 166
# end   phrase_atom          904882
# end   phrase               651674
# end   clause_atom          515722
# end   clause               427590
# end   sentence_atom        1236053
# end   sentence             1172336
# start sentence             1172337
# start sentence_atom        1236054
# start clause               427591
# start clause_atom          515723
# start phrase               651675
# start phrase_atom          904883
# slot  word                 167
# end   phrase_atom          904883
# end   phrase               651675
# start phrase               651676
# start phrase_atom          904884
# slot  word                 168
# start subphrase            1300561
# slot  word                 169
# end   subphrase            1300561
# start subphrase            1300562
# slot  word                 170
# slot  word                 171
# end   subphrase            1300562
# end   phrase_atom          904884
# end   phrase               651676
# start phrase               651677
# start phrase_atom          904885
# slot  word                 172
# end   phrase_atom          904885
# end   phrase               651677
# start phrase               651678
# start phrase_atom          904886
# slot  word                 173
# end   phrase_atom          904886
# end   phrase               651678
# end   clause_atom          515723
# end   clause               427591
# end   sentence_atom        1236054
# end   sentence             1172337
# end   half_verse           606412
# start half_verse           606413
# start sentence             1172338
# start sentence_atom        1236055
# start clause               427592
# start clause_atom          515724
# start phrase               651679
# start phrase_atom          904887
# slot  word                 174
# end   phrase_atom          904887
# end   phrase               651679
# start phrase               651680
# start phrase_atom          904888
# slot  word                 175
# end   phrase_atom          904888
# end   phrase               651680
# start phrase               651681
# start phrase_atom          904889
# slot  word                 176
# end   phrase_atom          904889
# end   phrase               651681
# end   clause_atom          515724
# end   clause               427592
# start clause               427593
# start clause_atom          515725
# start phrase               651682
# start phrase_atom          904890
# slot  word                 177
# end   phrase_atom          904890
# end   phrase               651682
# start phrase               651683
# start phrase_atom          904891
# slot  word                 178
# end   phrase_atom          904891
# end   phrase               651683
# end   clause_atom          515725
# end   clause               427593
# end   sentence_atom        1236055
# end   sentence             1172338
# end   half_verse           606413
# end   verse                1414398
# start verse                1414399
# start half_verse           606414
# start sentence             1172339
# start sentence_atom        1236056
# start clause               427594
# start clause_atom          515726
# start phrase               651684
# start phrase_atom          904892
# slot  word                 179
# end   phrase_atom          904892
# end   phrase               651684
# start phrase               651685
# start phrase_atom          904893
# slot  word                 180
# end   phrase_atom          904893
# end   phrase               651685
# start phrase               651686
# start phrase_atom          904894
# slot  word                 181
# end   phrase_atom          904894
# end   phrase               651686
# end   clause_atom          515726
# end   clause               427594
# end   sentence_atom        1236056
# end   sentence             1172339
# start sentence             1172340
# start sentence_atom        1236057
# start clause               427595
# start clause_atom          515727
# start phrase               651687
# start phrase_atom          904895
# slot  word                 182
# end   phrase_atom          904895
# end   phrase               651687
# start phrase               651688
# start phrase_atom          904896
# slot  word                 183
# slot  word                 184
# end   phrase_atom          904896
# end   phrase               651688
# start phrase               651689
# start phrase_atom          904897
# slot  word                 185
# end   phrase_atom          904897
# start phrase_atom          904898
# slot  word                 186
# end   phrase_atom          904898
# end   clause_atom          515727
# start clause               427596
# start clause_atom          515728
# start phrase               651690
# start phrase_atom          904899
# slot  word                 187
# end   phrase_atom          904899
# end   phrase               651690
# start phrase               651691
# start phrase_atom          904900
# slot  word                 188
# end   phrase_atom          904900
# end   phrase               651691
# end   clause_atom          515728
# end   clause               427596
# start clause_atom          515729
# start phrase_atom          904901
# start subphrase            1300563
# slot  word                 189
# end   subphrase            1300563
# start subphrase            1300564
# slot  word                 190
# end   subphrase            1300564
# end   phrase_atom          904901
# end   clause_atom          515729
# end   phrase               651689
# end   clause               427595
# start clause               427597
# start clause_atom          515730
# start phrase               651692
# start phrase_atom          904902
# slot  word                 191
# end   phrase_atom          904902
# end   phrase               651692
# start phrase               651693
# start phrase_atom          904903
# slot  word                 192
# end   phrase_atom          904903
# end   phrase               651693
# start phrase               651694
# start phrase_atom          904904
# slot  word                 193
# slot  word                 194
# end   phrase_atom          904904
# end   phrase               651694
# end   clause_atom          515730
# start clause               427598
# start clause_atom          515731
# start phrase               651695
# start phrase_atom          904905
# slot  word                 195
# end   phrase_atom          904905
# end   phrase               651695
# start phrase               651696
# start phrase_atom          904906
# slot  word                 196
# end   phrase_atom          904906
# end   phrase               651696
# start phrase               651697
# start phrase_atom          904907
# slot  word                 197
# end   phrase_atom          904907
# end   phrase               651697
# end   clause_atom          515731
# end   clause               427598
# start clause_atom          515732
# start phrase               651698
# start phrase_atom          904908
# slot  word                 198
# slot  word                 199
# slot  word                 200
# end   phrase_atom          904908
# end   phrase               651698
# end   clause_atom          515732
# end   clause               427597
# end   sentence_atom        1236057
# end   sentence             1172340
# end   half_verse           606414
# start half_verse           606415
# start sentence             1172341
# start sentence_atom        1236058
# start clause               427599
# start clause_atom          515733
# start phrase               651699
# start phrase_atom          904909
# slot  word                 201
# end   phrase_atom          904909
# end   phrase               651699
# start phrase               651700
# start phrase_atom          904910
# slot  word                 202
# end   phrase_atom          904910
# end   phrase               651700
# start phrase               651701
# start phrase_atom          904911
# slot  word                 203
# end   phrase_atom          904911
# end   phrase               651701
# end   clause_atom          515733
# end   clause               427599
# end   sentence_atom        1236058
# end   sentence             1172341
# end   half_verse           606415
# end   verse                1414399
# start verse                1414400
# start half_verse           606416
# start sentence             1172342
# start sentence_atom        1236059
# start clause               427600
# start clause_atom          515734
# start phrase               651702
# start phrase_atom          904912
# slot  word                 204
# end   phrase_atom          904912
# end   phrase               651702
# start phrase               651703
# start phrase_atom          904913
# slot  word                 205
# end   phrase_atom          904913
# end   phrase               651703
# start phrase               651704
# start phrase_atom          904914
# slot  word                 206
# slot  word                 207
# end   phrase_atom          904914
# end   phrase               651704
# start phrase               651705
# start phrase_atom          904915
# slot  word                 208
# end   phrase_atom          904915
# start phrase_atom          904916
# slot  word                 209
# end   phrase_atom          904916
# end   clause_atom          515734
# start clause               427601
# start clause_atom          515735
# start phrase               651706
# start phrase_atom          904917
# slot  word                 210
# end   phrase_atom          904917
# end   phrase               651706
# start phrase               651707
# start phrase_atom          904918
# slot  word                 211
# end   phrase_atom          904918
# end   phrase               651707
# start phrase               651708
# start phrase_atom          904919
# slot  word                 212
# slot  word                 213
# end   phrase_atom          904919
# end   phrase               651708
# end   clause_atom          515735
# end   clause               427601
# start clause_atom          515736
# start phrase_atom          904920
# slot  word                 214
# end   phrase_atom          904920
# start phrase_atom          904921
# slot  word                 215
# end   phrase_atom          904921
# end   clause_atom          515736
# end   phrase               651705
# end   clause               427600
# start clause               427602
# start clause_atom          515737
# start phrase               651709
# start phrase_atom          904922
# slot  word                 216
# end   phrase_atom          904922
# end   phrase               651709
# start phrase               651710
# start phrase_atom          904923
# slot  word                 217
# end   phrase_atom          904923
# end   phrase               651710
# end   clause_atom          515737
# start clause               427603
# start clause_atom          515738
# start phrase               651711
# start phrase_atom          904924
# slot  word                 218
# end   phrase_atom          904924
# end   phrase               651711
# start phrase               651712
# start phrase_atom          904925
# slot  word                 219
# end   phrase_atom          904925
# end   phrase               651712
# start phrase               651713
# start phrase_atom          904926
# slot  word                 220
# end   phrase_atom          904926
# end   phrase               651713
# end   clause_atom          515738
# end   clause               427603
# start clause_atom          515739
# start phrase               651714
# start phrase_atom          904927
# slot  word                 221
# slot  word                 222
# end   phrase_atom          904927
# end   phrase               651714
# end   clause_atom          515739
# end   clause               427602
# end   sentence_atom        1236059
# end   sentence             1172342
# end   half_verse           606416
# start half_verse           606417
# start sentence             1172343
# start sentence_atom        1236060
# start clause               427604
# start clause_atom          515740
# start phrase               651715
# start phrase_atom          904928
# slot  word                 223
# end   phrase_atom          904928
# end   phrase               651715
# start phrase               651716
# start phrase_atom          904929
# slot  word                 224
# end   phrase_atom          904929
# end   phrase               651716
# start phrase               651717
# start phrase_atom          904930
# slot  word                 225
# end   phrase_atom          904930
# end   phrase               651717
# end   clause_atom          515740
# end   clause               427604
# start clause               427605
# start clause_atom          515741
# start phrase               651718
# start phrase_atom          904931
# slot  word                 226
# end   phrase_atom          904931
# end   phrase               651718
# start phrase               651719
# start phrase_atom          904932
# slot  word                 227
# end   phrase_atom          904932
# end   phrase               651719
# end   clause_atom          515741
# end   clause               427605
# end   sentence_atom        1236060
# end   sentence             1172343
# end   half_verse           606417
# end   verse                1414400
# start verse                1414401
# start half_verse           606418
# start sentence             1172344
# start sentence_atom        1236061
# start clause               427606
# start clause_atom          515742
# start phrase               651720
# start phrase_atom          904933
# slot  word                 228
# end   phrase_atom          904933
# end   phrase               651720
# start phrase               651721
# start phrase_atom          904934
# slot  word                 229
# end   phrase_atom          904934
# end   phrase               651721
# start phrase               651722
# start phrase_atom          904935
# slot  word                 230
# end   phrase_atom          904935
# end   phrase               651722
# end   clause_atom          515742
# end   clause               427606
# end   sentence_atom        1236061
# end   sentence             1172344
# start sentence             1172345
# start sentence_atom        1236062
# start clause               427607
# start clause_atom          515743
# start phrase               651723
# start phrase_atom          904936
# slot  word                 231
# end   phrase_atom          904936
# end   phrase               651723
# start phrase               651724
# start phrase_atom          904937
# slot  word                 232
# end   phrase_atom          904937
# end   phrase               651724
# start phrase               651725
# start phrase_atom          904938
# slot  word                 233
# end   phrase_atom          904938
# end   phrase               651725
# end   clause_atom          515743
# end   clause               427607
# end   sentence_atom        1236062
# end   sentence             1172345
# start sentence             1172346
# start sentence_atom        1236063
# start clause               427608
# start clause_atom          515744
# start phrase               651726
# start phrase_atom          904939
# start subphrase            1300565
# slot  word                 234
# end   subphrase            1300565
# start subphrase            1300566
# slot  word                 235
# end   subphrase            1300566
# end   phrase_atom          904939
# end   phrase               651726
# end   clause_atom          515744
# end   clause               427608
# end   sentence_atom        1236063
# end   sentence             1172346
# end   half_verse           606418
# end   verse                1414401
# start verse                1414402
# start half_verse           606419
# start sentence             1172347
# start sentence_atom        1236064
# start clause               427609
# start clause_atom          515745
# start phrase               651727
# start phrase_atom          904940
# slot  word                 236
# end   phrase_atom          904940
# end   phrase               651727
# start phrase               651728
# start phrase_atom          904941
# slot  word                 237
# end   phrase_atom          904941
# end   phrase               651728
# start phrase               651729
# start phrase_atom          904942
# slot  word                 238
# end   phrase_atom          904942
# end   phrase               651729
# end   clause_atom          515745
# end   clause               427609
# end   sentence_atom        1236064
# end   sentence             1172347
# start sentence             1172348
# start sentence_atom        1236065
# start clause               427610
# start clause_atom          515746
# start phrase               651730
# start phrase_atom          904943
# slot  word                 239
# end   phrase_atom          904943
# end   phrase               651730
# start phrase               651731
# start phrase_atom          904944
# slot  word                 240
# end   phrase_atom          904944
# end   phrase               651731
# start phrase               651732
# start phrase_atom          904945
# slot  word                 241
# start subphrase            1300567
# slot  word                 242
# end   subphrase            1300567
# start subphrase            1300568
# slot  word                 243
# slot  word                 244
# end   subphrase            1300568
# end   phrase_atom          904945
# end   phrase               651732
# end   clause_atom          515746
# end   clause               427610
# start clause               427611
# start clause_atom          515747
# start phrase               651733
# start phrase_atom          904946
# slot  word                 245
# slot  word                 246
# end   phrase_atom          904946
# ...
# slot  word                 586
# end   phrase_atom          905124
# end   phrase               651900
# start phrase               651901
# start phrase_atom          905125
# slot  word                 587
# slot  word                 588
# slot  word                 589
# end   phrase_atom          905125
# end   phrase               651901
# end   clause_atom          515805
# end   clause               427668
# end   sentence_atom        1236105
# end   sentence             1172388
# end   half_verse           606446
# end   verse                1414416
# start verse                1414417
# start half_verse           606447
# start sentence             1172389
# start sentence_atom        1236106
# start clause               427669
# start clause_atom          515806
# start phrase               651902
# start phrase_atom          905126
# slot  word                 590
# end   phrase_atom          905126
# end   phrase               651902
# start phrase               651903
# start phrase_atom          905127
# slot  word                 591
# end   phrase_atom          905127
# end   phrase               651903
# start phrase               651904
# start phrase_atom          905128
# slot  word                 592
# end   phrase_atom          905128
# end   phrase               651904
# end   clause_atom          515806
# end   clause               427669
# end   sentence_atom        1236106
# end   sentence             1172389
# start sentence             1172390
# start sentence_atom        1236107
# start clause               427670
# start clause_atom          515807
# start phrase               651905
# start phrase_atom          905129
# slot  word                 593
# end   phrase_atom          905129
# end   phrase               651905
# start phrase               651906
# start phrase_atom          905130
# slot  word                 594
# end   phrase_atom          905130
# end   phrase               651906
# start phrase               651907
# start phrase_atom          905131
# slot  word                 595
# end   phrase_atom          905131
# end   phrase               651907
# start phrase               651908
# start phrase_atom          905132
# slot  word                 596
# start subphrase            1300661
# slot  word                 597
# end   subphrase            1300661
# start subphrase            1300662
# slot  word                 598
# end   subphrase            1300662
# end   phrase_atom          905132
# end   clause_atom          515807
# start clause               427671
# start clause_atom          515808
# start phrase               651909
# start phrase_atom          905133
# slot  word                 599
# end   phrase_atom          905133
# end   phrase               651909
# start phrase               651910
# start phrase_atom          905134
# slot  word                 600
# end   phrase_atom          905134
# end   phrase               651910
# end   clause_atom          515808
# end   clause               427671
# start clause               427672
# start clause_atom          515809
# start phrase               651911
# start phrase_atom          905135
# slot  word                 601
# end   phrase_atom          905135
# end   phrase               651911
# start phrase               651912
# start phrase_atom          905136
# slot  word                 602
# start subphrase            1300663
# slot  word                 603
# end   subphrase            1300663
# start subphrase            1300666
# start subphrase            1300664
# slot  word                 604
# end   subphrase            1300664
# start subphrase            1300665
# slot  word                 605
# slot  word                 606
# end   subphrase            1300665
# end   subphrase            1300666
# end   phrase_atom          905136
# end   phrase               651912
# end   clause_atom          515809
# end   clause               427672
# start clause_atom          515810
# start phrase_atom          905137
# slot  word                 607
# end   phrase_atom          905137
# start phrase_atom          905138
# slot  word                 608
# start subphrase            1300667
# slot  word                 609
# end   subphrase            1300667
# start subphrase            1300668
# slot  word                 610
# slot  word                 611
# end   subphrase            1300668
# end   phrase_atom          905138
# end   clause_atom          515810
# end   phrase               651908
# end   clause               427670
# start clause               427673
# start clause_atom          515811
# start phrase               651913
# start phrase_atom          905139
# slot  word                 612
# end   phrase_atom          905139
# end   phrase               651913
# start phrase               651914
# start phrase_atom          905140
# slot  word                 613
# end   phrase_atom          905140
# end   phrase               651914
# start phrase               651915
# start phrase_atom          905141
# start subphrase            1300669
# slot  word                 614
# end   subphrase            1300669
# start subphrase            1300670
# slot  word                 615
# end   subphrase            1300670
# end   phrase_atom          905141
# end   phrase               651915
# end   clause_atom          515811
# end   clause               427673
# start clause               427674
# start clause_atom          515812
# start phrase               651916
# start phrase_atom          905142
# slot  word                 616
# end   phrase_atom          905142
# end   phrase               651916
# start phrase               651917
# start phrase_atom          905143
# slot  word                 617
# end   phrase_atom          905143
# end   phrase               651917
# end   clause_atom          515812
# end   clause               427674
# end   sentence_atom        1236107
# end   half_verse           606447
# start half_verse           606448
# start sentence             1172391
# start sentence_atom        1236108
# start clause               427675
# start clause_atom          515813
# start phrase               651918
# start phrase_atom          905144
# slot  word                 618
# end   phrase_atom          905144
# end   phrase               651918
# start phrase               651919
# start phrase_atom          905145
# slot  word                 619
# end   phrase_atom          905145
# end   phrase               651919
# start phrase               651920
# start phrase_atom          905146
# slot  word                 620
# slot  word                 621
# end   phrase_atom          905146
# end   phrase               651920
# end   clause_atom          515813
# end   clause               427675
# end   sentence_atom        1236108
# end   sentence             1172391
# end   half_verse           606448
# end   verse                1414417
# start verse                1414418
# start half_verse           606449
# start sentence_atom        1236109
# start clause               427676
# start clause_atom          515814
# start phrase               651921
# start phrase_atom          905147
# slot  word                 622
# end   phrase_atom          905147
# end   phrase               651921
# start phrase               651922
# start phrase_atom          905148
# start subphrase            1300675
# slot  word                 623
# start subphrase            1300671
# slot  word                 624
# end   subphrase            1300671
# start subphrase            1300674
# start subphrase            1300672
# slot  word                 625
# end   subphrase            1300672
# start subphrase            1300673
# slot  word                 626
# slot  word                 627
# end   subphrase            1300673
# end   subphrase            1300674
# end   subphrase            1300675
# slot  word                 628
# start subphrase            1300680
# slot  word                 629
# start subphrase            1300676
# slot  word                 630
# end   subphrase            1300676
# start subphrase            1300679
# start subphrase            1300677
# slot  word                 631
# end   subphrase            1300677
# start subphrase            1300678
# slot  word                 632
# slot  word                 633
# end   subphrase            1300678
# end   subphrase            1300679
# end   subphrase            1300680
# slot  word                 634
# slot  word                 635
# start subphrase            1300681
# slot  word                 636
# end   subphrase            1300681
# start subphrase            1300682
# slot  word                 637
# end   subphrase            1300682
# end   phrase_atom          905148
# start phrase_atom          905149
# slot  word                 638
# slot  word                 639
# slot  word                 640
# end   phrase_atom          905149
# end   phrase               651922
# end   clause_atom          515814
# start clause               427677
# start clause_atom          515815
# start phrase               651923
# start phrase_atom          905150
# slot  word                 641
# end   phrase_atom          905150
# end   phrase               651923
# start phrase               651924
# start phrase_atom          905151
# slot  word                 642
# end   phrase_atom          905151
# end   phrase               651924
# start phrase               651925
# start phrase_atom          905152
# start subphrase            1300683
# slot  word                 643
# end   subphrase            1300683
# start subphrase            1300684
# slot  word                 644
# end   subphrase            1300684
# end   phrase_atom          905152
# end   phrase               651925
# end   clause_atom          515815
# end   clause               427677
# start clause_atom          515816
# start phrase               651926
# start phrase_atom          905153
# slot  word                 645
# start subphrase            1300685
# slot  word                 646
# end   subphrase            1300685
# start subphrase            1300688
# start subphrase            1300686
# slot  word                 647
# end   subphrase            1300686
# start subphrase            1300687
# slot  word                 648
# end   subphrase            1300687
# end   subphrase            1300688
# end   phrase_atom          905153
# end   phrase               651926
# start phrase               651927
# start phrase_atom          905154
# slot  word                 649
# slot  word                 650
# end   phrase_atom          905154
# end   phrase               651927
# end   clause_atom          515816
# end   clause               427676
# end   sentence_atom        1236109
# end   half_verse           606449
# end   sentence             1172390
# start half_verse           606450
# start sentence             1172392
# start sentence_atom        1236110
# start clause               427678
# start clause_atom          515817
# start phrase               651928
# start phrase_atom          905155
# slot  word                 651
# end   phrase_atom          905155
# end   phrase               651928
# start phrase               651929
# start phrase_atom          905156
# slot  word                 652
# end   phrase_atom          905156
# end   phrase               651929
# start phrase               651930
# start phrase_atom          905157
# slot  word                 653
# end   phrase_atom          905157
# end   phrase               651930
# end   clause_atom          515817
# end   clause               427678
# end   sentence_atom        1236110
# end   sentence             1172392
# end   half_verse           606450
# end   verse                1414418
# start verse                1414419
# start half_verse           606451
# start sentence             1172393
# start sentence_atom        1236111
# start clause               427679
# start clause_atom          515818
# start phrase               651931
# start phrase_atom          905158
# slot  word                 654
# end   phrase_atom          905158
# end   phrase               651931
# start phrase               651932
# start phrase_atom          905159
# slot  word                 655
# end   phrase_atom          905159
# end   phrase               651932
# start phrase               651933
# start phrase_atom          905160
# slot  word                 656
# end   phrase_atom          905160
# end   phrase               651933
# start phrase               651934
# start phrase_atom          905161
# slot  word                 657
# slot  word                 658
# end   phrase_atom          905161
# end   phrase               651934
# end   clause_atom          515818
# end   clause               427679
# start clause               427680
# start clause_atom          515819
# start phrase               651935
# start phrase_atom          905162
# slot  word                 659
# end   phrase_atom          905162
# end   phrase               651935
# start phrase               651936
# start phrase_atom          905163
# slot  word                 660
# end   phrase_atom          905163
# end   phrase               651936
# end   clause_atom          515819
# end   clause               427680
# end   sentence_atom        1236111
# end   sentence             1172393
# start sentence             1172394
# start sentence_atom        1236112
# start clause               427681
# start clause_atom          515820
# start phrase               651937
# start phrase_atom          905164
# slot  word                 661
# end   phrase_atom          905164
# end   phrase               651937
# start phrase               651938
# start phrase_atom          905165
# slot  word                 662
# end   phrase_atom          905165
# end   phrase               651938
# start phrase               651939
# start phrase_atom          905166
# slot  word                 663
# end   phrase_atom          905166
# end   phrase               651939
# start phrase               651940
# start phrase_atom          905167
# slot  word                 664
# end   phrase_atom          905167
# end   phrase               651940
# end   clause_atom          515820
# end   clause               427681
# end   sentence_atom        1236112
# end   sentence             1172394
# end   half_verse           606451
# start half_verse           606452
# start sentence             1172395
# start sentence_atom        1236113
# start clause               427682
# start clause_atom          515821
# start phrase               651941
# start phrase_atom          905168
# slot  word                 665
# end   phrase_atom          905168
# end   phrase               651941
# start phrase               651942
# start phrase_atom          905169
# slot  word                 666
# end   phrase_atom          905169
# end   phrase               651942
# start phrase               651943
# start phrase_atom          905170
# slot  word                 667
# end   phrase_atom          905170
# end   phrase               651943
# end   clause_atom          515821
# end   clause               427682
# end   sentence_atom        1236113
# end   sentence             1172395
# start sentence             1172396
# start sentence_atom        1236114
# start clause               427683
# start clause_atom          515822
# start phrase               651944
# start phrase_atom          905171
# slot  word                 668
# end   phrase_atom          905171
# end   phrase               651944
# start phrase               651945
# start phrase_atom          905172
# slot  word                 669
# end   phrase_atom          905172
# end   phrase               651945
# start phrase               651946
# start phrase_atom          905173
# slot  word                 670
# end   phrase_atom          905173
# end   phrase               651946
# end   clause_atom          515822
# end   clause               427683
# end   sentence_atom        1236114
# end   sentence             1172396
# start sentence             1172397
# start sentence_atom        1236115
# start clause               427684
# start clause_atom          515823
# start phrase               651947
# start phrase_atom          905174
# start subphrase            1300689
# slot  word                 671
# end   subphrase            1300689
# start subphrase            1300690
# slot  word                 672
# slot  word                 673
# end   subphrase            1300690
# end   phrase_atom          905174
# end   phrase               651947
# end   clause_atom          515823
# end   clause               427684
# end   sentence_atom        1236115
# end   sentence             1172397
# end   half_verse           606452
# end   verse                1414419
# end   chapter              426630
