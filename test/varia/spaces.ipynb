# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("DT-UCPH/sp:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/DT-UCPH/sp/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/DT-UCPH/sp/tf/2.3</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.2.3</a>, <a target="_blank" href="https://github.com/DT-UCPH/sp/blob/master/app" title="DT-UCPH/sp app">DT-UCPH/sp/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
T.text(list(range(1,11)))
# Out:
# 'בראשית ברא'

# %%
words = list(range(1, 11))

# %%
v1 = F.otype.s("verse")[0]
v1
# Out:
# 399584

# %%
A.plain(v1)
# Out:
# <div class="rtl"><span class="tfsechead rtl"><span class="ltr">Genesis 1:1</span></span>  <span class="txtu hbo rtl"><span title="verse">1</span> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ב</span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ר</span><span class="txtu hbo">א</span><span class="txtu hbo">ש</span><span class="txtu hbo">י</span><span class="txtu hbo">ת</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ב</span><span class="txtu hbo">ר</span><span class="txtu hbo">א</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">א</span><span class="txtu hbo">ל</span><span class="txtu hbo">ה</span><span class="txtu hbo">י</span><span class="txtu hbo">ם</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">א</span><span class="txtu hbo">ת</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="tx
# ...

# %%
A.pretty(v1, withNodes=True)
# Out:
# <div class="tfsechead rtl"><span class="ltr">Genesis 1:1</span></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:399584 </span> <span class="txtu hbo"><span title="verse">1</span></span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">word:405425 </span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1 </span> <span class="txtu hbo">ב</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">word:405426 </span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">2 </span> <span class="txtu hbo">ר</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3 </span> <span class="txtu hbo">א</span></div></div><div class="contnr c0 trm rtl  " ><div class="lb
# ...

# %%
A.plain(405425, _asString=True)
# Out:
# '<div class="rtl"><span class="tfsechead rtl"><span class="ltr">Genesis 1:1</span></span>\xa0\xa0<span class="txtu hbo rtl"> </span><span class="txtu hbo">ב</span></div>'

# %%
T.text(405425)
# Out:
# 'ב'

# %%
T.text(v1)
# Out:
# 'בראשית ברא אלהים את השמים ואת הארץ '

# %%
for ch in T.text(v1):
    print(f"{ch=}")
# Out:
# ch='ב'
# ch='ר'
# ch='א'
# ch='ש'
# ch='י'
# ch='ת'
# ch=' '
# ch='ב'
# ch='ר'
# ch='א'
# ch=' '
# ch='א'
# ch='ל'
# ch='ה'
# ch='י'
# ch='ם'
# ch=' '
# ch='א'
# ch='ת'
# ch=' '
# ch='ה'
# ch='ש'
# ch='מ'
# ch='י'
# ch='ם'
# ch=' '
# ch='ו'
# ch='א'
# ch='ת'
# ch=' '
# ch='ה'
# ch='א'
# ch='ר'
# ch='ץ'
# ch=' '

# %%
A.plain(v1, _asString=True)
# Out:
# '<div class="rtl"><span class="tfsechead rtl"><span class="ltr">Genesis 1:1</span></span>\xa0\xa0<span class="txtu hbo rtl"><span title="verse">1</span> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ב</span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ר</span><span class="txtu hbo">א</span><span class="txtu hbo">ש</span><span class="txtu hbo">י</span><span class="txtu hbo">ת</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">ב</span><span class="txtu hbo">ר</span><span class="txtu hbo">א</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">א</span><span class="txtu hbo">ל</span><span class="txtu hbo">ה</span><span class="txtu hbo">י</span><span class="txtu hbo">ם</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span class="txtu hbo">א</span><span class="txtu hbo">ת</span><span class="txtu hbo"> </span><span class="txtu hbo rtl"> </span><span cl
# ...

# %%
A.plain(v1)
# Out:
# verse 399584 outer=True tpl='{verse}' tplFilled='<span title="verse">1</span> '
# word 405425 outer=False tpl='' tplFilled=' '
# word 405426 outer=False tpl='' tplFilled=' '
# word 405427 outer=False tpl='' tplFilled=' '
# word 405428 outer=False tpl='' tplFilled=' '
# word 405429 outer=False tpl='' tplFilled=' '
# word 405430 outer=False tpl='' tplFilled=' '
# word 405431 outer=False tpl='' tplFilled=' '
# word 405432 outer=False tpl='' tplFilled=' '
# word 405433 outer=False tpl='' tplFilled=' '
# word 405434 outer=False tpl='' tplFilled=' '
# word 405435 outer=False tpl='' tplFilled=' '
# ...

# %%
A = use("hermans/works:clone", checkout="clone", backend="gitlab.huc.knaw.nl", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/hermans/works/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/hermans/works/tf/0.4</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/hermans/works/parallels/tf/0.4</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.2.3</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/hermans/works/blob/master/app" title="hermans/works app">hermans/works/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...
