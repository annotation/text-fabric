# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("CLARIAH/wp6-ferdinandhuyck:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-ferdinandhuyck/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/CLARIAH/wp6-ferdinandhuyck/tf/0.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.2.3</a>, <a target="_blank" href="https://github.com/CLARIAH/wp6-ferdinandhuyck/blob/main/app" title="CLARIAH/wp6-ferdinandhuyck app">CLARIAH/wp6-ferdinandhuyck/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
A.api.TF.features
# Out:
# {'after': <tf.core.data.Data at 0x1427df290>,
#  'chapter': <tf.core.data.Data at 0x1427df5d0>,
#  'chunk': <tf.core.data.Data at 0x1427dfa90>,
#  'curr': <tf.core.data.Data at 0x1427dfd90>,
#  'empty': <tf.core.data.Data at 0x1427dfbd0>,
#  'empty_lb': <tf.core.data.Data at 0x1427dfd10>,
#  'empty_link': <tf.core.data.Data at 0x1427dffd0>,
#  'empty_pb': <tf.core.data.Data at 0x1427dfdd0>,
#  'empty_pb_n': <tf.core.data.Data at 0x10486a790>,
#  'is_meta': <tf.core.data.Data at 0x104868ed0>,
#  'is_note': <tf.core.data.Data at 0x104868b10>,
#  'n': <tf.core.data.Data at 0x104868190>,
#  'oslots': <tf.core.data.Data at 0x104869190>,
#  'otext': <tf.core.data.Data at 0x104869c50>,
#  'otype': <tf.core.data.Data at 0x104869350>,
#  'place': <tf.core.data.Data at 0x104869990>,
#  'rend': <tf.core.data.Data at 0x1427814d0>,
#  'rend_1tab': <tf.core.data.Data at 0x142780310>,
#  'rend_b': <tf.core.data.Data at 0x1427800d0>,
#  'rend_bq': <tf.core.data.Data at 0x142780050>,
# ...

# %%
A.api.TF.features["place"].data

# %%
A.exportMQL("fh")
# Out:
#   0.00s Checking features of dataset fh
#    |   25m 52s feature "type" => "typ"
#   0.00s 28 features to export to MQL ...
#   0.00s Loading 28 features
#   0.00s Writing enumerations
# 	after          :  228 values, 228 not a name, e.g. «»
# 	chapter        :   44 values, 44 not a name, e.g. «2 interpGrp»
# 	empty_pb_n     :  480 values, 462 not a name, e.g. «1»
# 	is_meta        :    1 values, 1 not a name, e.g. «1»
# 	is_note        :    1 values, 1 not a name, e.g. «1»
# 	n              :    2 values, 2 not a name, e.g. «(1)»
# 	rend           :   11 values, 1 not a name, e.g. «; 1tab»
# 	to             :    3 values, 3 not a name, e.g. «U20B0.gif»
#    |     0.01s Writing an all-in-one enum with   18 values
#   0.02s Mapping 28 features onto 45 object types
#   0.05s Writing 28 features as data in 45 object types
#    |     0.00s word data ...
#    |      |     0.14s batch of size                4.0MB with   50000 of   50000 words
# ...
