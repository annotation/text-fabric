# %%
from tf.clean import clean

# %%
pDir = '~/github/pthu/patristics/tf'

# %%
clean(specific=pDir, current=True)
# Out:
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Theophylacti/In Cyrilli In Xii Prophetas/.tf/2 version 2: delete it and its 18 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Dialogus Cum Tryphone/.tf/2 version 2: delete it and its 19 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Apologia/.tf/2 version 2: delete it and its 18 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Apologia Secunda/.tf/2 version 2: delete it and its 19 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Pinytus/De Epistola Pinyti Ad Dionysium/.tf/2 version 2: delete it and its 18 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Eusebius Of Caesarea/Historia Ecclesiastica/.tf/2 version 2: delete it and its 18 files ...dry
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Theodoretus/Historia Ecclesiastica/.tf/2 version 2: delete it and its 20 files ...dry
# ...

# %%
clean(specific=pDir, current=True, dry=False)
# Out:
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Theophylacti/In Cyrilli In Xii Prophetas/.tf/2 version 2: delete it and its 18 files ...done
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Dialogus Cum Tryphone/.tf/2 version 2: delete it and its 19 files ...done
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Apologia/.tf/2 version 2: delete it and its 18 files ...done
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Justinus Martyr/Apologia Secunda/.tf/2 version 2: delete it and its 19 files ...done
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Pinytus/De Epistola Pinyti Ad Dionysium/.tf/2 version 2: delete it and its 18 files ...done
# /Users/dirk/github/pthu/patristics/tf/1.0/patristics/Eusebius Of Caesarea/Historia Ecclesiastica/.tf/2 version 2: delete it and its 18 files ...done
# ...
