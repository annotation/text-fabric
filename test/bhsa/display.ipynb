# %% [markdown]
# # Rich display
#
# We have a new module, `bhsa.py`, that can display every node in a shebanq-like way.
# It can also display query results obtained by Text-Fabric search.
#
# ## Install
#
# This module is part of the [BHSA](https://github.com/ETCBC/bhsa) repo, which you need to have to run TF on the Hebrew Bible anyway. So update your repo by `git pull origin master` or clone it again.
#
# ## Usage
#
# The new module makes the use of TF a bit easier.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
from IPython.display import display, HTML
from tf.fabric import Fabric
from tf.extra.bhsa import Bhsa

# %% [markdown]
# Specify locations.

# %%
VERSION = '2017'
DATABASE = '~/github/etcbc'
BHSA = f'bhsa/tf/{VERSION}'
PHONO = f'phono/tf/{VERSION}'

# %% [markdown]
# Call Text-Fabric in the usual way.

# %%
TF = Fabric(locations=[DATABASE], modules=[BHSA, PHONO], silent=False )
# Out:
# This is Text-Fabric 5.0.4
# Api reference : https://dans-labs.github.io/text-fabric/Api/General/
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 118 features found and 0 ignored

# %%
api = TF.load('''
    vs vt
''', silent=True)
api.makeAvailableIn(globals())

# %% [markdown]
# ## Call up more power
#
#
# If you have your notebook in a github repo, you will get the link to its online version,
# on GitHub and on NBviewer.
# provided you pass the name of your notebook.
#
# Note that handy documentation links are shown after loading.

# %%
B = Bhsa(api, 'display', version=VERSION)
# Out:
# **Documentation:** <a target="_blank" href="https://etcbc.github.io/bhsa" title="{provenance of this corpus}">BHSA</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/hebrew/2017/0_home.html" title="{CORPUS.upper()} feature documentation">Feature docs</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/Bhsa/" title="BHSA API documentation">BHSA API</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/" title="text-fabric-api">Text-Fabric API 5.0.4</a> <a target="_blank" href="https://dans-labs.github.io/text-fabric/Api/General/#search-templates" title="Search Templates Introduction and Reference">Search Reference</a>
# This notebook online:
# <a target="_blank" href="http://nbviewer.jupyter.org/github/Dans-labs/text-fabric/blob/master/test/bhsa/display.ipynb">NBViewer</a>
# <a target="_blank" href="https://github.com/Dans-labs/text-fabric/blob/master/test/bhsa/display.ipynb">GitHub</a>
# <style type="text/css">
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lex {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.L,.catom.L,.patom.L {
#     border-left-style: none
# }
# .satom.R,.catom.R,.patom.R {
#     border-right-style: none
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl;
#     text-decoration: none;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #aaaaaa;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .hl {
#     background-color: #ffee66;
# }
# </style>

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
phrase = 651572
B.pretty(phrase)
# Out:
# <div class="atoms " style="background-color: None;">
#
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1MN" title="show this lexeme in SHEBANQ">מֵ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></span> <span class="gloss">from</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1OL" title="show this lexeme in SHEBANQ">עַ֣ל </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></span> <span class="gloss">upon</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1L" title="show this lexeme in SHEBANQ">לָ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></span> <span class="gloss">to</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1RQJOn" title="show this lexeme in SHEBANQ">רָקִ֑יעַ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></span> <span class="gloss">firmament</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Where is this phrase on SHEBANQ?
# You can click on the word `phrase` in the label of the box.
#
# You can generate this link in code as follows:

# %%
B.shbLink(phrase)
# Out:
# <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a>

# %% [markdown]
# A link to another passage:

# %%
z = T.nodeFromSection(('Ezra', 3, 4))

# %%
B.shbLink(z)
# Out:
# <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Esra&chapter=3&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Ezra 3:4</a>

# %% [markdown]
# # Verses
# Now a couple of verses:

# %%
verse1 = T.nodeFromSection(('Genesis', 1, 7))
verse2 = T.nodeFromSection(('Genesis', 1, 17))

# %%
B.pretty(verse1)
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:7</a></div>
#
#     </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">sentence</a>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1OFHv" title="show this lexeme in SHEBANQ">יַּ֣עַשׂ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">verb</a></span> <span class="gloss">make</span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִים֮ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></span> <span class="gloss">god(s)</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1RQJOn" title="show this lexeme in SHEBANQ">רָקִיעַ֒ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">subs</a></span> <span class="gloss">firmament</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">sentence</a>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l" style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=7&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:7">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1BDLv" title="show this lexeme in SHEBANQ">יַּבְדֵּ֗ל </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebr

# %% [markdown]
# The next verse with node numbers.

# %%
B.pretty(verse2, withNodes=True)
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#         <span class="nd">1414206</span>
#     </div>
#
# <div class="satom  L" style="background-color: None;">
#
#     <div class="sentence">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">sentence</a> <span class="nd">1172254</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a> <span class="nd">427611</span>  <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a> <span class="nd">651681</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">314</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a> <span class="nd">651682</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">315</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1NTNv" title="show this lexeme in SHEBANQ">יִּתֵּ֥ן </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></span> <span class="gloss">give</span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a> <span class="nd">651683</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">316</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֹתָ֛ם </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a> <span class="nd">651684</span>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">317</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִ֖ים </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span> <span class="gloss">god(s)</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a> <span class="nd">651685</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">318</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></span> <span class="gloss">in</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">319</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1RQJOn" title="show this lexeme in SHEBANQ">רְקִ֣יעַ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span> <span class="gloss">firmament</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">320</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">321</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1CMJMn" title="show this lexeme in SHEBANQ">שָּׁמָ֑יִם </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span> <span class="gloss">heavens</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a> <span class="nd">427612</span>  <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>

# %% [markdown]
# Now we selectively remove a few features from the display:

# %%
B.pretty(verse2, suppress={'gloss', 'typ'})
# Out:
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Genesis 1:17</a></div>
#
#     </div>
#
# <div class="satom  L" style="background-color: None;">
#
#     <div class="sentence">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">sentence</a>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Conj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">conj</a></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1NTNv" title="show this lexeme in SHEBANQ">יִּתֵּ֥ן </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">verb</a></span> <span class="vs">qal</span> <span class="vt">wayq</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Objc</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֹתָ֛ם </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Subj</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהִ֖ים </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Cmpl</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1RQJOn" title="show this lexeme in SHEBANQ">רְקִ֣יעַ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">art</a></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1CMJMn" title="show this lexeme in SHEBANQ">שָּׁמָ֑יִם </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">subs</a></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">clause</a>   <span class="rela">Adju</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">phrase</a>   <span class="function">Pred</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1L" title="show this lexeme in SHEBANQ">לְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&chapter=1&verse=17&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Genesis 1:17">prep</a></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebr

# %% [markdown]
# # Query results
# We run a TF query and show some of its results with a lot of pomp and circumstance.
# The query is written by Stephen Ku, and he is the one who prompted me to write
# rich display function for query results.

# %%
ellipQuery = '''
sentence
  c1:clause
    phrase function=Pred
      word pdp=verb
  c2:clause
    phrase function=Pred
  c3:clause typ=Ellp
    phrase function=Objc
      word pdp=subs|nmpr|prps|prde|prin
  c1 << c2
  c2 << c3
'''

# %% [markdown]
# Instead of running `S.search()`, we do `B.search()`.

# %%
results = B.search(ellipQuery)
len(results)
# Out:
#   2.74s 1410 results
# 1410

# %% [markdown]
# Here it comes: the `B.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
B.show(results, start=10, end=14, withNodes=True)
# Out:
# **verse** *10*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 23:16</a></div>
#         <span class="nd">1416350</span>
#     </div>
#
# <div class="satom  r hl">
#
#     <div class="sentence hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=15&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:15">sentence</a> <span class="nd">1178797</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">clause</a> <span class="nd">436062</span>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">phrase</a> <span class="nd">677161</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">41279</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">phrase</a> <span class="nd">677162</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">41280</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1XGn" title="show this lexeme in SHEBANQ">חַ֤ג </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">subs</a></span> <span class="gloss">festival</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">41281</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">41282</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1QYJRn" title="show this lexeme in SHEBANQ">קָּצִיר֙ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">subs</a></span> <span class="gloss">harvest</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">phrase</a> <span class="nd">677163</span>  <span class="function">Adju</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">41283</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1BKWRJMn" title="show this lexeme in SHEBANQ">בִּכּוּרֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">subs</a></span> <span class="gloss">first fruits</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">41284</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1MOFHn" title="show this lexeme in SHEBANQ">מַעֲשֶׂ֔יךָ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">subs</a></span> <span class="gloss">deed</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">clause</a> <span class="nd">436063</span>  <span class="rela">Attr</span> <span class="typ">xYq0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">phrase</a> <span class="nd">677164</span>  <span class="function">Rela</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">41285</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ACR" title="show this lexeme in SHEBANQ">אֲשֶׁ֥ר </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">conj</a></span> <span class="gloss">&lt;relative></span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">phrase</a> <span class="nd">677165</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">41286</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ZROv" title="show this lexeme in SHEBANQ">תִּזְרַ֖ע </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=23&verse=16&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 23:16">verb</a></span> <span class="gloss">sow</span> <span class="vs">qal</span> <span class="vt">impf</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " styl
# **verse** *11*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 25:12</a></div>
#         <span class="nd">1416397</span>
#     </div>
#
# <div class="satom  hl">
#
#     <div class="sentence hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">sentence</a> <span class="nd">1178916</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">clause</a> <span class="nd">436209</span>  <span class="typ">WQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677628</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">42122</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677629</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl">
# <span class="nd">42123</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1JYQv" title="show this lexeme in SHEBANQ">יָצַ֣קְתָּ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">verb</a></span> <span class="gloss">pour</span> <span class="vs">qal</span> <span class="vt">perf</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677630</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">42124</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1L" title="show this lexeme in SHEBANQ">לֹּ֗ו </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">prep</a></span> <span class="gloss">to</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677631</span>  <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">42125</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ARBOn" title="show this lexeme in SHEBANQ">אַרְבַּע֙ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">subs</a></span> <span class="gloss">four</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">42126</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1VBOTn" title="show this lexeme in SHEBANQ">טַבְּעֹ֣ת </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">subs</a></span> <span class="gloss">sealing ring</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">42127</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ZHBn" title="show this lexeme in SHEBANQ">זָהָ֔ב </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">subs</a></span> <span class="gloss">gold</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">clause</a> <span class="nd">436210</span>  <span class="rela">Coor</span> <span class="typ">WQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677632</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">42128</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=25&verse=12&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 25:12">phrase</a> <span class="nd">677633</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">42129</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1NTNv" title="show this lexeme in SHEBANQ">נָ֣תַתָּ֔ה </a></div>
# <di
# **verse** *12*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 31:6</a></div>
#         <span class="nd">1416616</span>
#     </div>
#
# <div class="satom " style="background-color: None;">
#
#     <div class="sentence">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">sentence</a> <span class="nd">1179364</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">clause</a> <span class="nd">436834</span>  <span class="typ">CPen</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679622</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46227</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679623</span>  <span class="function">Frnt</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46228</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ANJ" title="show this lexeme in SHEBANQ">אֲנִ֞י </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">prps</a></span> <span class="gloss">i</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">clause</a> <span class="nd">436835</span>  <span class="rela">Resu</span> <span class="typ">xQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679624</span>  <span class="function">Intj</span> <span class="typ">InjP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46229</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1HNH" title="show this lexeme in SHEBANQ">הִנֵּ֧ה </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">intj</a></span> <span class="gloss">behold</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679625</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46230</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1NTNv" title="show this lexeme in SHEBANQ">נָתַ֣תִּי </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">verb</a></span> <span class="gloss">give</span> <span class="vs">qal</span> <span class="vt">perf</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679626</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46231</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1ATii" title="show this lexeme in SHEBANQ">אִתֹּ֗ו </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">prep</a></span> <span class="gloss">together with</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l" style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">phrase</a> <span class="nd">679627</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46232</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֵ֣ת </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46233</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AHLJABn" title="show this lexeme in SHEBANQ">אָהֳלִיאָ֞ב </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">nmpr</a></span> <span class="gloss">Oholiab</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l" style="background-color: None;">
#
#     <div clas
# **verse** *13*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 31:10</a></div>
#         <span class="nd">1416620</span>
#     </div>
#
# <div class="satom  R L hl">
#
#     <div class="sentence hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">sentence</a> <span class="nd">1179366</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom " style="background-color: None;">
#
#     <div class="clause">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">clause</a> <span class="nd">436843</span>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">phrase</a> <span class="nd">679644</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46313</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l" style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">phrase</a> <span class="nd">679645</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46314</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֵ֖ת </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46315</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1BGDn" title="show this lexeme in SHEBANQ">בִּגְדֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">subs</a></span> <span class="gloss">garment</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46316</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46317</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1FRDin" title="show this lexeme in SHEBANQ">שְּׂרָ֑ד </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">subs</a></span> <span class="gloss">cord</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46318</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46319</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46320</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1BGDn" title="show this lexeme in SHEBANQ">בִּגְדֵ֤י </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">subs</a></span> <span class="gloss">garment</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46321</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46322</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1QDCn" title="show this lexeme in SHEBANQ">קֹּ֨דֶשׁ֙ </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">subs</a></span> <span class="gloss">holiness</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l" style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=10&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:10">phrase</a> <span class="nd">679645</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46323</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1L" title="show this lexeme in SHEBANQ">לְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="
# **verse** *14*
# <div class="verse " style="background-color: None;">
#
#     <div class="vl">
#         <div class="vrs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Exodus 31:11</a></div>
#         <span class="nd">1416621</span>
#     </div>
#
# <div class="satom  R hl">
#
#     <div class="sentence hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=6&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:6">sentence</a> <span class="nd">1179366</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl">
#
#     <div class="clause hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">clause</a> <span class="nd">436845</span>  <span class="typ">Ellp</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">phrase</a> <span class="nd">679647</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46333</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl">
#
#     <div class="phrase hl">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">phrase</a> <span class="nd">679648</span>  <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46334</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֵ֨ת </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word  hl">
# <span class="nd">46335</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1CMNn" title="show this lexeme in SHEBANQ">שֶׁ֧מֶן </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">subs</a></span> <span class="gloss">oil</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46336</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word  hl">
# <span class="nd">46337</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1MCXHn" title="show this lexeme in SHEBANQ">מִּשְׁחָ֛ה </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">subs</a></span> <span class="gloss">anointment</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46338</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">conj</a></span> <span class="gloss">and</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46339</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">prep</a></span> <span class="gloss">&lt;object marker></span></div>
#
# </div>
#
# <div class="word  hl">
# <span class="nd">46340</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1QVRTn" title="show this lexeme in SHEBANQ">קְטֹ֥רֶת </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">subs</a></span> <span class="gloss">smoke of sacrifice</span></div>
#
# </div>
#
# <div class="word " style="background-color: None;">
# <span class="nd">46341</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">art</a></span> <span class="gloss">the</span></div>
#
# </div>
#
# <div class="word  hl">
# <span class="nd">46342</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1SMn" title="show this lexeme in SHEBANQ">סַּמִּ֖ים </a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">subs</a></span> <span class="gloss">perfume</span></div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom " style="background-color: None;">
#
#     <div class="phrase">
#         <a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">phrase</a> <span class="nd">679649</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word " style="background-color: None;">
# <span class="nd">46343</span>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=2017&id=1L" title="show this lexeme in SHEBANQ">לַ</a></div>
# <div class="features"> <span class="pdp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&chapter=31&verse=11&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Exodus 31:11">prep</
